# %%
import stim
from dem_builder_teleportation_LDU import DEM_builder
import os
import numpy as np
import scipy
from surface_code_teleportation_LDU import Rotated_Surface_Code_teleportation_LDU
import pymatching
import pickle
import multiprocessing
from multiprocessing import Pool

# %%
#function for simulation

#Compute the logical error rate of the surface code supplemented with the teleportation LDU for a given noise and loss probability using a naive decoder
#stored as dictionnary in a file for a fixed loss probability and various depolarizing noise probabilities

def simulation_code_fixed_loss(L,loss,depo,num_shots):
    loss=round(loss,5)
    depo=round(depo,5)
    lattice = Rotated_Surface_Code_teleportation_LDU(L,L,L,'|0>','Z',measurement_order='z_first',loss_rate=loss,after_CZ=('DEPOLARIZE2',depo))
    dem_build=DEM_builder(lattice)
    path_dem='data/dem/naive_dem_teleportation_LDU/DEM_surface_code_({},{},{})_loss_rate={}.dem'.format(lattice.width,lattice.height,lattice.rounds,lattice.loss_rate)
    
    error_rate=dem_build.naive_logical_errors(num_shots,path_dem)
    
    if os.path.exists('data/logical_error/naive_logical_error_teleportation_LDU_d=({},{})_rounds={}_loss_rate={}.pkl'.format(L,L,L,loss)):
        with open('data/logical_error/naive_logical_error_teleportation_LDU_d=({},{})_rounds={}_loss_rate={}.pkl'.format(L,L,L,loss), 'rb') as fp:
            data_saved=pickle.load(fp)
        
    else:
        data_saved={}
    if depo not in data_saved.keys():#CREATE DICTIONNARY if the noise probability has never been computed
        data_saved[depo]={}
        data_saved[depo]['num_shots']=num_shots
        data_saved[depo]['error_rate']=error_rate
    else:#UPDATE DICTIONNARY if there has been already simulation for that given loss and noise probability
        data_saved[depo]['error_rate']*=data_saved[depo]['num_shots']/(data_saved[depo]['num_shots']+num_shots)
        data_saved[depo]['error_rate']+=error_rate*num_shots/(data_saved[depo]['num_shots']+num_shots)
        data_saved[depo]['num_shots']+=num_shots
    
    #stored in a file for a given loss and various noise probabilities
    with open('data/logical_error/naive_logical_error_teleportation_LDU_d=({},{})_rounds={}_loss_rate={}.pkl'.format(L,L,L,loss), 'wb') as fp:
        pickle.dump(data_saved, fp)

    print('logical error rate for (L={},loss_rate={},depo={}) = {}'.format(L,loss,depo,error_rate))
    


#wrapper to one argument (needed for parallelization)
def multi_args_wrapper_fixed_loss(args):
   simulation_code_fixed_loss(*args)

# %%
#Compute the logical error rate and store as a dictionnary in files with a fixed loss probabilities

Ls = range(3,13,2)
depo_list = np.linspace(0.001, 0.016, 16) #list of depolarizing noise probabilities
loss_list=[0.,0.001,0.002,0.003,0.005,0.007,0.01,0.015,0.02,0.025,0.027] #list of loss probabilities
num_shots = 10000 #number of shots per core
nb_core=10 #number of cores used

for loss_rate in loss_list:
    for L in Ls:
        for depo in depo_list:
            with Pool(processes=nb_core) as pool:
                pool.imap(multi_args_wrapper_fixed_loss,[(L,loss_rate,depo,num_shots) for _ in range(10)])
                pool.close()
                pool.join()
# Out:
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0003
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0004
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0004
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0003
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0001
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0002
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0005
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0004
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0005
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0016
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0017
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0009
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0014
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0021
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0012
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0018
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0014
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0015
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0019
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0035
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0041
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0036
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0039
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0038
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0026
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0029
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0024
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.003
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0029
# logical error rate for (L=3,loss_rate=0.0,depo=0.004) = 0.0039
# logical error rate for (L=3,loss_rate=0.0,depo=0.004) = 0.0056
# logical error rate for (L=3,loss_rate=0.0,depo=0.004) = 0.
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.05
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.0542
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.0512
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.0527
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.052
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.0507
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.0494
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.0489
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.0522
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.0512
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.0685
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.0671
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.0711
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.0685
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.0675
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.0654
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.0685
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.0671
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.068
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.0871
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.0888
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.0934
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.0876
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.0889
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.086
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.092
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.0887
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.0863
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.0894
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.1084
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.1046
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.1096
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.1071
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.1104
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.1072
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.1102
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.1133
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.1058
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.1134
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.1294
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.1342
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.1373
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.1321
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.1365
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.1365
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.133
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.1345
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.1359
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.131
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.16
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.1653
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.1551
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.1591
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.1546
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.1554
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.1639
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.1645
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.156
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.1584
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.1838
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.1783
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.1816
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.185
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.1861
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.1906
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.1829
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.1848
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.1733
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.1863
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0001
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0001
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0001
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0002
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0001
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0002
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0001
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0005
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0004
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0003
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0001
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0001
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0002
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0002
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0013
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0011
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.001
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0015
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0003
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0006
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0017
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0006
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0007
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0011
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0034
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0024
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0034
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0024
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0034
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0021
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0027
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0032
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0035
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0026
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0058
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0056
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0078
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0062
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.007
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0059
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0066
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0049
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0049
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0066
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0137
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0114
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.014
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0127
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0121
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0114
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0141
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0127
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.012
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0096
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0244
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0247
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0229
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0191
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0218
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0254
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0212
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.021
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0213
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0198
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0363
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0341
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0354
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0355
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0374
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0362
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0375
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0383
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.037
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0337
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.0565
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.0518
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.0517
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.0601
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.054
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.0525
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.0502
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.0526
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.0516
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.0556
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.0769
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.0754
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.0774
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.0752
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.0749
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.0742
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.0791
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.0729
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.0788
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.078
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.1072
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.1068
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.1046
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.1049
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.1003
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.1071
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.1046
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.1055
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.1038
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.1043
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.1351
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.1293
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.135
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.129
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.1417
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.1351
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.1276
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.1378
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.1318
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.1298
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.1691
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.1709
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.1666
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.1674
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.1708
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.1725
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.1735
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.1638
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.1662
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.1619
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.2052
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.2051
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.2022
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.2042
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.1984
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.2016
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.2031
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.2
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.2023
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.2052
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.2456
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.2381
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.2426
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.2357
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.2465
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.2427
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.2442
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.2479
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.2375
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.2355
# logical error rate for (L=11,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.003) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.003) = 0.0002
# logical error rate for (L=11,loss_rate=0.0,depo=0.003) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.003) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.003) = 0.0002
# logical error rate for (L=11,loss_rate=0.0,depo=0.003) = 0.0001
# logical error rate for (L=11,loss_rate=0.0,depo=0.003) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.003) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.003) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.003) = 0.0
# logical error rate for (L=11,loss_rate=0.0,depo=0.004) = 0.0007
# logical error rate for (L=11,loss_rate=0.0,depo=0.004) = 0.0004
# logical error rate for (L=11,loss_rate=0.0,depo=0.004) = 0.0003
# logical error rate for (L=11,loss_rate=0.0,depo=0.004) = 0.0005
# logical error rate for (L=11,loss_rate=0.0,depo=0.004) = 0.0003
# logical error rate for (L=11,loss_rate=0.0,depo=0.004) = 0.0006
# logical error rate for (L=11,loss_rate=0.0,depo=0.004) = 0.0003
# logical error rate for (L=11,loss_rate=0.0,depo=0.004) = 0.0001
# logical error rate for (L=11,loss_rate=0.0,depo=0.004) = 0.0001
# logical error rate for (L=11,loss_rate=0.0,depo=0.004) = 0.0005
# logical error rate for (L=11,loss_rate=0.0,depo=0.005) = 0.0015
# logical error rate for (L=11,loss_rate=0.0,depo=0.005) = 0.0012
# logical error rate for (L=11,loss_rate=0.0,depo=0.005) = 0.0009
# logical error rate for (L=11,loss_rate=0.0,depo=0.005) = 0.0017
# logical error rate for (L=11,loss_rate=0.0,depo=0.005) = 0.0021
# logical error rate for (L=11,loss_rate=0.0,depo=0.005) = 0.0017
# logical error rate for (L=11,loss_rate=0.0,depo=0.005) = 0.0009
# logical error rate for (L=11,loss_rate=0.0,depo=0.005) = 0.0016
# logical error rate for (L=11,loss_rate=0.0,depo=0.005) = 0.0022
# logical error rate for (L=11,loss_rate=0.0,depo=0.005) = 0.0017
# logical error rate for (L=11,loss_rate=0.0,depo=0.006) = 0.0045
# logical error rate for (L=11,loss_rate=0.0,depo=0.006) = 0.0037
# logical error rate for (L=11,loss_rate=0.0,depo=0.006) = 0.0027
# logical error rate for (L=11,loss_rate=0.0,depo=0.006) = 0.0043
# logical error rate for (L=11,loss_rate=0.0,depo=0.006) = 0.0042
# logical error rate for (L=11,loss_rate=0.0,depo=0.006) = 0.0036
# logical error rate for (L=11,loss_rate=0.0,depo=0.006) = 0.0038
# logical error rate for (L=11,loss_rate=0.0,depo=0.006) = 0.0041
# logical error rate for (L=11,loss_rate=0.0,depo=0.006) = 0.0043
# logical error rate for (L=11,loss_rate=0.0,depo=0.006) = 0.0028
# logical error rate for (L=11,loss_rate=0.0,depo=0.007) = 0.0095
# logical error rate for (L=11,loss_rate=0.0,depo=0.007) = 0.0071
# logical error rate for (L=11,loss_rate=0.0,depo=0.007) = 0.0111
# logical error rate for (L=11,loss_rate=0.0,depo=0.007) = 0.0112
# logical error rate for (L=11,loss_rate=0.0,depo=0.007) = 0.0093
# logical error rate for (L=11,loss_rate=0.0,depo=0.007) = 0.0088
# logical error rate for (L=11,loss_rate=0.0,depo=0.007) = 0.0089
# logical error rate for (L=11,loss_rate=0.0,depo=0.007) = 0.0091
# logical error rate for (L=11,loss_rate=0.0,depo=0.007) = 0.0105
# logical error rate for (L=11,loss_rate=0.0,depo=0.007) = 0.0104
# logical error rate for (L=11,loss_rate=0.0,depo=0.008) = 0.0177
# logical error rate for (L=11,loss_rate=0.0,depo=0.008) = 0.017
# logical error rate for (L=11,loss_rate=0.0,depo=0.008) = 0.021
# logical error rate for (L=11,loss_rate=0.0,depo=0.008) = 0.0205
# logical error rate for (L=11,loss_rate=0.0,depo=0.008) = 0.0207
# logical error rate for (L=11,loss_rate=0.0,depo=0.008) = 0.0197
# logical error rate for (L=11,loss_rate=0.0,depo=0.008) = 0.0202
# logical error rate for (L=11,loss_rate=0.0,depo=0.008) = 0.017
# logical error rate for (L=11,loss_rate=0.0,depo=0.008) = 0.0184
# logical error rate for (L=11,loss_rate=0.0,depo=0.008) = 0.0195
# logical error rate for (L=11,loss_rate=0.0,depo=0.009) = 0.0377
# logical error rate for (L=11,loss_rate=0.0,depo=0.009) = 0.0334
# logical error rate for (L=11,loss_rate=0.0,depo=0.009) = 0.0312
# logical error rate for (L=11,loss_rate=0.0,depo=0.009) = 0.0322
# logical error rate for (L=11,loss_rate=0.0,depo=0.009) = 0.0316
# logical error rate for (L=11,loss_rate=0.0,depo=0.009) = 0.0381
# logical error rate for (L=11,loss_rate=0.0,depo=0.009) = 0.036
# logical error rate for (L=11,loss_rate=0.0,depo=0.009) = 0.0342
# logical error rate for (L=11,loss_rate=0.0,depo=0.009) = 0.0364
# logical error rate for (L=11,loss_rate=0.0,depo=0.009) = 0.0346
# logical error rate for (L=11,loss_rate=0.0,depo=0.01) = 0.0555
# logical error rate for (L=11,loss_rate=0.0,depo=0.01) = 0.0513
# logical error rate for (L=11,loss_rate=0.0,depo=0.01) = 0.0563
# logical error rate for (L=11,loss_rate=0.0,depo=0.01) = 0.0548
# logical error rate for (L=11,loss_rate=0.0,depo=0.01) = 0.0538
# logical error rate for (L=11,loss_rate=0.0,depo=0.01) = 0.0575
# logical error rate for (L=11,loss_rate=0.0,depo=0.01) = 0.0575
# logical error rate for (L=11,loss_rate=0.0,depo=0.01) = 0.0556
# logical error rate for (L=11,loss_rate=0.0,depo=0.01) = 0.0499
# logical error rate for (L=11,loss_rate=0.0,depo=0.01) = 0.0553
# logical error rate for (L=11,loss_rate=0.0,depo=0.011) = 0.0823
# logical error rate for (L=11,loss_rate=0.0,depo=0.011) = 0.0834
# logical error rate for (L=11,loss_rate=0.0,depo=0.011) = 0.0795
# logical error rate for (L=11,loss_rate=0.0,depo=0.011) = 0.0883
# logical error rate for (L=11,loss_rate=0.0,depo=0.011) = 0.0862
# logical error rate for (L=11,loss_rate=0.0,depo=0.011) = 0.0791
# logical error rate for (L=11,loss_rate=0.0,depo=0.011) = 0.0813
# logical error rate for (L=11,loss_rate=0.0,depo=0.011) = 0.0843
# logical error rate for (L=11,loss_rate=0.0,depo=0.011) = 0.0889
# logical error rate for (L=11,loss_rate=0.0,depo=0.011) = 0.0844
# logical error rate for (L=11,loss_rate=0.0,depo=0.012) = 0.1224
# logical error rate for (L=11,loss_rate=0.0,depo=0.012) = 0.1221
# logical error rate for (L=11,loss_rate=0.0,depo=0.012) = 0.119
# logical error rate for (L=11,loss_rate=0.0,depo=0.012) = 0.117
# logical error rate for (L=11,loss_rate=0.0,depo=0.012) = 0.1228
# logical error rate for (L=11,loss_rate=0.0,depo=0.012) = 0.1174
# logical error rate for (L=11,loss_rate=0.0,depo=0.012) = 0.1193
# logical error rate for (L=11,loss_rate=0.0,depo=0.012) = 0.1146
# logical error rate for (L=11,loss_rate=0.0,depo=0.012) = 0.1203
# logical error rate for (L=11,loss_rate=0.0,depo=0.012) = 0.1171
# logical error rate for (L=11,loss_rate=0.0,depo=0.013) = 0.1655
# logical error rate for (L=11,loss_rate=0.0,depo=0.013) = 0.164
# logical error rate for (L=11,loss_rate=0.0,depo=0.013) = 0.1637
# logical error rate for (L=11,loss_rate=0.0,depo=0.013) = 0.1644
# logical error rate for (L=11,loss_rate=0.0,depo=0.013) = 0.1651
# logical error rate for (L=11,loss_rate=0.0,depo=0.013) = 0.1511
# ...
# logical error rate for (L=9,loss_rate=0.025,depo=0.008) = 0.5047
# logical error rate for (L=9,loss_rate=0.025,depo=0.008) = 0.5039
# logical error rate for (L=9,loss_rate=0.025,depo=0.008) = 0.4941
# logical error rate for (L=9,loss_rate=0.025,depo=0.008) = 0.4934
# logical error rate for (L=9,loss_rate=0.025,depo=0.009) = 0.4952
# logical error rate for (L=9,loss_rate=0.025,depo=0.009) = 0.5035
# logical error rate for (L=9,loss_rate=0.025,depo=0.009) = 0.4929
# logical error rate for (L=9,loss_rate=0.025,depo=0.009) = 0.4982
# logical error rate for (L=9,loss_rate=0.025,depo=0.009) = 0.5041
# logical error rate for (L=9,loss_rate=0.025,depo=0.009) = 0.5002
# logical error rate for (L=9,loss_rate=0.025,depo=0.009) = 0.4964
# logical error rate for (L=9,loss_rate=0.025,depo=0.009) = 0.5054
# logical error rate for (L=9,loss_rate=0.025,depo=0.009) = 0.5016
# logical error rate for (L=9,loss_rate=0.025,depo=0.009) = 0.495
# logical error rate for (L=9,loss_rate=0.025,depo=0.01) = 0.4922
# logical error rate for (L=9,loss_rate=0.025,depo=0.01) = 0.5019
# logical error rate for (L=9,loss_rate=0.025,depo=0.01) = 0.4981
# logical error rate for (L=9,loss_rate=0.025,depo=0.01) = 0.4945
# logical error rate for (L=9,loss_rate=0.025,depo=0.01) = 0.4954
# logical error rate for (L=9,loss_rate=0.025,depo=0.01) = 0.4996
# logical error rate for (L=9,loss_rate=0.025,depo=0.01) = 0.4967
# logical error rate for (L=9,loss_rate=0.025,depo=0.01) = 0.5025
# logical error rate for (L=9,loss_rate=0.025,depo=0.01) = 0.4979
# logical error rate for (L=9,loss_rate=0.025,depo=0.01) = 0.4909
# logical error rate for (L=9,loss_rate=0.025,depo=0.011) = 0.508
# logical error rate for (L=9,loss_rate=0.025,depo=0.011) = 0.5009
# logical error rate for (L=9,loss_rate=0.025,depo=0.011) = 0.4994
# logical error rate for (L=9,loss_rate=0.025,depo=0.011) = 0.4963
# logical error rate for (L=9,loss_rate=0.025,depo=0.011) = 0.5052
# logical error rate for (L=9,loss_rate=0.025,depo=0.011) = 0.5012
# logical error rate for (L=9,loss_rate=0.025,depo=0.011) = 0.4981
# logical error rate for (L=9,loss_rate=0.025,depo=0.011) = 0.499
# logical error rate for (L=9,loss_rate=0.025,depo=0.011) = 0.501
# logical error rate for (L=9,loss_rate=0.025,depo=0.011) = 0.5
# logical error rate for (L=9,loss_rate=0.025,depo=0.012) = 0.5002
# logical error rate for (L=9,loss_rate=0.025,depo=0.012) = 0.5037
# logical error rate for (L=9,loss_rate=0.025,depo=0.012) = 0.5041
# logical error rate for (L=9,loss_rate=0.025,depo=0.012) = 0.4984
# logical error rate for (L=9,loss_rate=0.025,depo=0.012) = 0.5047
# logical error rate for (L=9,loss_rate=0.025,depo=0.012) = 0.5024
# logical error rate for (L=9,loss_rate=0.025,depo=0.012) = 0.5044
# logical error rate for (L=9,loss_rate=0.025,depo=0.012) = 0.5
# logical error rate for (L=9,loss_rate=0.025,depo=0.012) = 0.4984
# logical error rate for (L=9,loss_rate=0.025,depo=0.012) = 0.4981
# logical error rate for (L=9,loss_rate=0.025,depo=0.013) = 0.4925
# logical error rate for (L=9,loss_rate=0.025,depo=0.013) = 0.5026
# logical error rate for (L=9,loss_rate=0.025,depo=0.013) = 0.4896
# logical error rate for (L=9,loss_rate=0.025,depo=0.013) = 0.4982
# logical error rate for (L=9,loss_rate=0.025,depo=0.013) = 0.4993
# logical error rate for (L=9,loss_rate=0.025,depo=0.013) = 0.5007
# logical error rate for (L=9,loss_rate=0.025,depo=0.013) = 0.498
# logical error rate for (L=9,loss_rate=0.025,depo=0.013) = 0.4981
# logical error rate for (L=9,loss_rate=0.025,depo=0.013) = 0.4978
# logical error rate for (L=9,loss_rate=0.025,depo=0.013) = 0.5008
# logical error rate for (L=9,loss_rate=0.025,depo=0.014) = 0.5033
# logical error rate for (L=9,loss_rate=0.025,depo=0.014) = 0.4997
# logical error rate for (L=9,loss_rate=0.025,depo=0.014) = 0.5004
# logical error rate for (L=9,loss_rate=0.025,depo=0.014) = 0.4997
# logical error rate for (L=9,loss_rate=0.025,depo=0.014) = 0.4958
# logical error rate for (L=9,loss_rate=0.025,depo=0.014) = 0.506
# logical error rate for (L=9,loss_rate=0.025,depo=0.014) = 0.4976
# logical error rate for (L=9,loss_rate=0.025,depo=0.014) = 0.4967
# logical error rate for (L=9,loss_rate=0.025,depo=0.014) = 0.5013
# logical error rate for (L=9,loss_rate=0.025,depo=0.014) = 0.4969
# logical error rate for (L=9,loss_rate=0.025,depo=0.015) = 0.493
# logical error rate for (L=9,loss_rate=0.025,depo=0.015) = 0.5025
# logical error rate for (L=9,loss_rate=0.025,depo=0.015) = 0.4995
# logical error rate for (L=9,loss_rate=0.025,depo=0.015) = 0.5023
# logical error rate for (L=9,loss_rate=0.025,depo=0.015) = 0.4958
# logical error rate for (L=9,loss_rate=0.025,depo=0.015) = 0.5031
# logical error rate for (L=9,loss_rate=0.025,depo=0.015) = 0.4995
# logical error rate for (L=9,loss_rate=0.025,depo=0.015) = 0.4994
# logical error rate for (L=9,loss_rate=0.025,depo=0.015) = 0.5029
# logical error rate for (L=9,loss_rate=0.025,depo=0.015) = 0.5033
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.4916
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.4918
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.497
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.5012
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.498
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.506
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.4906
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.4926
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.4884
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.4963
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.5006
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.4937
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.5001
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.5018
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.5029
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.493
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.4969
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.494
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.5047
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.5046
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.4964
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.5036
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.5
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.5044
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.5002
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.5055
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.4936
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.4977
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.5063
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.4974
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.499
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.4935
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.5036
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.4931
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.5031
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.4918
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.5084
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.4938
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.5037
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.503
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5038
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.502
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5065
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5049
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5009
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5047
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5006
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5029
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5006
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5018
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.4914
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.5113
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.4998
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.496
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.4931
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.4979
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.5018
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.4957
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.5015
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.5077
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.5016
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.4924
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.4892
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.4988
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.498
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.5035
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.5092
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.5026
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.4979
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.5082
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.5015
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.4978
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.5023
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.5123
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.5012
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.5063
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.4948
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.4964
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.4991
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.4993
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.4956
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.5028
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.4985
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.4951
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.4957
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.5003
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.4909
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.5003
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.4837
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.4934
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.501
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.4943
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.4989
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.4996
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.5023
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.4969
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.5014
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.5027
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.4875
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.4942
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.5021
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.5081
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.4953
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.4958
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.5032
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.5047
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.4927
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.5035
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.4975
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.5072
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.5002
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.4961
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.4989
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.4965
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.4979
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.5018
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.4998
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.4953
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.4976
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.4937
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.4944
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.5134
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.5049
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.5009
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.5062
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.497
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.5072
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.4997
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.5005
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.5038
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.5071
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.4955
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.4933
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.5012
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.4916
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.4983
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.5076
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.5058
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.4957
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.4986
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.4933
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.496
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.4971
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.5064
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.5018
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.4967
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.5038
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.5015
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.5039
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.5046
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.5017
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.4944
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.4978
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.4999
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.5043
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.4979
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.4952
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.5076
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.5009
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.4959
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.5055
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.4912
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.4954
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.5027
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.4973
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.4923
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.5048
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.5017
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.4966
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.4981

# %%
#function for simulation

#Compute the logical error rate of the surface code supplemented with the teleportation LDU for a given noise and loss probability using a naive decoder
#stored as a dictionnary in a file for a fixed depolarizing noise probability and various loss probabilities

def simulation_code_fixed_depo(L,loss,depo,num_shots):
    loss=round(loss,5)
    depo=round(depo,5)
    lattice = Rotated_Surface_Code_teleportation_LDU(L,L,L,'|0>','Z',measurement_order='z_first',loss_rate=loss,after_CZ=('DEPOLARIZE2',depo))
    dem_build=DEM_builder(lattice)
    path_dem='data/dem/naive_dem_teleportation_LDU/DEM_surface_code_({},{},{})_loss_rate={}.dem'.format(lattice.width,lattice.height,lattice.rounds,lattice.loss_rate)
    
    error_rate=dem_build.naive_logical_errors(num_shots,path_dem)
    
    if os.path.exists('data/logical_error/naive_logical_error_teleportation_LDU_d=({},{})_rounds={}_depo_noise={}.pkl'.format(L,L,L,depo)):
        with open('data/logical_error/naive_logical_error_teleportation_LDU_d=({},{})_rounds={}_depo_noise={}.pkl'.format(L,L,L,depo), 'rb') as fp:
            data_saved=pickle.load(fp)
        
    else:
        data_saved={}
    if loss not in data_saved.keys():#CREATE DICTIONNARY if the loss probability has never been computed
        data_saved[loss]={}
        data_saved[loss]['num_shots']=num_shots
        data_saved[loss]['error_rate']=error_rate
    else:#UPDATE DICTIONNARY if there has been already simulation for that given loss and noise probability
        data_saved[loss]['error_rate']*=data_saved[loss]['num_shots']/(data_saved[loss]['num_shots']+num_shots)
        data_saved[loss]['error_rate']+=error_rate*num_shots/(data_saved[loss]['num_shots']+num_shots)
        data_saved[loss]['num_shots']+=num_shots
    
    #stored in a file for a given loss and various noise probabilities
    with open('data/logical_error/naive_logical_error_teleportation_LDU_d=({},{})_rounds={}_depo_noise={}.pkl'.format(L,L,L,depo), 'wb') as fp:
        pickle.dump(data_saved, fp)

    print('logical error rate for (L={},loss_rate={},depo={}) = {}'.format(L,loss,depo,error_rate))
    

