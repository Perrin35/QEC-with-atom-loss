# %%
import stim
from dem_builder_teleportation_LDU import DEM_builder
import os
import numpy as np
import scipy
from surface_code_teleportation_LDU import Rotated_Surface_Code_teleportation_LDU
import pymatching
import pickle
import multiprocessing
from multiprocessing import Pool

# %%
#function for simulation

#Compute the logical error rate of the surface code supplemented with the teleportation LDU for a given noise and loss probability
#stored as a dictionnary in a file for a fixed loss probability and various depolarizing noise probabilities
def simulation_code_fixed_loss(L,loss,depo,num_shots):
    loss=round(loss,5)
    depo=round(depo,5)
    lattice = Rotated_Surface_Code_teleportation_LDU(L,L,L,'|0>','Z',measurement_order='z_first',loss_rate=loss,after_CZ=('DEPOLARIZE2',depo))
    dem_build=DEM_builder(lattice)
    PATH='data/dem/dem_teleportation_LDU/DEM_surface_code_({},{},{})'.format(L,L,L)
    
    error_rate=dem_build.logical_errors(num_shots,PATH)

    
    if os.path.exists('data/logical_error/logical_error_teleportation_LDU_d=({},{})_rounds={}_loss_rate={}.pkl'.format(L,L,L,loss)):
        with open('data/logical_error/logical_error_teleportation_LDU_d=({},{})_rounds={}_loss_rate={}.pkl'.format(L,L,L,loss), 'rb') as fp:
            data_saved=pickle.load(fp)
        
    else:
        data_saved={}
    if depo not in data_saved.keys():#CREATE DICTIONNARY if the noise probability has never been computed
        data_saved[depo]={}
        data_saved[depo]['num_shots']=num_shots
        data_saved[depo]['error_rate']=error_rate
    else: #UPDATE DICTIONNARY if there has been already simulation for that given loss and noise probability
        data_saved[depo]['error_rate']*=data_saved[depo]['num_shots']/(data_saved[depo]['num_shots']+num_shots)
        data_saved[depo]['error_rate']+=error_rate*num_shots/(data_saved[depo]['num_shots']+num_shots)
        data_saved[depo]['num_shots']+=num_shots

    #stored in a file for a given loss and various noise probabilities
    with open('data/logical_error/logical_error_teleportation_LDU_d=({},{})_rounds={}_loss_rate={}.pkl'.format(L,L,L,loss), 'wb') as fp:
        pickle.dump(data_saved, fp)

    print('logical error rate for (L={},loss_rate={},depo={}) = {}'.format(L,loss,depo,error_rate))
    

#wrapper to one argument (needed for parallelization)
def multi_args_wrapper_fixed_loss(args):
   simulation_code_fixed_loss(*args)

# %%
#Compute the logical error rate and store as a dictionnary in files with a fixed loss probabilities

Ls = range(3,13,2)
depo_list = np.linspace(0.001, 0.016, 16) #list of depolarizing noise probabilities
loss_list=[0.,0.001,0.002,0.003,0.005,0.007,0.01,0.015,0.02,0.025,0.027] #list of loss probabilities
num_shots = 10000 #number of shots per core
nb_core=10 #number of cores used

for loss_rate in loss_list:
    for L in Ls:
        for depo in depo_list:
            with Pool(processes=nb_core) as pool:
                pool.imap(multi_args_wrapper_fixed_loss,[(L,loss_rate,depo,num_shots) for _ in range(10)])
                pool.close()
                pool.join()
# Out:
# logical error rate for (L=3,loss_rate=0.002,depo=0.001) = 0.0017
# logical error rate for (L=3,loss_rate=0.002,depo=0.001) = 0.0019
# logical error rate for (L=3,loss_rate=0.002,depo=0.001) = 0.0019
# logical error rate for (L=3,loss_rate=0.002,depo=0.001) = 0.0017
# logical error rate for (L=3,loss_rate=0.002,depo=0.001) = 0.0016
# logical error rate for (L=3,loss_rate=0.002,depo=0.001) = 0.0013
# logical error rate for (L=3,loss_rate=0.002,depo=0.001) = 0.0014
# logical error rate for (L=3,loss_rate=0.002,depo=0.001) = 0.0017
# logical error rate for (L=3,loss_rate=0.002,depo=0.001) = 0.0015
# logical error rate for (L=3,loss_rate=0.002,depo=0.001) = 0.0016
# logical error rate for (L=3,loss_rate=0.002,depo=0.002) = 0.0037
# logical error rate for (L=3,loss_rate=0.002,depo=0.002) = 0.0037
# logical error rate for (L=3,loss_rate=0.002,depo=0.002) = 0.0037
# logical error rate for (L=3,loss_rate=0.002,depo=0.002) = 0.0034
# logical error rate for (L=3,loss_rate=0.002,depo=0.002) = 0.0042
# logical error rate for (L=3,loss_rate=0.002,depo=0.002) = 0.003
# logical error rate for (L=3,loss_rate=0.002,depo=0.002) = 0.0031
# logical error rate for (L=3,loss_rate=0.002,depo=0.002) = 0.0028
# logical error rate for (L=3,loss_rate=0.002,depo=0.002) = 0.0027
# logical error rate for (L=3,loss_rate=0.002,depo=0.002) = 0.0029
# logical error rate for (L=3,loss_rate=0.002,depo=0.003) = 0.0058
# logical error rate for (L=3,loss_rate=0.002,depo=0.003) = 0.0066
# logical error rate for (L=3,loss_rate=0.002,depo=0.003) = 0.0058
# logical error rate for (L=3,loss_rate=0.002,depo=0.003) = 0.006
# logical error rate for (L=3,loss_rate=0.002,depo=0.003) = 0.0062
# logical error rate for (L=3,loss_rate=0.002,depo=0.003) = 0.0059
# logical error rate for (L=3,loss_rate=0.002,depo=0.003) = 0.0047
# logical error rate for (L=3,loss_rate=0.002,depo=0.003) = 0.0064
# logical error rate for (L=3,loss_rate=0.002,depo=0.003) = 0.0067
# logical error rate for (L=3,loss_rate=0.002,depo=0.003) = 0.0072
# logical error rate for (L=3,loss_rate=0.002,depo=0.004) = 0.0093
# logical error rate for (L=3,loss_rate=0.002,depo=0.004) = 0.0095
# logical error rate for (L=3,loss_rate=0.002,depo=0.004) = 0.0101
# logical error rate for (L=3,loss_rate=0.002,depo=0.004) = 0.0091
# logical error rate for (L=3,loss_rate=0.002,depo=0.004) = 0.0093
# logical error rate for (L=3,loss_rate=0.002,depo=0.004) = 0.009
# logical error rate for (L=3,loss_rate=0.002,depo=0.004) = 0.0107
# logical error rate for (L=3,loss_rate=0.002,depo=0.004) = 0.0104
# logical error rate for (L=3,loss_rate=0.002,depo=0.004) = 0.01
# logical error rate for (L=3,loss_rate=0.002,depo=0.004) = 0.01
# logical error rate for (L=3,loss_rate=0.002,depo=0.005) = 0.0131
# logical error rate for (L=3,loss_rate=0.002,depo=0.005) = 0.0121
# logical error rate for (L=3,loss_rate=0.002,depo=0.005) = 0.0147
# logical error rate for (L=3,loss_rate=0.002,depo=0.005) = 0.0111
# logical error rate for (L=3,loss_rate=0.002,depo=0.005) = 0.0125
# logical error rate for (L=3,loss_rate=0.002,depo=0.005) = 0.0124
# logical error rate for (L=3,loss_rate=0.002,depo=0.005) = 0.0115
# logical error rate for (L=3,loss_rate=0.002,depo=0.005) = 0.0124
# logical error rate for (L=3,loss_rate=0.002,depo=0.005) = 0.0122
# logical error rate for (L=3,loss_rate=0.002,depo=0.005) = 0.0127
# logical error rate for (L=3,loss_rate=0.002,depo=0.006) = 0.0141
# logical error rate for (L=3,loss_rate=0.002,depo=0.006) = 0.0162
# logical error rate for (L=3,loss_rate=0.002,depo=0.006) = 0.0165
# logical error rate for (L=3,loss_rate=0.002,depo=0.006) = 0.0174
# logical error rate for (L=3,loss_rate=0.002,depo=0.006) = 0.0182
# logical error rate for (L=3,loss_rate=0.002,depo=0.006) = 0.0153
# logical error rate for (L=3,loss_rate=0.002,depo=0.006) = 0.0152
# logical error rate for (L=3,loss_rate=0.002,depo=0.006) = 0.0202
# logical error rate for (L=3,loss_rate=0.002,depo=0.006) = 0.0167
# logical error rate for (L=3,loss_rate=0.002,depo=0.006) = 0.0171
# logical error rate for (L=3,loss_rate=0.002,depo=0.007) = 0.0232
# logical error rate for (L=3,loss_rate=0.002,depo=0.007) = 0.0211
# logical error rate for (L=3,loss_rate=0.002,depo=0.007) = 0.022
# logical error rate for (L=3,loss_rate=0.002,depo=0.007) = 0.0215
# logical error rate for (L=3,loss_rate=0.002,depo=0.007) = 0.0243
# logical error rate for (L=3,loss_rate=0.002,depo=0.007) = 0.0219
# logical error rate for (L=3,loss_rate=0.002,depo=0.007) = 0.019
# logical error rate for (L=3,loss_rate=0.002,depo=0.007) = 0.0215
# logical error rate for (L=3,loss_rate=0.002,depo=0.007) = 0.0214
# logical error rate for (L=3,loss_rate=0.002,depo=0.007) = 0.0202
# logical error rate for (L=3,loss_rate=0.002,depo=0.008) = 0.0235
# logical error rate for (L=3,loss_rate=0.002,depo=0.008) = 0.0277
# logical error rate for (L=3,loss_rate=0.002,depo=0.008) = 0.0259
# logical error rate for (L=3,loss_rate=0.002,depo=0.008) = 0.0229
# logical error rate for (L=3,loss_rate=0.002,depo=0.008) = 0.0289
# logical error rate for (L=3,loss_rate=0.002,depo=0.008) = 0.0259
# logical error rate for (L=3,loss_rate=0.002,depo=0.008) = 0.0242
# logical error rate for (L=3,loss_rate=0.002,depo=0.008) = 0.0247
# logical error rate for (L=3,loss_rate=0.002,depo=0.008) = 0.0261
# logical error rate for (L=3,loss_rate=0.002,depo=0.008) = 0.0257
# logical error rate for (L=3,loss_rate=0.002,depo=0.009) = 0.0337
# logical error rate for (L=3,loss_rate=0.002,depo=0.009) = 0.0301
# logical error rate for (L=3,loss_rate=0.002,depo=0.009) = 0.0306
# logical error rate for (L=3,loss_rate=0.002,depo=0.009) = 0.0314
# logical error rate for (L=3,loss_rate=0.002,depo=0.009) = 0.0311
# logical error rate for (L=3,loss_rate=0.002,depo=0.009) = 0.0331
# logical error rate for (L=3,loss_rate=0.002,depo=0.009) = 0.0327
# logical error rate for (L=3,loss_rate=0.002,depo=0.009) = 0.0303
# logical error rate for (L=3,loss_rate=0.002,depo=0.009) = 0.0326
# logical error rate for (L=3,loss_rate=0.002,depo=0.009) = 0.0303
# logical error rate for (L=3,loss_rate=0.002,depo=0.01) = 0.0343
# logical error rate for (L=3,loss_rate=0.002,depo=0.01) = 0.0353
# logical error rate for (L=3,loss_rate=0.002,depo=0.01) = 0.0334
# logical error rate for (L=3,loss_rate=0.002,depo=0.01) = 0.0388
# logical error rate for (L=3,loss_rate=0.002,depo=0.01) = 0.0344
# logical error rate for (L=3,loss_rate=0.002,depo=0.01) = 0.0371
# logical error rate for (L=3,loss_rate=0.002,depo=0.01) = 0.0402
# logical error rate for (L=3,loss_rate=0.002,depo=0.01) = 0.0356
# logical error rate for (L=3,loss_rate=0.002,depo=0.01) = 0.0379
# logical error rate for (L=3,loss_rate=0.002,depo=0.01) = 0.0365
# logical error rate for (L=3,loss_rate=0.002,depo=0.011) = 0.0423
# logical error rate for (L=3,loss_rate=0.002,depo=0.011) = 0.0401
# logical error rate for (L=3,loss_rate=0.002,depo=0.011) = 0.0416
# logical error rate for (L=3,loss_rate=0.002,depo=0.011) = 0.0421
# logical error rate for (L=3,loss_rate=0.002,depo=0.011) = 0.0441
# logical error rate for (L=3,loss_rate=0.002,depo=0.011) = 0.0413
# logical error rate for (L=3,loss_rate=0.002,depo=0.011) = 0.0449
# logical error rate for (L=3,loss_rate=0.002,depo=0.011) = 0.0447
# logical error rate for (L=3,loss_rate=0.002,depo=0.011) = 0.043
# logical error rate for (L=3,loss_rate=0.002,depo=0.011) = 0.0418
# logical error rate for (L=3,loss_rate=0.002,depo=0.012) = 0.0502
# logical error rate for (L=3,loss_rate=0.002,depo=0.012) = 0.0512
# logical error rate for (L=3,loss_rate=0.002,depo=0.012) = 0.0538
# logical error rate for (L=3,loss_rate=0.002,depo=0.012) = 0.05
# logical error rate for (L=3,loss_rate=0.002,depo=0.012) = 0.0473
# logical error rate for (L=3,loss_rate=0.002,depo=0.012) = 0.0455
# logical error rate for (L=3,loss_rate=0.002,depo=0.012) = 0.0479
# logical error rate for (L=3,loss_rate=0.002,depo=0.012) = 0.0508
# logical error rate for (L=3,loss_rate=0.002,depo=0.012) = 0.0496
# logical error rate for (L=3,loss_rate=0.002,depo=0.012) = 0.049
# logical error rate for (L=3,loss_rate=0.002,depo=0.013) = 0.0561
# logical error rate for (L=3,loss_rate=0.002,depo=0.013) = 0.0578
# logical error rate for (L=3,loss_rate=0.002,depo=0.013) = 0.0524
# logical error rate for (L=3,loss_rate=0.002,depo=0.013) = 0.055
# logical error rate for (L=3,loss_rate=0.002,depo=0.013) = 0.0589
# logical error rate for (L=3,loss_rate=0.002,depo=0.013) = 0.0554
# logical error rate for (L=3,loss_rate=0.002,depo=0.013) = 0.0555
# logical error rate for (L=3,loss_rate=0.002,depo=0.013) = 0.0487
# logical error rate for (L=3,loss_rate=0.002,depo=0.013) = 0.053
# logical error rate for (L=3,loss_rate=0.002,depo=0.013) = 0.0577
# logical error rate for (L=3,loss_rate=0.002,depo=0.014) = 0.0601
# logical error rate for (L=3,loss_rate=0.002,depo=0.014) = 0.0634
# logical error rate for (L=3,loss_rate=0.002,depo=0.014) = 0.062
# logical error rate for (L=3,loss_rate=0.002,depo=0.014) = 0.0601
# logical error rate for (L=3,loss_rate=0.002,depo=0.014) = 0.0616
# logical error rate for (L=3,loss_rate=0.002,depo=0.014) = 0.0615
# logical error rate for (L=3,loss_rate=0.002,depo=0.014) = 0.0635
# logical error rate for (L=3,loss_rate=0.002,depo=0.014) = 0.0634
# logical error rate for (L=3,loss_rate=0.002,depo=0.014) = 0.0618
# logical error rate for (L=3,loss_rate=0.002,depo=0.014) = 0.0622
# logical error rate for (L=3,loss_rate=0.002,depo=0.015) = 0.0679
# logical error rate for (L=3,loss_rate=0.002,depo=0.015) = 0.0678
# logical error rate for (L=3,loss_rate=0.002,depo=0.015) = 0.0639
# logical error rate for (L=3,loss_rate=0.002,depo=0.015) = 0.065
# logical error rate for (L=3,loss_rate=0.002,depo=0.015) = 0.0663
# logical error rate for (L=3,loss_rate=0.002,depo=0.015) = 0.0677
# logical error rate for (L=3,loss_rate=0.002,depo=0.015) = 0.0695
# logical error rate for (L=3,loss_rate=0.002,depo=0.015) = 0.0683
# logical error rate for (L=3,loss_rate=0.002,depo=0.015) = 0.0704
# logical error rate for (L=3,loss_rate=0.002,depo=0.015) = 0.0694
# logical error rate for (L=5,loss_rate=0.002,depo=0.001) = 0.0005
# logical error rate for (L=5,loss_rate=0.002,depo=0.001) = 0.0002
# logical error rate for (L=5,loss_rate=0.002,depo=0.001) = 0.0003
# logical error rate for (L=5,loss_rate=0.002,depo=0.001) = 0.0007
# logical error rate for (L=5,loss_rate=0.002,depo=0.001) = 0.0004
# logical error rate for (L=5,loss_rate=0.002,depo=0.001) = 0.0006
# logical error rate for (L=5,loss_rate=0.002,depo=0.001) = 0.0003
# logical error rate for (L=5,loss_rate=0.002,depo=0.001) = 0.0005
# logical error rate for (L=5,loss_rate=0.002,depo=0.001) = 0.0003
# logical error rate for (L=5,loss_rate=0.002,depo=0.001) = 0.0006
# logical error rate for (L=5,loss_rate=0.002,depo=0.002) = 0.0019
# logical error rate for (L=5,loss_rate=0.002,depo=0.002) = 0.0025
# logical error rate for (L=5,loss_rate=0.002,depo=0.002) = 0.002
# logical error rate for (L=5,loss_rate=0.002,depo=0.002) = 0.0017
# logical error rate for (L=5,loss_rate=0.002,depo=0.002) = 0.0025
# logical error rate for (L=5,loss_rate=0.002,depo=0.002) = 0.0016
# logical error rate for (L=5,loss_rate=0.002,depo=0.002) = 0.0014
# logical error rate for (L=5,loss_rate=0.002,depo=0.002) = 0.001
# logical error rate for (L=5,loss_rate=0.002,depo=0.002) = 0.0022
# logical error rate for (L=5,loss_rate=0.002,depo=0.002) = 0.0013
# logical error rate for (L=5,loss_rate=0.002,depo=0.003) = 0.0039
# logical error rate for (L=5,loss_rate=0.002,depo=0.003) = 0.0038
# logical error rate for (L=5,loss_rate=0.002,depo=0.003) = 0.0045
# logical error rate for (L=5,loss_rate=0.002,depo=0.003) = 0.0035
# logical error rate for (L=5,loss_rate=0.002,depo=0.003) = 0.0035
# logical error rate for (L=5,loss_rate=0.002,depo=0.003) = 0.0038
# logical error rate for (L=5,loss_rate=0.002,depo=0.003) = 0.0043
# logical error rate for (L=5,loss_rate=0.002,depo=0.003) = 0.0034
# logical error rate for (L=5,loss_rate=0.002,depo=0.003) = 0.0039
# logical error rate for (L=5,loss_rate=0.002,depo=0.003) = 0.003
# logical error rate for (L=5,loss_rate=0.002,depo=0.004) = 0.0056
# logical error rate for (L=5,loss_rate=0.002,depo=0.004) = 0.0078
# logical error rate for (L=5,loss_rate=0.002,depo=0.004) = 0.0091
# logical error rate for (L=5,loss_rate=0.002,depo=0.004) = 0.0072
# logical error rate for (L=5,loss_rate=0.002,depo=0.004) = 0.006
# logical error rate for (L=5,loss_rate=0.002,depo=0.004) = 0.0079
# logical error rate for (L=5,loss_rate=0.002,depo=0.004) = 0.0075
# logical error rate for (L=5,loss_rate=0.002,depo=0.004) = 0.0062
# logical error rate for (L=5,loss_rate=0.002,depo=0.004) = 0.0067
# logical error rate for (L=5,loss_rate=0.002,depo=0.004) = 0.0077
# logical error rate for (L=5,loss_rate=0.002,depo=0.005) = 0.0114
# logical error rate for (L=5,loss_rate=0.002,depo=0.005) = 0.0112
# logical error rate for (L=5,loss_rate=0.002,depo=0.005) = 0.0116
# logical error rate for (L=5,loss_rate=0.002,depo=0.005) = 0.0127
# logical error rate for (L=5,loss_rate=0.002,depo=0.005) = 0.0134
# logical error rate for (L=5,loss_rate=0.002,depo=0.005) = 0.0118
# logical error rate for (L=5,loss_rate=0.002,depo=0.005) = 0.0119
# logical error rate for (L=5,loss_rate=0.002,depo=0.005) = 0.0129
# logical error rate for (L=5,loss_rate=0.002,depo=0.005) = 0.0118
# logical error rate for (L=5,loss_rate=0.002,depo=0.005) = 0.0118
# logical error rate for (L=5,loss_rate=0.002,depo=0.006) = 0.0169
# logical error rate for (L=5,loss_rate=0.002,depo=0.006) = 0.0202
# logical error rate for (L=5,loss_rate=0.002,depo=0.006) = 0.0176
# logical error rate for (L=5,loss_rate=0.002,depo=0.006) = 0.0174
# logical error rate for (L=5,loss_rate=0.002,depo=0.006) = 0.0187
# logical error rate for (L=5,loss_rate=0.002,depo=0.006) = 0.0179
# logical error rate for (L=5,loss_rate=0.002,depo=0.006) = 0.0188
# logical error rate for (L=5,loss_rate=0.002,depo=0.006) = 0.0188
# logical error rate for (L=5,loss_rate=0.002,depo=0.006) = 0.017
# logical error rate for (L=5,loss_rate=0.002,depo=0.006) = 0.0172
# logical error rate for (L=5,loss_rate=0.002,depo=0.007) = 0.0274
# logical error rate for (L=5,loss_rate=0.002,depo=0.007) = 0.0244
# logical error rate for (L=5,loss_rate=0.002,depo=0.007) = 0.0269
# logical error rate for (L=5,loss_rate=0.002,depo=0.007) = 0.027
# logical error rate for (L=5,loss_rate=0.002,depo=0.007) = 0.0266
# logical error rate for (L=5,loss_rate=0.002,depo=0.007) = 0.0263
# logical error rate for (L=5,loss_rate=0.002,depo=0.007) = 0.0276
# logical error rate for (L=5,loss_rate=0.002,depo=0.007) = 0.026
# logical error rate for (L=5,loss_rate=0.002,depo=0.007) = 0.0265
# logical error rate for (L=5,loss_rate=0.002,depo=0.007) = 0.0271
# logical error rate for (L=5,loss_rate=0.002,depo=0.008) = 0.0365
# logical error rate for (L=5,loss_rate=0.002,depo=0.008) = 0.0334
# logical error rate for (L=5,loss_rate=0.002,depo=0.008) = 0.0382
# logical error rate for (L=5,loss_rate=0.002,depo=0.008) = 0.0341
# logical error rate for (L=5,loss_rate=0.002,depo=0.008) = 0.0349
# logical error rate for (L=5,loss_rate=0.002,depo=0.008) = 0.0382
# logical error rate for (L=5,loss_rate=0.002,depo=0.008) = 0.0375
# logical error rate for (L=5,loss_rate=0.002,depo=0.008) = 0.0334
# logical error rate for (L=5,loss_rate=0.002,depo=0.008) = 0.036
# logical error rate for (L=5,loss_rate=0.002,depo=0.008) = 0.0333
# logical error rate for (L=5,loss_rate=0.002,depo=0.009) = 0.0473
# logical error rate for (L=5,loss_rate=0.002,depo=0.009) = 0.0442
# logical error rate for (L=5,loss_rate=0.002,depo=0.009) = 0.0457
# logical error rate for (L=5,loss_rate=0.002,depo=0.009) = 0.0466
# logical error rate for (L=5,loss_rate=0.002,depo=0.009) = 0.0469
# logical error rate for (L=5,loss_rate=0.002,depo=0.009) = 0.045
# logical error rate for (L=5,loss_rate=0.002,depo=0.009) = 0.041
# logical error rate for (L=5,loss_rate=0.002,depo=0.009) = 0.0462
# logical error rate for (L=5,loss_rate=0.002,depo=0.009) = 0.0434
# logical error rate for (L=5,loss_rate=0.002,depo=0.009) = 0.0461
# logical error rate for (L=5,loss_rate=0.002,depo=0.01) = 0.0594
# logical error rate for (L=5,loss_rate=0.002,depo=0.01) = 0.0618
# logical error rate for (L=5,loss_rate=0.002,depo=0.01) = 0.0573
# logical error rate for (L=5,loss_rate=0.002,depo=0.01) = 0.0596
# logical error rate for (L=5,loss_rate=0.002,depo=0.01) = 0.059
# logical error rate for (L=5,loss_rate=0.002,depo=0.01) = 0.0555
# logical error rate for (L=5,loss_rate=0.002,depo=0.01) = 0.0557
# logical error rate for (L=5,loss_rate=0.002,depo=0.01) = 0.0552
# logical error rate for (L=5,loss_rate=0.002,depo=0.01) = 0.0563
# logical error rate for (L=5,loss_rate=0.002,depo=0.01) = 0.0558
# logical error rate for (L=5,loss_rate=0.002,depo=0.011) = 0.0696
# logical error rate for (L=5,loss_rate=0.002,depo=0.011) = 0.0756
# logical error rate for (L=5,loss_rate=0.002,depo=0.011) = 0.0648
# logical error rate for (L=5,loss_rate=0.002,depo=0.011) = 0.071
# logical error rate for (L=5,loss_rate=0.002,depo=0.011) = 0.0713
# logical error rate for (L=5,loss_rate=0.002,depo=0.011) = 0.0655
# logical error rate for (L=5,loss_rate=0.002,depo=0.011) = 0.0697
# logical error rate for (L=5,loss_rate=0.002,depo=0.011) = 0.0697
# logical error rate for (L=5,loss_rate=0.002,depo=0.011) = 0.0736
# logical error rate for (L=5,loss_rate=0.002,depo=0.011) = 0.0633
# logical error rate for (L=5,loss_rate=0.002,depo=0.012) = 0.0867
# logical error rate for (L=5,loss_rate=0.002,depo=0.012) = 0.0875
# logical error rate for (L=5,loss_rate=0.002,depo=0.012) = 0.0826
# logical error rate for (L=5,loss_rate=0.002,depo=0.012) = 0.086
# logical error rate for (L=5,loss_rate=0.002,depo=0.012) = 0.0828
# logical error rate for (L=5,loss_rate=0.002,depo=0.012) = 0.0899
# logical error rate for (L=5,loss_rate=0.002,depo=0.012) = 0.084
# logical error rate for (L=5,loss_rate=0.002,depo=0.012) = 0.0826
# logical error rate for (L=5,loss_rate=0.002,depo=0.012) = 0.0872
# logical error rate for (L=5,loss_rate=0.002,depo=0.012) = 0.0856
# logical error rate for (L=5,loss_rate=0.002,depo=0.013) = 0.0968
# logical error rate for (L=5,loss_rate=0.002,depo=0.013) = 0.0978
# logical error rate for (L=5,loss_rate=0.002,depo=0.013) = 0.0998
# logical error rate for (L=5,loss_rate=0.002,depo=0.013) = 0.1028
# logical error rate for (L=5,loss_rate=0.002,depo=0.013) = 0.1043
# logical error rate for (L=5,loss_rate=0.002,depo=0.013) = 0.1009
# logical error rate for (L=5,loss_rate=0.002,depo=0.013) = 0.0972
# logical error rate for (L=5,loss_rate=0.002,depo=0.013) = 0.094
# logical error rate for (L=5,loss_rate=0.002,depo=0.013) = 0.0986
# logical error rate for (L=5,loss_rate=0.002,depo=0.013) = 0.0986
# logical error rate for (L=5,loss_rate=0.002,depo=0.014) = 0.1133
# logical error rate for (L=5,loss_rate=0.002,depo=0.014) = 0.1115
# logical error rate for (L=5,loss_rate=0.002,depo=0.014) = 0.1222
# logical error rate for (L=5,loss_rate=0.002,depo=0.014) = 0.1128
# logical error rate for (L=5,loss_rate=0.002,depo=0.014) = 0.1199
# logical error rate for (L=5,loss_rate=0.002,depo=0.014) = 0.1141
# logical error rate for (L=5,loss_rate=0.002,depo=0.014) = 0.1148
# logical error rate for (L=5,loss_rate=0.002,depo=0.014) = 0.117
# logical error rate for (L=5,loss_rate=0.002,depo=0.014) = 0.1205
# logical error rate for (L=5,loss_rate=0.002,depo=0.014) = 0.1184
# logical error rate for (L=5,loss_rate=0.002,depo=0.015) = 0.1317
# logical error rate for (L=5,loss_rate=0.002,depo=0.015) = 0.1292
# logical error rate for (L=5,loss_rate=0.002,depo=0.015) = 0.1329
# logical error rate for (L=5,loss_rate=0.002,depo=0.015) = 0.1244
# logical error rate for (L=5,loss_rate=0.002,depo=0.015) = 0.1318
# logical error rate for (L=5,loss_rate=0.002,depo=0.015) = 0.1371
# logical error rate for (L=5,loss_rate=0.002,depo=0.015) = 0.1263
# logical error rate for (L=5,loss_rate=0.002,depo=0.015) = 0.1311
# logical error rate for (L=5,loss_rate=0.002,depo=0.015) = 0.1381
# logical error rate for (L=5,loss_rate=0.002,depo=0.015) = 0.1305
# logical error rate for (L=7,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.002,depo=0.001) = 0.0001
# logical error rate for (L=7,loss_rate=0.002,depo=0.001) = 0.0001
# logical error rate for (L=7,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.002,depo=0.001) = 0.0001
# logical error rate for (L=7,loss_rate=0.002,depo=0.001) = 0.0002
# logical error rate for (L=7,loss_rate=0.002,depo=0.001) = 0.0002
# logical error rate for (L=7,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.002,depo=0.001) = 0.0001
# logical error rate for (L=7,loss_rate=0.002,depo=0.002) = 0.0
# logical error rate for (L=7,loss_rate=0.002,depo=0.002) = 0.0003
# logical error rate for (L=7,loss_rate=0.002,depo=0.002) = 0.0003
# logical error rate for (L=7,loss_rate=0.002,depo=0.002) = 0.0006
# logical error rate for (L=7,loss_rate=0.002,depo=0.002) = 0.0007
# logical error rate for (L=7,loss_rate=0.002,depo=0.002) = 0.0009
# logical error rate for (L=7,loss_rate=0.002,depo=0.002) = 0.0007
# logical error rate for (L=7,loss_rate=0.002,depo=0.002) = 0.0
# logical error rate for (L=7,loss_rate=0.002,depo=0.002) = 0.0002
# logical error rate for (L=7,loss_rate=0.002,depo=0.002) = 0.0002
# logical error rate for (L=7,loss_rate=0.002,depo=0.003) = 0.002
# logical error rate for (L=7,loss_rate=0.002,depo=0.003) = 0.0019
# logical error rate for (L=7,loss_rate=0.002,depo=0.003) = 0.0025
# logical error rate for (L=7,loss_rate=0.002,depo=0.003) = 0.0017
# logical error rate for (L=7,loss_rate=0.002,depo=0.003) = 0.0017
# logical error rate for (L=7,loss_rate=0.002,depo=0.003) = 0.0015
# logical error rate for (L=7,loss_rate=0.002,depo=0.003) = 0.0024
# logical error rate for (L=7,loss_rate=0.002,depo=0.003) = 0.0016
# logical error rate for (L=7,loss_rate=0.002,depo=0.003) = 0.0017
# logical error rate for (L=7,loss_rate=0.002,depo=0.003) = 0.0011
# logical error rate for (L=7,loss_rate=0.002,depo=0.004) = 0.0049
# logical error rate for (L=7,loss_rate=0.002,depo=0.004) = 0.0045
# logical error rate for (L=7,loss_rate=0.002,depo=0.004) = 0.0046
# logical error rate for (L=7,loss_rate=0.002,depo=0.004) = 0.0043
# logical error rate for (L=7,loss_rate=0.002,depo=0.004) = 0.0045
# logical error rate for (L=7,loss_rate=0.002,depo=0.004) = 0.0049
# logical error rate for (L=7,loss_rate=0.002,depo=0.004) = 0.0031
# logical error rate for (L=7,loss_rate=0.002,depo=0.004) = 0.0046
# logical error rate for (L=7,loss_rate=0.002,depo=0.004) = 0.0037
# logical error rate for (L=7,loss_rate=0.002,depo=0.004) = 0.003
# logical error rate for (L=7,loss_rate=0.002,depo=0.005) = 0.0091
# logical error rate for (L=7,loss_rate=0.002,depo=0.005) = 0.0079
# logical error rate for (L=7,loss_rate=0.002,depo=0.005) = 0.0105
# logical error rate for (L=7,loss_rate=0.002,depo=0.005) = 0.0067
# logical error rate for (L=7,loss_rate=0.002,depo=0.005) = 0.0074
# logical error rate for (L=7,loss_rate=0.002,depo=0.005) = 0.0081
# logical error rate for (L=7,loss_rate=0.002,depo=0.005) = 0.0079
# logical error rate for (L=7,loss_rate=0.002,depo=0.005) = 0.0087
# logical error rate for (L=7,loss_rate=0.002,depo=0.005) = 0.0086
# logical error rate for (L=7,loss_rate=0.002,depo=0.005) = 0.0086
# logical error rate for (L=7,loss_rate=0.002,depo=0.006) = 0.0162
# logical error rate for (L=7,loss_rate=0.002,depo=0.006) = 0.014
# logical error rate for (L=7,loss_rate=0.002,depo=0.006) = 0.0152
# logical error rate for (L=7,loss_rate=0.002,depo=0.006) = 0.0163
# logical error rate for (L=7,loss_rate=0.002,depo=0.006) = 0.0166
# logical error rate for (L=7,loss_rate=0.002,depo=0.006) = 0.016
# logical error rate for (L=7,loss_rate=0.002,depo=0.006) = 0.019
# logical error rate for (L=7,loss_rate=0.002,depo=0.006) = 0.0164
# logical error rate for (L=7,loss_rate=0.002,depo=0.006) = 0.015
# logical error rate for (L=7,loss_rate=0.002,depo=0.006) = 0.0159
# logical error rate for (L=7,loss_rate=0.002,depo=0.007) = 0.0244
# logical error rate for (L=7,loss_rate=0.002,depo=0.007) = 0.0242
# logical error rate for (L=7,loss_rate=0.002,depo=0.007) = 0.0281
# logical error rate for (L=7,loss_rate=0.002,depo=0.007) = 0.0223
# logical error rate for (L=7,loss_rate=0.002,depo=0.007) = 0.0251
# logical error rate for (L=7,loss_rate=0.002,depo=0.007) = 0.0251
# logical error rate for (L=7,loss_rate=0.002,depo=0.007) = 0.0254
# logical error rate for (L=7,loss_rate=0.002,depo=0.007) = 0.0252
# logical error rate for (L=7,loss_rate=0.002,depo=0.007) = 0.0246
# logical error rate for (L=7,loss_rate=0.002,depo=0.007) = 0.0263
# logical error rate for (L=7,loss_rate=0.002,depo=0.008) = 0.0391
# logical error rate for (L=7,loss_rate=0.002,depo=0.008) = 0.0365
# logical error rate for (L=7,loss_rate=0.002,depo=0.008) = 0.0343
# logical error rate for (L=7,loss_rate=0.002,depo=0.008) = 0.0351
# logical error rate for (L=7,loss_rate=0.002,depo=0.008) = 0.0359
# logical error rate for (L=7,loss_rate=0.002,depo=0.008) = 0.0393
# logical error rate for (L=7,loss_rate=0.002,depo=0.008) = 0.0363
# logical error rate for (L=7,loss_rate=0.002,depo=0.008) = 0.0374
# logical error rate for (L=7,loss_rate=0.002,depo=0.008) = 0.0375
# logical error rate for (L=7,loss_rate=0.002,depo=0.008) = 0.0387
# logical error rate for (L=7,loss_rate=0.002,depo=0.009) = 0.0581
# logical error rate for (L=7,loss_rate=0.002,depo=0.009) = 0.0552
# logical error rate for (L=7,loss_rate=0.002,depo=0.009) = 0.0567
# logical error rate for (L=7,loss_rate=0.002,depo=0.009) = 0.0551
# logical error rate for (L=7,loss_rate=0.002,depo=0.009) = 0.0547
# logical error rate for (L=7,loss_rate=0.002,depo=0.009) = 0.0536
# logical error rate for (L=7,loss_rate=0.002,depo=0.009) = 0.0538
# logical error rate for (L=7,loss_rate=0.002,depo=0.009) = 0.0499
# logical error rate for (L=7,loss_rate=0.002,depo=0.009) = 0.0486
# logical error rate for (L=7,loss_rate=0.002,depo=0.009) = 0.0559
# logical error rate for (L=7,loss_rate=0.002,depo=0.01) = 0.0711
# logical error rate for (L=7,loss_rate=0.002,depo=0.01) = 0.0675
# logical error rate for (L=7,loss_rate=0.002,depo=0.01) = 0.0729
# logical error rate for (L=7,loss_rate=0.002,depo=0.01) = 0.0726
# logical error rate for (L=7,loss_rate=0.002,depo=0.01) = 0.07
# logical error rate for (L=7,loss_rate=0.002,depo=0.01) = 0.0773
# logical error rate for (L=7,loss_rate=0.002,depo=0.01) = 0.0735
# logical error rate for (L=7,loss_rate=0.002,depo=0.01) = 0.0718
# logical error rate for (L=7,loss_rate=0.002,depo=0.01) = 0.0786
# logical error rate for (L=7,loss_rate=0.002,depo=0.01) = 0.0716
# logical error rate for (L=7,loss_rate=0.002,depo=0.011) = 0.0932
# logical error rate for (L=7,loss_rate=0.002,depo=0.011) = 0.0889
# logical error rate for (L=7,loss_rate=0.002,depo=0.011) = 0.0899
# logical error rate for (L=7,loss_rate=0.002,depo=0.011) = 0.0963
# logical error rate for (L=7,loss_rate=0.002,depo=0.011) = 0.0926
# logical error rate for (L=7,loss_rate=0.002,depo=0.011) = 0.088
# logical error rate for (L=7,loss_rate=0.002,depo=0.011) = 0.0879
# logical error rate for (L=7,loss_rate=0.002,depo=0.011) = 0.0932
# logical error rate for (L=7,loss_rate=0.002,depo=0.011) = 0.0912
# logical error rate for (L=7,loss_rate=0.002,depo=0.011) = 0.0923
# logical error rate for (L=7,loss_rate=0.002,depo=0.012) = 0.1135
# logical error rate for (L=7,loss_rate=0.002,depo=0.012) = 0.1102
# logical error rate for (L=7,loss_rate=0.002,depo=0.012) = 0.1121
# logical error rate for (L=7,loss_rate=0.002,depo=0.012) = 0.1168
# logical error rate for (L=7,loss_rate=0.002,depo=0.012) = 0.1139
# logical error rate for (L=7,loss_rate=0.002,depo=0.012) = 0.1141
# logical error rate for (L=7,loss_rate=0.002,depo=0.012) = 0.1127
# logical error rate for (L=7,loss_rate=0.002,depo=0.012) = 0.1168
# logical error rate for (L=7,loss_rate=0.002,depo=0.012) = 0.1121
# logical error rate for (L=7,loss_rate=0.002,depo=0.013) = 0.1402
# logical error rate for (L=7,loss_rate=0.002,depo=0.013) = 0.1405
# logical error rate for (L=7,loss_rate=0.002,depo=0.013) = 0.1366
# logical error rate for (L=7,loss_rate=0.002,depo=0.013) = 0.1422
# logical error rate for (L=7,loss_rate=0.002,depo=0.013) = 0.1425
# logical error rate for (L=7,loss_rate=0.002,depo=0.013) = 0.1375
# logical error rate for (L=7,loss_rate=0.002,depo=0.013) = 0.1334
# logical error rate for (L=7,loss_rate=0.002,depo=0.013) = 0.1346
# logical error rate for (L=7,loss_rate=0.002,depo=0.013) = 0.1364
# logical error rate for (L=7,loss_rate=0.002,depo=0.013) = 0.1447
# logical error rate for (L=7,loss_rate=0.002,depo=0.014) = 0.1636
# logical error rate for (L=7,loss_rate=0.002,depo=0.014) = 0.161
# logical error rate for (L=7,loss_rate=0.002,depo=0.014) = 0.1622
# logical error rate for (L=7,loss_rate=0.002,depo=0.014) = 0.1607
# logical error rate for (L=7,loss_rate=0.002,depo=0.014) = 0.1646
# logical error rate for (L=7,loss_rate=0.002,depo=0.014) = 0.1644
# logical error rate for (L=7,loss_rate=0.002,depo=0.014) = 0.1634
# logical error rate for (L=7,loss_rate=0.002,depo=0.014) = 0.17
# logical error rate for (L=7,loss_rate=0.002,depo=0.014) = 0.1635
# logical error rate for (L=7,loss_rate=0.002,depo=0.014) = 0.163
# logical error rate for (L=7,loss_rate=0.002,depo=0.015) = 0.1953
# logical error rate for (L=7,loss_rate=0.002,depo=0.015) = 0.1909
# logical error rate for (L=7,loss_rate=0.002,depo=0.015) = 0.1894
# logical error rate for (L=7,loss_rate=0.002,depo=0.015) = 0.1871
# logical error rate for (L=7,loss_rate=0.002,depo=0.015) = 0.1909
# logical error rate for (L=7,loss_rate=0.002,depo=0.015) = 0.1898
# logical error rate for (L=7,loss_rate=0.002,depo=0.015) = 0.187
# logical error rate for (L=7,loss_rate=0.002,depo=0.015) = 0.1891
# logical error rate for (L=7,loss_rate=0.002,depo=0.015) = 0.1913
# logical error rate for (L=7,loss_rate=0.002,depo=0.015) = 0.1916
# logical error rate for (L=9,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.002,depo=0.001) = 0.0001
# logical error rate for (L=9,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.002,depo=0.002) = 0.0001
# logical error rate for (L=9,loss_rate=0.002,depo=0.002) = 0.0002
# logical error rate for (L=9,loss_rate=0.002,depo=0.002) = 0.0
# logical error rate for (L=9,loss_rate=0.002,depo=0.002) = 0.0002
# logical error rate for (L=9,loss_rate=0.002,depo=0.002) = 0.0001
# logical error rate for (L=9,loss_rate=0.002,depo=0.002) = 0.0001
# logical error rate for (L=9,loss_rate=0.002,depo=0.002) = 0.0002
# logical error rate for (L=9,loss_rate=0.002,depo=0.002) = 0.0001
# logical error rate for (L=9,loss_rate=0.002,depo=0.002) = 0.0001
# logical error rate for (L=9,loss_rate=0.002,depo=0.002) = 0.0002
# logical error rate for (L=9,loss_rate=0.002,depo=0.003) = 0.001
# logical error rate for (L=9,loss_rate=0.002,depo=0.003) = 0.0008
# logical error rate for (L=9,loss_rate=0.002,depo=0.003) = 0.0007
# logical error rate for (L=9,loss_rate=0.002,depo=0.003) = 0.0008
# logical error rate for (L=9,loss_rate=0.002,depo=0.003) = 0.0007
# logical error rate for (L=9,loss_rate=0.002,depo=0.003) = 0.001
# logical error rate for (L=9,loss_rate=0.002,depo=0.003) = 0.0007
# logical error rate for (L=9,loss_rate=0.002,depo=0.003) = 0.0005
# logical error rate for (L=9,loss_rate=0.002,depo=0.003) = 0.0007
# logical error rate for (L=9,loss_rate=0.002,depo=0.003) = 0.0006
# logical error rate for (L=9,loss_rate=0.002,depo=0.004) = 0.0023
# logical error rate for (L=9,loss_rate=0.002,depo=0.004) = 0.0022
# logical error rate for (L=9,loss_rate=0.002,depo=0.004) = 0.0021
# logical error rate for (L=9,loss_rate=0.002,depo=0.004) = 0.0033
# logical error rate for (L=9,loss_rate=0.002,depo=0.004) = 0.002
# logical error rate for (L=9,loss_rate=0.002,depo=0.004) = 0.0017
# logical error rate for (L=9,loss_rate=0.002,depo=0.004) = 0.0024
# logical error rate for (L=9,loss_rate=0.002,depo=0.004) = 0.0018
# logical error rate for (L=9,loss_rate=0.002,depo=0.004) = 0.002
# logical error rate for (L=9,loss_rate=0.002,depo=0.004) = 0.0025
# logical error rate for (L=9,loss_rate=0.002,depo=0.005) = 0.0065
# logical error rate for (L=9,loss_rate=0.002,depo=0.005) = 0.0052
# logical error rate for (L=9,loss_rate=0.002,depo=0.005) = 0.0062
# logical error rate for (L=9,loss_rate=0.002,depo=0.005) = 0.0062
# logical error rate for (L=9,loss_rate=0.002,depo=0.005) = 0.0072
# logical error rate for (L=9,loss_rate=0.002,depo=0.005) = 0.005
# logical error rate for (L=9,loss_rate=0.002,depo=0.005) = 0.0056
# logical error rate for (L=9,loss_rate=0.002,depo=0.005) = 0.0052
# logical error rate for (L=9,loss_rate=0.002,depo=0.005) = 0.0043
# logical error rate for (L=9,loss_rate=0.002,depo=0.005) = 0.0071
# logical error rate for (L=9,loss_rate=0.002,depo=0.006) = 0.012
# logical error rate for (L=9,loss_rate=0.002,depo=0.006) = 0.0125
# logical error rate for (L=9,loss_rate=0.002,depo=0.006) = 0.0137
# logical error rate for (L=9,loss_rate=0.002,depo=0.006) = 0.0109
# logical error rate for (L=9,loss_rate=0.002,depo=0.006) = 0.0127
# logical error rate for (L=9,loss_rate=0.002,depo=0.006) = 0.0127
# logical error rate for (L=9,loss_rate=0.002,depo=0.006) = 0.0146
# logical error rate for (L=9,loss_rate=0.002,depo=0.006) = 0.0119
# logical error rate for (L=9,loss_rate=0.002,depo=0.006) = 0.0127
# logical error rate for (L=9,loss_rate=0.002,depo=0.006) = 0.0131
# logical error rate for (L=9,loss_rate=0.002,depo=0.007) = 0.0211
# logical error rate for (L=9,loss_rate=0.002,depo=0.007) = 0.0215
# logical error rate for (L=9,loss_rate=0.002,depo=0.007) = 0.0233
# logical error rate for (L=9,loss_rate=0.002,depo=0.007) = 0.0212
# logical error rate for (L=9,loss_rate=0.002,depo=0.007) = 0.0238
# logical error rate for (L=9,loss_rate=0.002,depo=0.007) = 0.0229
# logical error rate for (L=9,loss_rate=0.002,depo=0.007) = 0.0224
# logical error rate for (L=9,loss_rate=0.002,depo=0.007) = 0.0224
# logical error rate for (L=9,loss_rate=0.002,depo=0.007) = 0.0228
# logical error rate for (L=9,loss_rate=0.002,depo=0.007) = 0.0206
# logical error rate for (L=9,loss_rate=0.002,depo=0.008) = 0.038
# logical error rate for (L=9,loss_rate=0.002,depo=0.008) = 0.037
# logical error rate for (L=9,loss_rate=0.002,depo=0.008) = 0.0379
# logical error rate for (L=9,loss_rate=0.002,depo=0.008) = 0.0354
# logical error rate for (L=9,loss_rate=0.002,depo=0.008) = 0.0354
# logical error rate for (L=9,loss_rate=0.002,depo=0.008) = 0.0361
# logical error rate for (L=9,loss_rate=0.002,depo=0.008) = 0.0363
# logical error rate for (L=9,loss_rate=0.002,depo=0.008) = 0.0385
# logical error rate for (L=9,loss_rate=0.002,depo=0.008) = 0.035
# logical error rate for (L=9,loss_rate=0.002,depo=0.008) = 0.0384
# logical error rate for (L=9,loss_rate=0.002,depo=0.009) = 0.0623
# logical error rate for (L=9,loss_rate=0.002,depo=0.009) = 0.0574
# logical error rate for (L=9,loss_rate=0.002,depo=0.009) = 0.0594
# logical error rate for (L=9,loss_rate=0.002,depo=0.009) = 0.0555
# logical error rate for (L=9,loss_rate=0.002,depo=0.009) = 0.0584
# logical error rate for (L=9,loss_rate=0.002,depo=0.009) = 0.0542
# logical error rate for (L=9,loss_rate=0.002,depo=0.009) = 0.0547
# logical error rate for (L=9,loss_rate=0.002,depo=0.009) = 0.0589
# logical error rate for (L=9,loss_rate=0.002,depo=0.009) = 0.0543
# logical error rate for (L=9,loss_rate=0.002,depo=0.009) = 0.0571
# logical error rate for (L=9,loss_rate=0.002,depo=0.01) = 0.081
# logical error rate for (L=9,loss_rate=0.002,depo=0.01) = 0.0779
# logical error rate for (L=9,loss_rate=0.002,depo=0.01) = 0.0807
# logical error rate for (L=9,loss_rate=0.002,depo=0.01) = 0.0866
# logical error rate for (L=9,loss_rate=0.002,depo=0.01) = 0.0837
# logical error rate for (L=9,loss_rate=0.002,depo=0.01) = 0.0788
# logical error rate for (L=9,loss_rate=0.002,depo=0.01) = 0.0828
# logical error rate for (L=9,loss_rate=0.002,depo=0.01) = 0.0765
# logical error rate for (L=9,loss_rate=0.002,depo=0.01) = 0.079
# logical error rate for (L=9,loss_rate=0.002,depo=0.01) = 0.0828
# logical error rate for (L=9,loss_rate=0.002,depo=0.011) = 0.1068
# logical error rate for (L=9,loss_rate=0.002,depo=0.011) = 0.1112
# logical error rate for (L=9,loss_rate=0.002,depo=0.011) = 0.1086
# logical error rate for (L=9,loss_rate=0.002,depo=0.011) = 0.1055
# logical error rate for (L=9,loss_rate=0.002,depo=0.011) = 0.112
# logical error rate for (L=9,loss_rate=0.002,depo=0.011) = 0.1105
# logical error rate for (L=9,loss_rate=0.002,depo=0.011) = 0.1109
# logical error rate for (L=9,loss_rate=0.002,depo=0.011) = 0.1078
# logical error rate for (L=9,loss_rate=0.002,depo=0.011) = 0.1119
# logical error rate for (L=9,loss_rate=0.002,depo=0.011) = 0.1072
# logical error rate for (L=9,loss_rate=0.002,depo=0.012) = 0.142
# logical error rate for (L=9,loss_rate=0.002,depo=0.012) = 0.1364
# logical error rate for (L=9,loss_rate=0.002,depo=0.012) = 0.1406
# logical error rate for (L=9,loss_rate=0.002,depo=0.012) = 0.1387
# logical error rate for (L=9,loss_rate=0.002,depo=0.012) = 0.1458
# logical error rate for (L=9,loss_rate=0.002,depo=0.012) = 0.1443
# logical error rate for (L=9,loss_rate=0.002,depo=0.012) = 0.1401
# logical error rate for (L=9,loss_rate=0.002,depo=0.012) = 0.1387
# logical error rate for (L=9,loss_rate=0.002,depo=0.012) = 0.1416
# logical error rate for (L=9,loss_rate=0.002,depo=0.012) = 0.1411
# logical error rate for (L=9,loss_rate=0.002,depo=0.013) = 0.1795
# logical error rate for (L=9,loss_rate=0.002,depo=0.013) = 0.182
# logical error rate for (L=9,loss_rate=0.002,depo=0.013) = 0.1774
# logical error rate for (L=9,loss_rate=0.002,depo=0.013) = 0.1776
# logical error rate for (L=9,loss_rate=0.002,depo=0.013) = 0.1651
# logical error rate for (L=9,loss_rate=0.002,depo=0.013) = 0.1792
# logical error rate for (L=9,loss_rate=0.002,depo=0.013) = 0.1771
# logical error rate for (L=9,loss_rate=0.002,depo=0.013) = 0.1754
# logical error rate for (L=9,loss_rate=0.002,depo=0.013) = 0.1772
# logical error rate for (L=9,loss_rate=0.002,depo=0.013) = 0.1782
# logical error rate for (L=9,loss_rate=0.002,depo=0.014) = 0.2165
# logical error rate for (L=9,loss_rate=0.002,depo=0.014) = 0.2053
# logical error rate for (L=9,loss_rate=0.002,depo=0.014) = 0.2141
# logical error rate for (L=9,loss_rate=0.002,depo=0.014) = 0.2151
# logical error rate for (L=9,loss_rate=0.002,depo=0.014) = 0.204
# logical error rate for (L=9,loss_rate=0.002,depo=0.014) = 0.212
# logical error rate for (L=9,loss_rate=0.002,depo=0.014) = 0.216
# logical error rate for (L=9,loss_rate=0.002,depo=0.014) = 0.2086
# logical error rate for (L=9,loss_rate=0.002,depo=0.014) = 0.218
# logical error rate for (L=9,loss_rate=0.002,depo=0.014) = 0.2115
# logical error rate for (L=9,loss_rate=0.002,depo=0.015) = 0.2435
# logical error rate for (L=9,loss_rate=0.002,depo=0.015) = 0.2474
# logical error rate for (L=9,loss_rate=0.002,depo=0.015) = 0.2472
# logical error rate for (L=9,loss_rate=0.002,depo=0.015) = 0.2446
# logical error rate for (L=9,loss_rate=0.002,depo=0.015) = 0.2451
# logical error rate for (L=9,loss_rate=0.002,depo=0.015) = 0.2493
# logical error rate for (L=9,loss_rate=0.002,depo=0.015) = 0.2512
# logical error rate for (L=9,loss_rate=0.002,depo=0.015) = 0.2509
# logical error rate for (L=9,loss_rate=0.002,depo=0.015) = 0.2553
# logical error rate for (L=9,loss_rate=0.002,depo=0.015) = 0.246
# logical error rate for (L=11,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.002) = 0.0002
# logical error rate for (L=11,loss_rate=0.002,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.002) = 0.0001
# logical error rate for (L=11,loss_rate=0.002,depo=0.002) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.002) = 0.0001
# logical error rate for (L=11,loss_rate=0.002,depo=0.002) = 0.0003
# logical error rate for (L=11,loss_rate=0.002,depo=0.003) = 0.0003
# logical error rate for (L=11,loss_rate=0.002,depo=0.003) = 0.0004
# logical error rate for (L=11,loss_rate=0.002,depo=0.003) = 0.0004
# logical error rate for (L=11,loss_rate=0.002,depo=0.003) = 0.0004
# logical error rate for (L=11,loss_rate=0.002,depo=0.003) = 0.0003
# logical error rate for (L=11,loss_rate=0.002,depo=0.003) = 0.0002
# logical error rate for (L=11,loss_rate=0.002,depo=0.003) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.003) = 0.0002
# logical error rate for (L=11,loss_rate=0.002,depo=0.003) = 0.0001
# logical error rate for (L=11,loss_rate=0.002,depo=0.003) = 0.0002
# logical error rate for (L=11,loss_rate=0.002,depo=0.004) = 0.0016
# logical error rate for (L=11,loss_rate=0.002,depo=0.004) = 0.0008
# logical error rate for (L=11,loss_rate=0.002,depo=0.004) = 0.0006
# logical error rate for (L=11,loss_rate=0.002,depo=0.004) = 0.0015
# logical error rate for (L=11,loss_rate=0.002,depo=0.004) = 0.0016
# logical error rate for (L=11,loss_rate=0.002,depo=0.004) = 0.0015
# logical error rate for (L=11,loss_rate=0.002,depo=0.004) = 0.0013
# logical error rate for (L=11,loss_rate=0.002,depo=0.004) = 0.0025
# logical error rate for (L=11,loss_rate=0.002,depo=0.004) = 0.001
# logical error rate for (L=11,loss_rate=0.002,depo=0.004) = 0.0011
# logical error rate for (L=11,loss_rate=0.002,depo=0.005) = 0.0043
# logical error rate for (L=11,loss_rate=0.002,depo=0.005) = 0.0029
# logical error rate for (L=11,loss_rate=0.002,depo=0.005) = 0.004
# logical error rate for (L=11,loss_rate=0.002,depo=0.005) = 0.0029
# logical error rate for (L=11,loss_rate=0.002,depo=0.005) = 0.0035
# logical error rate for (L=11,loss_rate=0.002,depo=0.005) = 0.0042
# logical error rate for (L=11,loss_rate=0.002,depo=0.005) = 0.0035
# logical error rate for (L=11,loss_rate=0.002,depo=0.005) = 0.0045
# logical error rate for (L=11,loss_rate=0.002,depo=0.005) = 0.0051
# logical error rate for (L=11,loss_rate=0.002,depo=0.005) = 0.0045
# logical error rate for (L=11,loss_rate=0.002,depo=0.006) = 0.0088
# logical error rate for (L=11,loss_rate=0.002,depo=0.006) = 0.0097
# logical error rate for (L=11,loss_rate=0.002,depo=0.006) = 0.0082
# logical error rate for (L=11,loss_rate=0.002,depo=0.006) = 0.0096
# logical error rate for (L=11,loss_rate=0.002,depo=0.006) = 0.0091
# logical error rate for (L=11,loss_rate=0.002,depo=0.006) = 0.0085
# logical error rate for (L=11,loss_rate=0.002,depo=0.006) = 0.0093
# logical error rate for (L=11,loss_rate=0.002,depo=0.006) = 0.0076
# logical error rate for (L=11,loss_rate=0.002,depo=0.006) = 0.01
# logical error rate for (L=11,loss_rate=0.002,depo=0.006) = 0.0093
# logical error rate for (L=11,loss_rate=0.002,depo=0.007) = 0.02
# logical error rate for (L=11,loss_rate=0.002,depo=0.007) = 0.0195
# logical error rate for (L=11,loss_rate=0.002,depo=0.007) = 0.0199
# logical error rate for (L=11,loss_rate=0.002,depo=0.007) = 0.0195
# logical error rate for (L=11,loss_rate=0.002,depo=0.007) = 0.0196
# logical error rate for (L=11,loss_rate=0.002,depo=0.007) = 0.0198
# logical error rate for (L=11,loss_rate=0.002,depo=0.007) = 0.0194
# logical error rate for (L=11,loss_rate=0.002,depo=0.007) = 0.0185
# logical error rate for (L=11,loss_rate=0.002,depo=0.007) = 0.02
# logical error rate for (L=11,loss_rate=0.002,depo=0.007) = 0.0205
# logical error rate for (L=11,loss_rate=0.002,depo=0.008) = 0.0384
# logical error rate for (L=11,loss_rate=0.002,depo=0.008) = 0.0342
# logical error rate for (L=11,loss_rate=0.002,depo=0.008) = 0.0379
# logical error rate for (L=11,loss_rate=0.002,depo=0.008) = 0.038
# logical error rate for (L=11,loss_rate=0.002,depo=0.008) = 0.0367
# logical error rate for (L=11,loss_rate=0.002,depo=0.008) = 0.0372
# logical error rate for (L=11,loss_rate=0.002,depo=0.008) = 0.0364
# logical error rate for (L=11,loss_rate=0.002,depo=0.008) = 0.039
# logical error rate for (L=11,loss_rate=0.002,depo=0.008) = 0.0386
# logical error rate for (L=11,loss_rate=0.002,depo=0.008) = 0.0348
# logical error rate for (L=11,loss_rate=0.002,depo=0.009) = 0.0611
# logical error rate for (L=11,loss_rate=0.002,depo=0.009) = 0.062
# logical error rate for (L=11,loss_rate=0.002,depo=0.009) = 0.0621
# logical error rate for (L=11,loss_rate=0.002,depo=0.009) = 0.0607
# logical error rate for (L=11,loss_rate=0.002,depo=0.009) = 0.0593
# logical error rate for (L=11,loss_rate=0.002,depo=0.009) = 0.0566
# logical error rate for (L=11,loss_rate=0.002,depo=0.009) = 0.0574
# logical error rate for (L=11,loss_rate=0.002,depo=0.009) = 0.0586
# logical error rate for (L=11,loss_rate=0.002,depo=0.009) = 0.0575
# logical error rate for (L=11,loss_rate=0.002,depo=0.009) = 0.0605
# logical error rate for (L=11,loss_rate=0.002,depo=0.01) = 0.0871
# logical error rate for (L=11,loss_rate=0.002,depo=0.01) = 0.0932
# logical error rate for (L=11,loss_rate=0.002,depo=0.01) = 0.0919
# logical error rate for (L=11,loss_rate=0.002,depo=0.01) = 0.0924
# logical error rate for (L=11,loss_rate=0.002,depo=0.01) = 0.0877
# logical error rate for (L=11,loss_rate=0.002,depo=0.01) = 0.0854
# logical error rate for (L=11,loss_rate=0.002,depo=0.01) = 0.0888
# logical error rate for (L=11,loss_rate=0.002,depo=0.01) = 0.0884
# logical error rate for (L=11,loss_rate=0.002,depo=0.01) = 0.0874
# logical error rate for (L=11,loss_rate=0.002,depo=0.01) = 0.0904
# logical error rate for (L=11,loss_rate=0.002,depo=0.011) = 0.1254
# logical error rate for (L=11,loss_rate=0.002,depo=0.011) = 0.1248
# logical error rate for (L=11,loss_rate=0.002,depo=0.011) = 0.1286
# logical error rate for (L=11,loss_rate=0.002,depo=0.011) = 0.1287
# logical error rate for (L=11,loss_rate=0.002,depo=0.011) = 0.1249
# logical error rate for (L=11,loss_rate=0.002,depo=0.011) = 0.1248
# logical error rate for (L=11,loss_rate=0.002,depo=0.011) = 0.1294
# logical error rate for (L=11,loss_rate=0.002,depo=0.011) = 0.1244
# logical error rate for (L=11,loss_rate=0.002,depo=0.011) = 0.1255
# logical error rate for (L=11,loss_rate=0.002,depo=0.011) = 0.126
# logical error rate for (L=11,loss_rate=0.002,depo=0.012) = 0.1676
# logical error rate for (L=11,loss_rate=0.002,depo=0.012) = 0.1713
# logical error rate for (L=11,loss_rate=0.002,depo=0.012) = 0.1686
# logical error rate for (L=11,loss_rate=0.002,depo=0.012) = 0.1667
# logical error rate for (L=11,loss_rate=0.002,depo=0.012) = 0.171
# logical error rate for (L=11,loss_rate=0.002,depo=0.012) = 0.1705
# logical error rate for (L=11,loss_rate=0.002,depo=0.012) = 0.1704
# logical error rate for (L=11,loss_rate=0.002,depo=0.012) = 0.1638
# logical error rate for (L=11,loss_rate=0.002,depo=0.012) = 0.1676
# logical error rate for (L=11,loss_rate=0.002,depo=0.012) = 0.1664
# logical error rate for (L=11,loss_rate=0.002,depo=0.013) = 0.21
# logical error rate for (L=11,loss_rate=0.002,depo=0.013) = 0.2126
# logical error rate for (L=11,loss_rate=0.002,depo=0.013) = 0.2176
# logical error rate for (L=11,loss_rate=0.002,depo=0.013) = 0.213
# logical error rate for (L=11,loss_rate=0.002,depo=0.013) = 0.2123
# logical error rate for (L=11,loss_rate=0.002,depo=0.013) = 0.2122
# logical error rate for (L=11,loss_rate=0.002,depo=0.013) = 0.21
# logical error rate for (L=11,loss_rate=0.002,depo=0.013) = 0.2123
# logical error rate for (L=11,loss_rate=0.002,depo=0.013) = 0.2103
# logical error rate for (L=11,loss_rate=0.002,depo=0.013) = 0.2122
# logical error rate for (L=11,loss_rate=0.002,depo=0.014) = 0.259
# logical error rate for (L=11,loss_rate=0.002,depo=0.014) = 0.2554
# logical error rate for (L=11,loss_rate=0.002,depo=0.014) = 0.2594
# logical error rate for (L=11,loss_rate=0.002,depo=0.014) = 0.2596
# logical error rate for (L=11,loss_rate=0.002,depo=0.014) = 0.2565
# logical error rate for (L=11,loss_rate=0.002,depo=0.014) = 0.2568
# logical error rate for (L=11,loss_rate=0.002,depo=0.014) = 0.2551
# logical error rate for (L=11,loss_rate=0.002,depo=0.014) = 0.2669
# logical error rate for (L=11,loss_rate=0.002,depo=0.014) = 0.2597
# logical error rate for (L=11,loss_rate=0.002,depo=0.014) = 0.259
# ...
# logical error rate for (L=9,loss_rate=0.007,depo=0.006) = 0.0456
# logical error rate for (L=9,loss_rate=0.007,depo=0.006) = 0.0483
# logical error rate for (L=9,loss_rate=0.007,depo=0.006) = 0.0452
# logical error rate for (L=9,loss_rate=0.007,depo=0.006) = 0.0467
# logical error rate for (L=9,loss_rate=0.007,depo=0.007) = 0.0754
# logical error rate for (L=9,loss_rate=0.007,depo=0.007) = 0.0719
# logical error rate for (L=9,loss_rate=0.007,depo=0.007) = 0.0753
# logical error rate for (L=9,loss_rate=0.007,depo=0.007) = 0.0704
# logical error rate for (L=9,loss_rate=0.007,depo=0.007) = 0.0767
# logical error rate for (L=9,loss_rate=0.007,depo=0.007) = 0.0705
# logical error rate for (L=9,loss_rate=0.007,depo=0.007) = 0.0692
# logical error rate for (L=9,loss_rate=0.007,depo=0.007) = 0.0715
# logical error rate for (L=9,loss_rate=0.007,depo=0.007) = 0.0691
# logical error rate for (L=9,loss_rate=0.007,depo=0.007) = 0.074
# logical error rate for (L=9,loss_rate=0.007,depo=0.008) = 0.1047
# logical error rate for (L=9,loss_rate=0.007,depo=0.008) = 0.0968
# logical error rate for (L=9,loss_rate=0.007,depo=0.008) = 0.1058
# logical error rate for (L=9,loss_rate=0.007,depo=0.008) = 0.102
# logical error rate for (L=9,loss_rate=0.007,depo=0.008) = 0.1053
# logical error rate for (L=9,loss_rate=0.007,depo=0.008) = 0.1039
# logical error rate for (L=9,loss_rate=0.007,depo=0.008) = 0.1026
# logical error rate for (L=9,loss_rate=0.007,depo=0.008) = 0.0978
# logical error rate for (L=9,loss_rate=0.007,depo=0.008) = 0.1059
# logical error rate for (L=9,loss_rate=0.007,depo=0.008) = 0.1016
# logical error rate for (L=9,loss_rate=0.007,depo=0.009) = 0.1418
# logical error rate for (L=9,loss_rate=0.007,depo=0.009) = 0.1279
# logical error rate for (L=9,loss_rate=0.007,depo=0.009) = 0.1419
# logical error rate for (L=9,loss_rate=0.007,depo=0.009) = 0.1317
# logical error rate for (L=9,loss_rate=0.007,depo=0.009) = 0.1395
# logical error rate for (L=9,loss_rate=0.007,depo=0.009) = 0.1373
# logical error rate for (L=9,loss_rate=0.007,depo=0.009) = 0.1329
# logical error rate for (L=9,loss_rate=0.007,depo=0.009) = 0.1361
# logical error rate for (L=9,loss_rate=0.007,depo=0.009) = 0.138
# logical error rate for (L=9,loss_rate=0.007,depo=0.009) = 0.1369
# logical error rate for (L=9,loss_rate=0.007,depo=0.01) = 0.1751
# logical error rate for (L=9,loss_rate=0.007,depo=0.01) = 0.1749
# logical error rate for (L=9,loss_rate=0.007,depo=0.01) = 0.1761
# logical error rate for (L=9,loss_rate=0.007,depo=0.01) = 0.1754
# logical error rate for (L=9,loss_rate=0.007,depo=0.01) = 0.17
# logical error rate for (L=9,loss_rate=0.007,depo=0.01) = 0.1737
# logical error rate for (L=9,loss_rate=0.007,depo=0.01) = 0.1768
# logical error rate for (L=9,loss_rate=0.007,depo=0.01) = 0.1754
# logical error rate for (L=9,loss_rate=0.007,depo=0.01) = 0.1773
# logical error rate for (L=9,loss_rate=0.007,depo=0.01) = 0.1704
# logical error rate for (L=9,loss_rate=0.007,depo=0.011) = 0.2123
# logical error rate for (L=9,loss_rate=0.007,depo=0.011) = 0.2115
# logical error rate for (L=9,loss_rate=0.007,depo=0.011) = 0.2164
# logical error rate for (L=9,loss_rate=0.007,depo=0.011) = 0.2095
# logical error rate for (L=9,loss_rate=0.007,depo=0.011) = 0.2116
# logical error rate for (L=9,loss_rate=0.007,depo=0.011) = 0.2106
# logical error rate for (L=9,loss_rate=0.007,depo=0.011) = 0.2126
# logical error rate for (L=9,loss_rate=0.007,depo=0.011) = 0.2159
# logical error rate for (L=9,loss_rate=0.007,depo=0.011) = 0.2195
# logical error rate for (L=9,loss_rate=0.007,depo=0.011) = 0.2097
# logical error rate for (L=9,loss_rate=0.007,depo=0.012) = 0.2552
# logical error rate for (L=9,loss_rate=0.007,depo=0.012) = 0.2469
# logical error rate for (L=9,loss_rate=0.007,depo=0.012) = 0.2546
# logical error rate for (L=9,loss_rate=0.007,depo=0.012) = 0.2479
# logical error rate for (L=9,loss_rate=0.007,depo=0.012) = 0.247
# logical error rate for (L=9,loss_rate=0.007,depo=0.012) = 0.2518
# logical error rate for (L=9,loss_rate=0.007,depo=0.012) = 0.2489
# logical error rate for (L=9,loss_rate=0.007,depo=0.012) = 0.2442
# logical error rate for (L=9,loss_rate=0.007,depo=0.012) = 0.2487
# logical error rate for (L=9,loss_rate=0.007,depo=0.012) = 0.2497
# logical error rate for (L=9,loss_rate=0.007,depo=0.013) = 0.296
# logical error rate for (L=9,loss_rate=0.007,depo=0.013) = 0.2824
# logical error rate for (L=9,loss_rate=0.007,depo=0.013) = 0.282
# logical error rate for (L=9,loss_rate=0.007,depo=0.013) = 0.286
# logical error rate for (L=9,loss_rate=0.007,depo=0.013) = 0.2818
# logical error rate for (L=9,loss_rate=0.007,depo=0.013) = 0.2908
# logical error rate for (L=9,loss_rate=0.007,depo=0.013) = 0.2846
# logical error rate for (L=9,loss_rate=0.007,depo=0.013) = 0.2945
# logical error rate for (L=9,loss_rate=0.007,depo=0.013) = 0.2888
# logical error rate for (L=9,loss_rate=0.007,depo=0.013) = 0.2883
# logical error rate for (L=9,loss_rate=0.007,depo=0.014) = 0.3146
# logical error rate for (L=9,loss_rate=0.007,depo=0.014) = 0.3297
# logical error rate for (L=9,loss_rate=0.007,depo=0.014) = 0.3304
# logical error rate for (L=9,loss_rate=0.007,depo=0.014) = 0.3212
# logical error rate for (L=9,loss_rate=0.007,depo=0.014) = 0.3231
# logical error rate for (L=9,loss_rate=0.007,depo=0.014) = 0.3243
# logical error rate for (L=9,loss_rate=0.007,depo=0.014) = 0.3243
# logical error rate for (L=9,loss_rate=0.007,depo=0.014) = 0.323
# logical error rate for (L=9,loss_rate=0.007,depo=0.014) = 0.3147
# logical error rate for (L=9,loss_rate=0.007,depo=0.014) = 0.3262
# logical error rate for (L=9,loss_rate=0.007,depo=0.015) = 0.3448
# logical error rate for (L=9,loss_rate=0.007,depo=0.015) = 0.3515
# logical error rate for (L=9,loss_rate=0.007,depo=0.015) = 0.3528
# logical error rate for (L=9,loss_rate=0.007,depo=0.015) = 0.3539
# logical error rate for (L=9,loss_rate=0.007,depo=0.015) = 0.3521
# logical error rate for (L=9,loss_rate=0.007,depo=0.015) = 0.3545
# logical error rate for (L=9,loss_rate=0.007,depo=0.015) = 0.3506
# logical error rate for (L=9,loss_rate=0.007,depo=0.015) = 0.3499
# logical error rate for (L=9,loss_rate=0.007,depo=0.015) = 0.3569
# logical error rate for (L=9,loss_rate=0.007,depo=0.015) = 0.3575
# logical error rate for (L=11,loss_rate=0.007,depo=0.001) = 0.0001
# logical error rate for (L=11,loss_rate=0.007,depo=0.001) = 0.0003
# logical error rate for (L=11,loss_rate=0.007,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.007,depo=0.001) = 0.0001
# logical error rate for (L=11,loss_rate=0.007,depo=0.001) = 0.0
# logical error rate for (L=11,loss_rate=0.007,depo=0.001) = 0.0004
# logical error rate for (L=11,loss_rate=0.007,depo=0.001) = 0.0002
# logical error rate for (L=11,loss_rate=0.007,depo=0.001) = 0.0002
# logical error rate for (L=11,loss_rate=0.007,depo=0.001) = 0.0002
# logical error rate for (L=11,loss_rate=0.007,depo=0.001) = 0.0002
# logical error rate for (L=11,loss_rate=0.007,depo=0.002) = 0.001
# logical error rate for (L=11,loss_rate=0.007,depo=0.002) = 0.0013
# logical error rate for (L=11,loss_rate=0.007,depo=0.002) = 0.0012
# logical error rate for (L=11,loss_rate=0.007,depo=0.002) = 0.0013
# logical error rate for (L=11,loss_rate=0.007,depo=0.002) = 0.0008
# logical error rate for (L=11,loss_rate=0.007,depo=0.002) = 0.0015
# logical error rate for (L=11,loss_rate=0.007,depo=0.002) = 0.001
# logical error rate for (L=11,loss_rate=0.007,depo=0.002) = 0.001
# logical error rate for (L=11,loss_rate=0.007,depo=0.002) = 0.0016
# logical error rate for (L=11,loss_rate=0.007,depo=0.002) = 0.0011
# logical error rate for (L=11,loss_rate=0.007,depo=0.003) = 0.004
# logical error rate for (L=11,loss_rate=0.007,depo=0.003) = 0.0034
# logical error rate for (L=11,loss_rate=0.007,depo=0.003) = 0.0055
# logical error rate for (L=11,loss_rate=0.007,depo=0.003) = 0.0043
# logical error rate for (L=11,loss_rate=0.007,depo=0.003) = 0.0048
# logical error rate for (L=11,loss_rate=0.007,depo=0.003) = 0.0046
# logical error rate for (L=11,loss_rate=0.007,depo=0.003) = 0.0046
# logical error rate for (L=11,loss_rate=0.007,depo=0.003) = 0.0033
# logical error rate for (L=11,loss_rate=0.007,depo=0.003) = 0.0049
# logical error rate for (L=11,loss_rate=0.007,depo=0.003) = 0.0046
# logical error rate for (L=11,loss_rate=0.007,depo=0.004) = 0.013
# logical error rate for (L=11,loss_rate=0.007,depo=0.004) = 0.0107
# logical error rate for (L=11,loss_rate=0.007,depo=0.004) = 0.0119
# logical error rate for (L=11,loss_rate=0.007,depo=0.004) = 0.0138
# logical error rate for (L=11,loss_rate=0.007,depo=0.004) = 0.0114
# logical error rate for (L=11,loss_rate=0.007,depo=0.004) = 0.0116
# logical error rate for (L=11,loss_rate=0.007,depo=0.004) = 0.0111
# logical error rate for (L=11,loss_rate=0.007,depo=0.004) = 0.0132
# logical error rate for (L=11,loss_rate=0.007,depo=0.004) = 0.0127
# logical error rate for (L=11,loss_rate=0.007,depo=0.004) = 0.0108
# logical error rate for (L=11,loss_rate=0.007,depo=0.005) = 0.0241
# logical error rate for (L=11,loss_rate=0.007,depo=0.005) = 0.0256
# logical error rate for (L=11,loss_rate=0.007,depo=0.005) = 0.0234
# logical error rate for (L=11,loss_rate=0.007,depo=0.005) = 0.0276
# logical error rate for (L=11,loss_rate=0.007,depo=0.005) = 0.025
# logical error rate for (L=11,loss_rate=0.007,depo=0.005) = 0.027
# logical error rate for (L=11,loss_rate=0.007,depo=0.005) = 0.026
# logical error rate for (L=11,loss_rate=0.007,depo=0.005) = 0.0271
# logical error rate for (L=11,loss_rate=0.007,depo=0.005) = 0.0268
# logical error rate for (L=11,loss_rate=0.007,depo=0.005) = 0.0254
# logical error rate for (L=11,loss_rate=0.007,depo=0.006) = 0.0509
# logical error rate for (L=11,loss_rate=0.007,depo=0.006) = 0.0509
# logical error rate for (L=11,loss_rate=0.007,depo=0.006) = 0.0477
# logical error rate for (L=11,loss_rate=0.007,depo=0.006) = 0.0499
# logical error rate for (L=11,loss_rate=0.007,depo=0.006) = 0.0478
# logical error rate for (L=11,loss_rate=0.007,depo=0.006) = 0.046
# logical error rate for (L=11,loss_rate=0.007,depo=0.006) = 0.0467
# logical error rate for (L=11,loss_rate=0.007,depo=0.006) = 0.0457
# logical error rate for (L=11,loss_rate=0.007,depo=0.006) = 0.0492
# logical error rate for (L=11,loss_rate=0.007,depo=0.006) = 0.0494
# logical error rate for (L=11,loss_rate=0.007,depo=0.007) = 0.0758
# logical error rate for (L=11,loss_rate=0.007,depo=0.007) = 0.0765
# logical error rate for (L=11,loss_rate=0.007,depo=0.007) = 0.0768
# logical error rate for (L=11,loss_rate=0.007,depo=0.007) = 0.0797
# logical error rate for (L=11,loss_rate=0.007,depo=0.007) = 0.0801
# logical error rate for (L=11,loss_rate=0.007,depo=0.007) = 0.0788
# logical error rate for (L=11,loss_rate=0.007,depo=0.007) = 0.0786
# logical error rate for (L=11,loss_rate=0.007,depo=0.007) = 0.0752
# logical error rate for (L=11,loss_rate=0.007,depo=0.007) = 0.0761
# logical error rate for (L=11,loss_rate=0.007,depo=0.007) = 0.081
# logical error rate for (L=11,loss_rate=0.007,depo=0.008) = 0.1176
# logical error rate for (L=11,loss_rate=0.007,depo=0.008) = 0.1247
# logical error rate for (L=11,loss_rate=0.007,depo=0.008) = 0.1143
# logical error rate for (L=11,loss_rate=0.007,depo=0.008) = 0.1142
# logical error rate for (L=11,loss_rate=0.007,depo=0.008) = 0.1164
# logical error rate for (L=11,loss_rate=0.007,depo=0.008) = 0.1153
# logical error rate for (L=11,loss_rate=0.007,depo=0.008) = 0.1125
# logical error rate for (L=11,loss_rate=0.007,depo=0.008) = 0.1152
# logical error rate for (L=11,loss_rate=0.007,depo=0.008) = 0.1169
# logical error rate for (L=11,loss_rate=0.007,depo=0.008) = 0.1168
# logical error rate for (L=11,loss_rate=0.007,depo=0.009) = 0.1589
# logical error rate for (L=11,loss_rate=0.007,depo=0.009) = 0.1642
# logical error rate for (L=11,loss_rate=0.007,depo=0.009) = 0.1715
# logical error rate for (L=11,loss_rate=0.007,depo=0.009) = 0.1576
# logical error rate for (L=11,loss_rate=0.007,depo=0.009) = 0.1635
# logical error rate for (L=11,loss_rate=0.007,depo=0.009) = 0.1662
# logical error rate for (L=11,loss_rate=0.007,depo=0.009) = 0.1602
# logical error rate for (L=11,loss_rate=0.007,depo=0.009) = 0.166
# logical error rate for (L=11,loss_rate=0.007,depo=0.009) = 0.1634
# logical error rate for (L=11,loss_rate=0.007,depo=0.009) = 0.1685
# logical error rate for (L=11,loss_rate=0.007,depo=0.01) = 0.2113
# logical error rate for (L=11,loss_rate=0.007,depo=0.01) = 0.2107
# logical error rate for (L=11,loss_rate=0.007,depo=0.01) = 0.2084
# logical error rate for (L=11,loss_rate=0.007,depo=0.01) = 0.2161
# logical error rate for (L=11,loss_rate=0.007,depo=0.01) = 0.2154
# logical error rate for (L=11,loss_rate=0.007,depo=0.01) = 0.2115
# logical error rate for (L=11,loss_rate=0.007,depo=0.01) = 0.2112
# logical error rate for (L=11,loss_rate=0.007,depo=0.01) = 0.2119
# logical error rate for (L=11,loss_rate=0.007,depo=0.01) = 0.2129
# logical error rate for (L=11,loss_rate=0.007,depo=0.01) = 0.2117
# logical error rate for (L=11,loss_rate=0.007,depo=0.011) = 0.2627
# logical error rate for (L=11,loss_rate=0.007,depo=0.011) = 0.2579
# logical error rate for (L=11,loss_rate=0.007,depo=0.011) = 0.2614
# logical error rate for (L=11,loss_rate=0.007,depo=0.011) = 0.2621
# logical error rate for (L=11,loss_rate=0.007,depo=0.011) = 0.2638
# logical error rate for (L=11,loss_rate=0.007,depo=0.011) = 0.2612
# logical error rate for (L=11,loss_rate=0.007,depo=0.011) = 0.2545
# logical error rate for (L=11,loss_rate=0.007,depo=0.011) = 0.2642
# logical error rate for (L=11,loss_rate=0.007,depo=0.011) = 0.2566
# logical error rate for (L=11,loss_rate=0.007,depo=0.011) = 0.2613
# logical error rate for (L=11,loss_rate=0.007,depo=0.012) = 0.3043
# logical error rate for (L=11,loss_rate=0.007,depo=0.012) = 0.3055
# logical error rate for (L=11,loss_rate=0.007,depo=0.012) = 0.2994
# logical error rate for (L=11,loss_rate=0.007,depo=0.012) = 0.3179
# logical error rate for (L=11,loss_rate=0.007,depo=0.012) = 0.3048
# logical error rate for (L=11,loss_rate=0.007,depo=0.012) = 0.3012
# logical error rate for (L=11,loss_rate=0.007,depo=0.012) = 0.3062
# logical error rate for (L=11,loss_rate=0.007,depo=0.012) = 0.3085
# logical error rate for (L=11,loss_rate=0.007,depo=0.012) = 0.3062
# logical error rate for (L=11,loss_rate=0.007,depo=0.012) = 0.2994
# logical error rate for (L=11,loss_rate=0.007,depo=0.013) = 0.3381
# logical error rate for (L=11,loss_rate=0.007,depo=0.013) = 0.3444
# logical error rate for (L=11,loss_rate=0.007,depo=0.013) = 0.3442
# logical error rate for (L=11,loss_rate=0.007,depo=0.013) = 0.3409
# logical error rate for (L=11,loss_rate=0.007,depo=0.013) = 0.3535
# logical error rate for (L=11,loss_rate=0.007,depo=0.013) = 0.3497
# logical error rate for (L=11,loss_rate=0.007,depo=0.013) = 0.3541
# logical error rate for (L=11,loss_rate=0.007,depo=0.013) = 0.3502
# logical error rate for (L=11,loss_rate=0.007,depo=0.013) = 0.3561
# logical error rate for (L=11,loss_rate=0.007,depo=0.013) = 0.3438
# logical error rate for (L=11,loss_rate=0.007,depo=0.014) = 0.386
# logical error rate for (L=11,loss_rate=0.007,depo=0.014) = 0.3863
# logical error rate for (L=11,loss_rate=0.007,depo=0.014) = 0.382
# logical error rate for (L=11,loss_rate=0.007,depo=0.014) = 0.3783
# logical error rate for (L=11,loss_rate=0.007,depo=0.014) = 0.393
# logical error rate for (L=11,loss_rate=0.007,depo=0.014) = 0.3927
# logical error rate for (L=11,loss_rate=0.007,depo=0.014) = 0.3829
# logical error rate for (L=11,loss_rate=0.007,depo=0.014) = 0.3813
# logical error rate for (L=11,loss_rate=0.007,depo=0.014) = 0.3871
# logical error rate for (L=11,loss_rate=0.007,depo=0.014) = 0.3758
# logical error rate for (L=11,loss_rate=0.007,depo=0.015) = 0.4244
# logical error rate for (L=11,loss_rate=0.007,depo=0.015) = 0.423
# logical error rate for (L=11,loss_rate=0.007,depo=0.015) = 0.4229
# logical error rate for (L=11,loss_rate=0.007,depo=0.015) = 0.4186
# logical error rate for (L=11,loss_rate=0.007,depo=0.015) = 0.4165
# logical error rate for (L=11,loss_rate=0.007,depo=0.015) = 0.4062
# logical error rate for (L=11,loss_rate=0.007,depo=0.015) = 0.4094
# logical error rate for (L=11,loss_rate=0.007,depo=0.015) = 0.41
# logical error rate for (L=11,loss_rate=0.007,depo=0.015) = 0.4122
# logical error rate for (L=11,loss_rate=0.007,depo=0.015) = 0.4207

# %%
#function for simulation

#Compute the logical error rate of the surface code supplemented with the teleportation LDU for a given noise and loss probability
#stored as a dictionnary in a file for a fixed depolarizing noise probability and various loss probabilities
def simulation_code_fixed_depo(L,loss,depo,num_shots):
    loss=round(loss,5)
    depo=round(depo,5)
    lattice = Rotated_Surface_Code_teleportation_LDU(L,L,L,'|0>','Z',measurement_order='z_first',loss_rate=loss,after_CZ=('DEPOLARIZE2',depo))
    dem_build=DEM_builder(lattice)
    PATH='data/dem/dem_teleportation_LDU/DEM_surface_code_({},{},{})'.format(L,L,L)
    
    error_rate=dem_build.logical_errors(num_shots,PATH)
    
    if os.path.exists('data/logical_error/logical_error_teleportation_LDU_d=({},{})_rounds={}_depo_noise={}.pkl'.format(L,L,L,depo)):
        with open('data/logical_error/logical_error_teleportation_LDU_d=({},{})_rounds={}_depo_noise={}.pkl'.format(L,L,L,depo), 'rb') as fp:
            data_saved=pickle.load(fp)
        
    else:
        data_saved={}
    if loss not in data_saved.keys():#CREATE DICTIONNARY if the loss probability has never been computed
        data_saved[loss]={}
        data_saved[loss]['num_shots']=num_shots
        data_saved[loss]['error_rate']=error_rate
    else:#UPDATE DICTIONNARY if there has been already simulation for that given loss and noise probability
        data_saved[loss]['error_rate']*=data_saved[loss]['num_shots']/(data_saved[loss]['num_shots']+num_shots)
        data_saved[loss]['error_rate']+=error_rate*num_shots/(data_saved[loss]['num_shots']+num_shots)
        data_saved[loss]['num_shots']+=num_shots

    #stored in a file for a given loss and various noise probabilities
    with open('data/logical_error/logical_error_teleportation_LDU_d=({},{})_rounds={}_depo_noise={}.pkl'.format(L,L,L,depo), 'wb') as fp:
        pickle.dump(data_saved, fp)

    print('logical error rate for (L={},loss_rate={},depo={}) = {}'.format(L,loss,depo,error_rate))
    

#wrapper to one argument (needed for parallelization)    
def multi_args_wrapper_fixed_depo(args):
   simulation_code_fixed_depo(*args)

# %%
#Compute the logical error rate and store as a dictionnary in files with a fixed depolarizing noise probabilities

Ls = range(3,13,2)
loss_list = np.linspace(0.001, 0.03, 30)
depo=0
num_shots = 10000 #number of shots per core
nb_core=10  #number of cores used

for L in Ls:
    for loss_rate in loss_list:
        with Pool(processes=nb_core) as pool:
            pool.imap(multi_args_wrapper_fixed_depo,[(L,loss_rate,depo,num_shots) for _ in range(10)])
            pool.close()
            pool.join()
# Out:
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0001
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0001
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0002
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0001
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0001
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0001
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0002
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0002
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0001
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0002
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0001
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0003
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0003
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0004
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0002
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0003
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0001
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0004
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0001
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0002
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0004
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0005
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0002
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0005
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0008
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0002
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0002
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0006
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0011
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0007
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0005
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0012
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0007
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0007
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0016
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0009
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0013
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0008
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0011
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0007
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.001
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0016
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0014
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0013
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0018
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0013
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0016
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0012
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0016
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0012
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0018
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0029
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0018
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0025
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0022
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0024
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0014
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0027
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0026
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0023
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.002
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0032
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0037
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0029
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0027
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0031
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0032
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0029
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0031
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0031
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0032
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0036
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0044
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0036
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0037
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.005
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0032
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0046
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0048
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.006
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0043
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0065
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0049
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0054
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0055
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0057
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0043
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0052
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0056
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0046
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0054
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0079
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0062
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0073
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0055
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0079
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0053
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0072
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0067
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0066
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0084
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.01
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0079
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0071
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0083
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0074
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0097
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.01
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0093
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.009
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0092
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0104
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0103
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0092
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0095
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0105
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0098
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0102
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0083
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0105
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0109
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.0141
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.0125
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.0122
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.0136
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.0124
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.0147
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.0128
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.0117
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.0113
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.0127
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.0137
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.0119
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.0175
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.0169
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.0136
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.0156
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.0176
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.0174
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.0145
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.0142
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.0189
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.0201
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.0168
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.0188
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.017
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.0168
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.0185
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.0189
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.0167
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.016
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.0227
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.0235
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.0215
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.019
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.0208
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.0206
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.02
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.0223
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.0196
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.0198
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.0235
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.0223
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.0258
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.0254
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.0218
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.0239
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.0225
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.0228
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.0249
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.0255
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.0296
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.0267
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.028
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.0283
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.0296
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.0249
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.0271
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.0275
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.025
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.0325
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.0292
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.0336
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.0312
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.0297
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.0303
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.0277
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.0288
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.032
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.0295
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.0328
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.0368
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.0348
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.0349
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.0365
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.0342
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.036
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.0321
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.0343
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.0356
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.0332
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.0403
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.04
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.038
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.038
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.0373
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.0378
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.0374
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.0381
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.04
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.039
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.0445
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.0442
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.0397
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.0404
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.0447
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.0414
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.0413
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.0391
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.0412
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.0448
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.0445
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.0476
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.0506
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.0473
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.0484
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.048
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.0499
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.0482
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.0448
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.049
# logical error rate for (L=3,loss_rate=0.026,depo=0.0) = 0.0466
# logical error rate for (L=3,loss_rate=0.026,depo=0.0) = 0.0527
# logical error rate for (L=3,loss_rate=0.026,depo=0.0) = 0.0526
# logical error rate for (L=3,loss_rate=0.026,depo=0.0) = 0.054
# logical error rate for (L=3,loss_rate=0.026,depo=0.0) = 0.051
# logical error rate for (L=3,loss_rate=0.026,depo=0.0) = 0.0555
# logical error rate for (L=3,loss_rate=0.026,depo=0.0) = 0.0522
# logical error rate for (L=3,loss_rate=0.026,depo=0.0) = 0.0518
# logical error rate for (L=3,loss_rate=0.026,depo=0.0) = 0.0499
# logical error rate for (L=3,loss_rate=0.026,depo=0.0) = 0.0523
# logical error rate for (L=3,loss_rate=0.027,depo=0.0) = 0.0553
# logical error rate for (L=3,loss_rate=0.027,depo=0.0) = 0.0608
# logical error rate for (L=3,loss_rate=0.027,depo=0.0) = 0.0567
# logical error rate for (L=3,loss_rate=0.027,depo=0.0) = 0.0608
# logical error rate for (L=3,loss_rate=0.027,depo=0.0) = 0.0566
# logical error rate for (L=3,loss_rate=0.027,depo=0.0) = 0.057
# logical error rate for (L=3,loss_rate=0.027,depo=0.0) = 0.0561
# logical error rate for (L=3,loss_rate=0.027,depo=0.0) = 0.0542
# logical error rate for (L=3,loss_rate=0.027,depo=0.0) = 0.065
# logical error rate for (L=3,loss_rate=0.027,depo=0.0) = 0.0626
# logical error rate for (L=3,loss_rate=0.028,depo=0.0) = 0.065
# logical error rate for (L=3,loss_rate=0.028,depo=0.0) = 0.0598
# logical error rate for (L=3,loss_rate=0.028,depo=0.0) = 0.0589
# logical error rate for (L=3,loss_rate=0.028,depo=0.0) = 0.0582
# logical error rate for (L=3,loss_rate=0.028,depo=0.0) = 0.0585
# logical error rate for (L=3,loss_rate=0.028,depo=0.0) = 0.0694
# logical error rate for (L=3,loss_rate=0.028,depo=0.0) = 0.0593
# logical error rate for (L=3,loss_rate=0.028,depo=0.0) = 0.0586
# logical error rate for (L=3,loss_rate=0.028,depo=0.0) = 0.0617
# logical error rate for (L=3,loss_rate=0.028,depo=0.0) = 0.0636
# logical error rate for (L=3,loss_rate=0.029,depo=0.0) = 0.0666
# logical error rate for (L=3,loss_rate=0.029,depo=0.0) = 0.0668
# logical error rate for (L=3,loss_rate=0.029,depo=0.0) = 0.0678
# logical error rate for (L=3,loss_rate=0.029,depo=0.0) = 0.0613
# logical error rate for (L=3,loss_rate=0.029,depo=0.0) = 0.0658
# logical error rate for (L=3,loss_rate=0.029,depo=0.0) = 0.0662
# logical error rate for (L=3,loss_rate=0.029,depo=0.0) = 0.0657
# logical error rate for (L=3,loss_rate=0.029,depo=0.0) = 0.067
# logical error rate for (L=3,loss_rate=0.029,depo=0.0) = 0.0636
# logical error rate for (L=3,loss_rate=0.029,depo=0.0) = 0.0655
# logical error rate for (L=3,loss_rate=0.03,depo=0.0) = 0.0752
# logical error rate for (L=3,loss_rate=0.03,depo=0.0) = 0.0722
# logical error rate for (L=3,loss_rate=0.03,depo=0.0) = 0.0759
# logical error rate for (L=3,loss_rate=0.03,depo=0.0) = 0.0746
# logical error rate for (L=3,loss_rate=0.03,depo=0.0) = 0.0745
# logical error rate for (L=3,loss_rate=0.03,depo=0.0) = 0.0709
# logical error rate for (L=3,loss_rate=0.03,depo=0.0) = 0.0719
# logical error rate for (L=3,loss_rate=0.03,depo=0.0) = 0.0755
# logical error rate for (L=3,loss_rate=0.03,depo=0.0) = 0.072
# logical error rate for (L=3,loss_rate=0.03,depo=0.0) = 0.0705
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0001
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0001
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0001
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0001
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0002
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0001
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0001
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0001
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0003
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0003
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0003
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0004
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0002
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0003
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0007
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0001
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0004
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0001
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0007
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0001
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0002
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0004
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0001
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0007
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0004
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0006
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0012
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0004
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0005
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0001
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0005
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0005
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0005
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.001
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0014
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0009
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0008
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0012
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0015
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0009
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0007
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0007
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0009
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.0026
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.0021
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.0017
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.0013
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.0013
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.0018
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.0018
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.0022
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.0015
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.0019
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.0024
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.002
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.0031
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.0032
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.0025
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.003
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.0022
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.0024
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.0024
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.0016
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.0041
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.0041
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.0039
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.004
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.0035
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.0042
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.0033
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.0033
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.0043
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.0037
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.0055
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.0059
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.0043
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.0046
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.0038
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.0047
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.0053
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.0054
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.0036
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.005
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.0069
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.0071
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.0065
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.0083
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.0063
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.0059
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.0082
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.0077
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.0083
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.0076
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.0102
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.0093
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.0109
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.0088
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.0103
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.0095
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.0104
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.009
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.0088
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.0112
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.0118
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.0141
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.0126
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.0142
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.0128
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.0121
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.014
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.0151
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.0152
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.0129
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 14
#      12 pool.imap(multi_args_wrapper_fixed_depo,[(L,loss_rate,depo,num_shots) for _ in range(10)])
#      13 pool.close()
# ---> 14 pool.join()
#
# File ~/anaconda3/envs/QEC/lib/python3.9/multiprocessing/pool.py:662, in Pool.join(self)
#     660 elif self._state not in (CLOSE, TERMINATE):
#     661     raise ValueError("In unknown state")
# --> 662 self._worker_handler.join()
#     663 self._task_handler.join()
#     664 self._result_handler.join()
#
# File ~/anaconda3/envs/QEC/lib/python3.9/threading.py:1033, in Thread.join(self, timeout)
#    1030     raise RuntimeError("cannot join current thread")
#    1032 if timeout is None:
# -> 1033     self._wait_for_tstate_lock()
#    1034 else:
#    1035     # the behavior of a negative timeout isn't documented, but
#    1036     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1037     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/anaconda3/envs/QEC/lib/python3.9/threading.py:1049, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1047 if lock is None:  # already determined that the C code is done
#    1048     assert self._is_stopped
# -> 1049 elif lock.acquire(block, timeout):
#    1050     lock.release()
#    1051     self._stop()
#
# KeyboardInterrupt:
