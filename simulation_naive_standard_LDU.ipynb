# %%
import stim
from dem_builder_standard_LDU import DEM_builder
import os
import numpy as np
import scipy
from surface_code_standard_LDU import Rotated_Surface_Code_standard_LDU
import pymatching
import pickle
import multiprocessing
from multiprocessing import Pool

# %%
#function for simulation

#Compute the logical error rate of the surface code supplemented with the standard LDU for a given noise and loss probability using a naive decoder
#stored as dictionnary in a file for a fixed loss probability and various depolarizing noise probabilities

def simulation_code_fixed_loss(L,loss,depo,num_shots):
    loss=round(loss,5)
    depo=round(depo,5)
    lattice = Rotated_Surface_Code_standard_LDU(L,L,L,'|0>','Z',measurement_order='z_first',loss_rate=loss,after_CZ=('DEPOLARIZE2',depo))
    dem_build=DEM_builder(lattice)
    path_dem='data/dem/naive_dem_standard_LDU/DEM_surface_code_({},{},{})_loss_rate={}.dem'.format(lattice.width,lattice.height,lattice.rounds,lattice.loss_rate)
    
    error_rate=dem_build.naive_logical_errors(num_shots,path_dem)
    
    if os.path.exists('data/logical_error/naive_logical_error_standard_LDU_d=({},{})_rounds={}_loss_rate={}.pkl'.format(L,L,L,loss)):
        with open('data/logical_error/naive_logical_error_standard_LDU_d=({},{})_rounds={}_loss_rate={}.pkl'.format(L,L,L,loss), 'rb') as fp:
            data_saved=pickle.load(fp)
        
    else:
        data_saved={}
    if depo not in data_saved.keys():#CREATE DICTIONNARY if the noise probability has never been computed
        data_saved[depo]={}
        data_saved[depo]['num_shots']=num_shots
        data_saved[depo]['error_rate']=error_rate
    else:#UPDATE DICTIONNARY if there has been already simulation for that given loss and noise probability
        data_saved[depo]['error_rate']*=data_saved[depo]['num_shots']/(data_saved[depo]['num_shots']+num_shots)
        data_saved[depo]['error_rate']+=error_rate*num_shots/(data_saved[depo]['num_shots']+num_shots)
        data_saved[depo]['num_shots']+=num_shots
    
    #stored in a file for a given loss and various noise probabilities
    with open('data/logical_error/naive_logical_error_standard_LDU_d=({},{})_rounds={}_loss_rate={}.pkl'.format(L,L,L,loss), 'wb') as fp:
        pickle.dump(data_saved, fp)

    print('logical error rate for (L={},loss_rate={},depo={}) = {}'.format(L,loss,depo,error_rate))
    


#wrapper to one argument (needed for parallelization)
def multi_args_wrapper_fixed_loss(args):
   simulation_code_fixed_loss(*args)

# %%
#Compute the logical error rate and store as a dictionnary in files with a fixed loss probabilities

Ls = range(3,13,2)
depo_list = np.linspace(0.001, 0.016, 16) #list of depolarizing noise probabilities
loss_list=[0.,0.001,0.002,0.003,0.005,0.007,0.01,0.015,0.02,0.025,0.027] #list of loss probabilities
num_shots = 10000 #number of shots per core
nb_core=10 #number of cores used

for loss_rate in loss_list:
    for L in Ls:
        for depo in depo_list:
            with Pool(processes=nb_core) as pool:
                pool.imap(multi_args_wrapper_fixed_loss,[(L,loss_rate,depo,num_shots) for _ in range(10)])
                pool.close()
                pool.join()
# Out:
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0004
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0006logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0006
#
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0004
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0008
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0006
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0006
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0003
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0009
# logical error rate for (L=3,loss_rate=0.0,depo=0.001) = 0.0005
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0024
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0018
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0018
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0024
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0013
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0021
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0028
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0031
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0028
# logical error rate for (L=3,loss_rate=0.0,depo=0.002) = 0.0024
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0051
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0063
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0055
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0052
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0043
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0059
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0047
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0058
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0058
# logical error rate for (L=3,loss_rate=0.0,depo=0.003) = 0.0053
# logical error rate for (L=3,loss_rate=0.0,depo=0.004) = 0.0084
# logical error rate for (L=3,loss_rate=0.0,depo=0.004) = 0.0079
# logical error rate for (L=3,loss_rate=0.0,depo=0.004) = 0.0088
# logical error rate for (L=3,loss_rate=0.0,depo=0.004) = 0.0092
# logical error rate for (L=3,loss_rate=0.0,depo=0.004) = 0.0087
# logical error rate for (L=3,loss_rate=0.0,depo=0.004) = 0.01
# logical error rate for (L=3,loss_rate=0.0,depo=0.004) = 0.01
# logical error rate for (L=3,loss_rate=0.0,depo=0.004) = 0.0097
# logical error rate for (L=3,loss_rate=0.0,depo=0.004) = 0.008
# logical error rate for (L=3,loss_rate=0.0,depo=0.004) = 0.0072
# logical error rate for (L=3,loss_rate=0.0,depo=0.005) = 0.0152
# logical error rate for (L=3,loss_rate=0.0,depo=0.005) = 0.0143
# logical error rate for (L=3,loss_rate=0.0,depo=0.005) = 0.013
# logical error rate for (L=3,loss_rate=0.0,depo=0.005) = 0.0143
# logical error rate for (L=3,loss_rate=0.0,depo=0.005) = 0.0138
# logical error rate for (L=3,loss_rate=0.0,depo=0.005) = 0.014
# logical error rate for (L=3,loss_rate=0.0,depo=0.005) = 0.0137
# logical error rate for (L=3,loss_rate=0.0,depo=0.005) = 0.0136
# logical error rate for (L=3,loss_rate=0.0,depo=0.005) = 0.0165
# logical error rate for (L=3,loss_rate=0.0,depo=0.005) = 0.0154
# logical error rate for (L=3,loss_rate=0.0,depo=0.006) = 0.0182
# logical error rate for (L=3,loss_rate=0.0,depo=0.006) = 0.0202
# logical error rate for (L=3,loss_rate=0.0,depo=0.006) = 0.0181
# logical error rate for (L=3,loss_rate=0.0,depo=0.006) = 0.0196
# logical error rate for (L=3,loss_rate=0.0,depo=0.006) = 0.0204
# logical error rate for (L=3,loss_rate=0.0,depo=0.006) = 0.0184
# logical error rate for (L=3,loss_rate=0.0,depo=0.006) = 0.0173
# logical error rate for (L=3,loss_rate=0.0,depo=0.006) = 0.0208
# logical error rate for (L=3,loss_rate=0.0,depo=0.006) = 0.0193
# logical error rate for (L=3,loss_rate=0.0,depo=0.006) = 0.0213
# logical error rate for (L=3,loss_rate=0.0,depo=0.007) = 0.0286
# logical error rate for (L=3,loss_rate=0.0,depo=0.007) = 0.0271
# logical error rate for (L=3,loss_rate=0.0,depo=0.007) = 0.023
# logical error rate for (L=3,loss_rate=0.0,depo=0.007) = 0.0271
# logical error rate for (L=3,loss_rate=0.0,depo=0.007) = 0.0269
# logical error rate for (L=3,loss_rate=0.0,depo=0.007) = 0.0263
# logical error rate for (L=3,loss_rate=0.0,depo=0.007) = 0.0279
# logical error rate for (L=3,loss_rate=0.0,depo=0.007) = 0.0247
# logical error rate for (L=3,loss_rate=0.0,depo=0.007) = 0.027
# logical error rate for (L=3,loss_rate=0.0,depo=0.007) = 0.0279
# logical error rate for (L=3,loss_rate=0.0,depo=0.008) = 0.0304
# logical error rate for (L=3,loss_rate=0.0,depo=0.008) = 0.0339
# logical error rate for (L=3,loss_rate=0.0,depo=0.008) = 0.0325
# logical error rate for (L=3,loss_rate=0.0,depo=0.008) = 0.0318
# logical error rate for (L=3,loss_rate=0.0,depo=0.008) = 0.0332
# logical error rate for (L=3,loss_rate=0.0,depo=0.008) = 0.0336
# logical error rate for (L=3,loss_rate=0.0,depo=0.008) = 0.0359
# logical error rate for (L=3,loss_rate=0.0,depo=0.008) = 0.0284
# logical error rate for (L=3,loss_rate=0.0,depo=0.008) = 0.0335
# logical error rate for (L=3,loss_rate=0.0,depo=0.008) = 0.0321
# logical error rate for (L=3,loss_rate=0.0,depo=0.009) = 0.0379
# logical error rate for (L=3,loss_rate=0.0,depo=0.009) = 0.0408
# logical error rate for (L=3,loss_rate=0.0,depo=0.009) = 0.0393
# logical error rate for (L=3,loss_rate=0.0,depo=0.009) = 0.0404
# logical error rate for (L=3,loss_rate=0.0,depo=0.009) = 0.0403
# logical error rate for (L=3,loss_rate=0.0,depo=0.009) = 0.0424
# logical error rate for (L=3,loss_rate=0.0,depo=0.009) = 0.0402
# logical error rate for (L=3,loss_rate=0.0,depo=0.009) = 0.0404
# logical error rate for (L=3,loss_rate=0.0,depo=0.009) = 0.04
# logical error rate for (L=3,loss_rate=0.0,depo=0.009) = 0.0442
# logical error rate for (L=3,loss_rate=0.0,depo=0.01) = 0.0496
# logical error rate for (L=3,loss_rate=0.0,depo=0.01) = 0.0478
# logical error rate for (L=3,loss_rate=0.0,depo=0.01) = 0.0496
# logical error rate for (L=3,loss_rate=0.0,depo=0.01) = 0.0487
# logical error rate for (L=3,loss_rate=0.0,depo=0.01) = 0.0489
# logical error rate for (L=3,loss_rate=0.0,depo=0.01) = 0.0473
# logical error rate for (L=3,loss_rate=0.0,depo=0.01) = 0.0475
# logical error rate for (L=3,loss_rate=0.0,depo=0.01) = 0.0507
# logical error rate for (L=3,loss_rate=0.0,depo=0.01) = 0.0474
# logical error rate for (L=3,loss_rate=0.0,depo=0.01) = 0.0518
# logical error rate for (L=3,loss_rate=0.0,depo=0.011) = 0.054
# logical error rate for (L=3,loss_rate=0.0,depo=0.011) = 0.0589
# logical error rate for (L=3,loss_rate=0.0,depo=0.011) = 0.0551
# logical error rate for (L=3,loss_rate=0.0,depo=0.011) = 0.0565
# logical error rate for (L=3,loss_rate=0.0,depo=0.011) = 0.0548
# logical error rate for (L=3,loss_rate=0.0,depo=0.011) = 0.0596
# logical error rate for (L=3,loss_rate=0.0,depo=0.011) = 0.0517
# logical error rate for (L=3,loss_rate=0.0,depo=0.011) = 0.0567
# logical error rate for (L=3,loss_rate=0.0,depo=0.011) = 0.0603
# logical error rate for (L=3,loss_rate=0.0,depo=0.011) = 0.0582
# logical error rate for (L=3,loss_rate=0.0,depo=0.012) = 0.0675
# logical error rate for (L=3,loss_rate=0.0,depo=0.012) = 0.0628
# logical error rate for (L=3,loss_rate=0.0,depo=0.012) = 0.0661
# logical error rate for (L=3,loss_rate=0.0,depo=0.012) = 0.064
# logical error rate for (L=3,loss_rate=0.0,depo=0.012) = 0.0658
# logical error rate for (L=3,loss_rate=0.0,depo=0.012) = 0.0623
# logical error rate for (L=3,loss_rate=0.0,depo=0.012) = 0.0663
# logical error rate for (L=3,loss_rate=0.0,depo=0.012) = 0.0626
# logical error rate for (L=3,loss_rate=0.0,depo=0.012) = 0.0674
# logical error rate for (L=3,loss_rate=0.0,depo=0.012) = 0.0647
# logical error rate for (L=3,loss_rate=0.0,depo=0.013) = 0.0706
# logical error rate for (L=3,loss_rate=0.0,depo=0.013) = 0.0748
# logical error rate for (L=3,loss_rate=0.0,depo=0.013) = 0.072
# logical error rate for (L=3,loss_rate=0.0,depo=0.013) = 0.0729
# logical error rate for (L=3,loss_rate=0.0,depo=0.013) = 0.0714
# logical error rate for (L=3,loss_rate=0.0,depo=0.013) = 0.0789
# logical error rate for (L=3,loss_rate=0.0,depo=0.013) = 0.0745
# logical error rate for (L=3,loss_rate=0.0,depo=0.013) = 0.0715
# logical error rate for (L=3,loss_rate=0.0,depo=0.013) = 0.0757
# logical error rate for (L=3,loss_rate=0.0,depo=0.013) = 0.0745
# logical error rate for (L=3,loss_rate=0.0,depo=0.014) = 0.0827
# logical error rate for (L=3,loss_rate=0.0,depo=0.014) = 0.082
# logical error rate for (L=3,loss_rate=0.0,depo=0.014) = 0.083
# logical error rate for (L=3,loss_rate=0.0,depo=0.014) = 0.0863
# logical error rate for (L=3,loss_rate=0.0,depo=0.014) = 0.0827
# logical error rate for (L=3,loss_rate=0.0,depo=0.014) = 0.0816
# logical error rate for (L=3,loss_rate=0.0,depo=0.014) = 0.0876
# logical error rate for (L=3,loss_rate=0.0,depo=0.014) = 0.0841
# logical error rate for (L=3,loss_rate=0.0,depo=0.014) = 0.078
# logical error rate for (L=3,loss_rate=0.0,depo=0.014) = 0.0822
# logical error rate for (L=3,loss_rate=0.0,depo=0.015) = 0.0892
# logical error rate for (L=3,loss_rate=0.0,depo=0.015) = 0.0919
# logical error rate for (L=3,loss_rate=0.0,depo=0.015) = 0.0932
# logical error rate for (L=3,loss_rate=0.0,depo=0.015) = 0.0951
# logical error rate for (L=3,loss_rate=0.0,depo=0.015) = 0.0906
# logical error rate for (L=3,loss_rate=0.0,depo=0.015) = 0.0939
# logical error rate for (L=3,loss_rate=0.0,depo=0.015) = 0.0921
# logical error rate for (L=3,loss_rate=0.0,depo=0.015) = 0.0932
# logical error rate for (L=3,loss_rate=0.0,depo=0.015) = 0.0965
# logical error rate for (L=3,loss_rate=0.0,depo=0.015) = 0.0954
# logical error rate for (L=3,loss_rate=0.0,depo=0.016) = 0.1056
# logical error rate for (L=3,loss_rate=0.0,depo=0.016) = 0.1045
# logical error rate for (L=3,loss_rate=0.0,depo=0.016) = 0.1101
# logical error rate for (L=3,loss_rate=0.0,depo=0.016) = 0.1003
# logical error rate for (L=3,loss_rate=0.0,depo=0.016) = 0.105
# logical error rate for (L=3,loss_rate=0.0,depo=0.016) = 0.1063
# logical error rate for (L=3,loss_rate=0.0,depo=0.016) = 0.1042
# logical error rate for (L=3,loss_rate=0.0,depo=0.016) = 0.1092
# logical error rate for (L=3,loss_rate=0.0,depo=0.016) = 0.1054
# logical error rate for (L=3,loss_rate=0.0,depo=0.016) = 0.1069
# logical error rate for (L=3,loss_rate=0.0,depo=0.017) = 0.1051
# logical error rate for (L=3,loss_rate=0.0,depo=0.017) = 0.1187
# logical error rate for (L=3,loss_rate=0.0,depo=0.017) = 0.1171
# logical error rate for (L=3,loss_rate=0.0,depo=0.017) = 0.1195
# logical error rate for (L=3,loss_rate=0.0,depo=0.017) = 0.1113
# logical error rate for (L=3,loss_rate=0.0,depo=0.017) = 0.1201
# logical error rate for (L=3,loss_rate=0.0,depo=0.017) = 0.1138
# logical error rate for (L=3,loss_rate=0.0,depo=0.017) = 0.1176
# logical error rate for (L=3,loss_rate=0.0,depo=0.017) = 0.1179
# logical error rate for (L=3,loss_rate=0.0,depo=0.017) = 0.1106
# logical error rate for (L=3,loss_rate=0.0,depo=0.018) = 0.1289
# logical error rate for (L=3,loss_rate=0.0,depo=0.018) = 0.1267
# logical error rate for (L=3,loss_rate=0.0,depo=0.018) = 0.123
# logical error rate for (L=3,loss_rate=0.0,depo=0.018) = 0.127
# logical error rate for (L=3,loss_rate=0.0,depo=0.018) = 0.122
# logical error rate for (L=3,loss_rate=0.0,depo=0.018) = 0.1223
# logical error rate for (L=3,loss_rate=0.0,depo=0.018) = 0.1236logical error rate for (L=3,loss_rate=0.0,depo=0.018) = 0.1238
#
# logical error rate for (L=3,loss_rate=0.0,depo=0.018) = 0.1221
# logical error rate for (L=3,loss_rate=0.0,depo=0.018) = 0.1243
# logical error rate for (L=3,loss_rate=0.0,depo=0.019) = 0.1343
# logical error rate for (L=3,loss_rate=0.0,depo=0.019) = 0.134
# logical error rate for (L=3,loss_rate=0.0,depo=0.019) = 0.1318
# logical error rate for (L=3,loss_rate=0.0,depo=0.019) = 0.1338
# logical error rate for (L=3,loss_rate=0.0,depo=0.019) = 0.1391
# logical error rate for (L=3,loss_rate=0.0,depo=0.019) = 0.1334
# logical error rate for (L=3,loss_rate=0.0,depo=0.019) = 0.1291
# logical error rate for (L=3,loss_rate=0.0,depo=0.019) = 0.1364
# logical error rate for (L=3,loss_rate=0.0,depo=0.019) = 0.1263
# logical error rate for (L=3,loss_rate=0.0,depo=0.019) = 0.1378
# logical error rate for (L=3,loss_rate=0.0,depo=0.02) = 0.1446
# logical error rate for (L=3,loss_rate=0.0,depo=0.02) = 0.1448
# logical error rate for (L=3,loss_rate=0.0,depo=0.02) = 0.1478
# logical error rate for (L=3,loss_rate=0.0,depo=0.02) = 0.1501
# logical error rate for (L=3,loss_rate=0.0,depo=0.02) = 0.147
# logical error rate for (L=3,loss_rate=0.0,depo=0.02) = 0.1464
# logical error rate for (L=3,loss_rate=0.0,depo=0.02) = 0.1473
# logical error rate for (L=3,loss_rate=0.0,depo=0.02) = 0.14
# logical error rate for (L=3,loss_rate=0.0,depo=0.02) = 0.1435
# logical error rate for (L=3,loss_rate=0.0,depo=0.02) = 0.1461
# logical error rate for (L=5,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=5,loss_rate=0.0,depo=0.001) = 0.0003
# logical error rate for (L=5,loss_rate=0.0,depo=0.001) = 0.0001
# logical error rate for (L=5,loss_rate=0.0,depo=0.001) = 0.0001
# logical error rate for (L=5,loss_rate=0.0,depo=0.001) = 0.0002
# logical error rate for (L=5,loss_rate=0.0,depo=0.001) = 0.0002
# logical error rate for (L=5,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=5,loss_rate=0.0,depo=0.001) = 0.0005
# logical error rate for (L=5,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=5,loss_rate=0.0,depo=0.001) = 0.0002
# logical error rate for (L=5,loss_rate=0.0,depo=0.002) = 0.0011
# logical error rate for (L=5,loss_rate=0.0,depo=0.002) = 0.0009
# logical error rate for (L=5,loss_rate=0.0,depo=0.002) = 0.0016
# logical error rate for (L=5,loss_rate=0.0,depo=0.002) = 0.0017
# logical error rate for (L=5,loss_rate=0.0,depo=0.002) = 0.0015
# logical error rate for (L=5,loss_rate=0.0,depo=0.002) = 0.0015
# logical error rate for (L=5,loss_rate=0.0,depo=0.002) = 0.0015
# logical error rate for (L=5,loss_rate=0.0,depo=0.002) = 0.001
# logical error rate for (L=5,loss_rate=0.0,depo=0.002) = 0.0009
# logical error rate for (L=5,loss_rate=0.0,depo=0.002) = 0.0011
# logical error rate for (L=5,loss_rate=0.0,depo=0.003) = 0.0047
# logical error rate for (L=5,loss_rate=0.0,depo=0.003) = 0.004
# logical error rate for (L=5,loss_rate=0.0,depo=0.003) = 0.0041
# logical error rate for (L=5,loss_rate=0.0,depo=0.003) = 0.0034
# logical error rate for (L=5,loss_rate=0.0,depo=0.003) = 0.0044
# logical error rate for (L=5,loss_rate=0.0,depo=0.003) = 0.0035
# logical error rate for (L=5,loss_rate=0.0,depo=0.003) = 0.0035
# logical error rate for (L=5,loss_rate=0.0,depo=0.003) = 0.003
# logical error rate for (L=5,loss_rate=0.0,depo=0.003) = 0.0037
# logical error rate for (L=5,loss_rate=0.0,depo=0.003) = 0.0035
# logical error rate for (L=5,loss_rate=0.0,depo=0.004) = 0.0078
# logical error rate for (L=5,loss_rate=0.0,depo=0.004) = 0.0096
# logical error rate for (L=5,loss_rate=0.0,depo=0.004) = 0.0074
# logical error rate for (L=5,loss_rate=0.0,depo=0.004) = 0.0095
# logical error rate for (L=5,loss_rate=0.0,depo=0.004) = 0.0075
# logical error rate for (L=5,loss_rate=0.0,depo=0.004) = 0.0091
# logical error rate for (L=5,loss_rate=0.0,depo=0.004) = 0.0081
# logical error rate for (L=5,loss_rate=0.0,depo=0.004) = 0.0077
# logical error rate for (L=5,loss_rate=0.0,depo=0.004) = 0.0087
# logical error rate for (L=5,loss_rate=0.0,depo=0.004) = 0.0078
# logical error rate for (L=5,loss_rate=0.0,depo=0.005) = 0.0172
# logical error rate for (L=5,loss_rate=0.0,depo=0.005) = 0.0157
# logical error rate for (L=5,loss_rate=0.0,depo=0.005) = 0.0138
# logical error rate for (L=5,loss_rate=0.0,depo=0.005) = 0.0151
# logical error rate for (L=5,loss_rate=0.0,depo=0.005) = 0.0159
# logical error rate for (L=5,loss_rate=0.0,depo=0.005) = 0.0158
# logical error rate for (L=5,loss_rate=0.0,depo=0.005) = 0.0183
# logical error rate for (L=5,loss_rate=0.0,depo=0.005) = 0.0172
# logical error rate for (L=5,loss_rate=0.0,depo=0.005) = 0.0167
# logical error rate for (L=5,loss_rate=0.0,depo=0.005) = 0.0145
# logical error rate for (L=5,loss_rate=0.0,depo=0.006) = 0.0261
# logical error rate for (L=5,loss_rate=0.0,depo=0.006) = 0.0255
# logical error rate for (L=5,loss_rate=0.0,depo=0.006) = 0.0262
# logical error rate for (L=5,loss_rate=0.0,depo=0.006) = 0.0245
# logical error rate for (L=5,loss_rate=0.0,depo=0.006) = 0.0259
# logical error rate for (L=5,loss_rate=0.0,depo=0.006) = 0.026
# logical error rate for (L=5,loss_rate=0.0,depo=0.006) = 0.0233
# logical error rate for (L=5,loss_rate=0.0,depo=0.006) = 0.024
# logical error rate for (L=5,loss_rate=0.0,depo=0.006) = 0.026
# logical error rate for (L=5,loss_rate=0.0,depo=0.006) = 0.0252
# logical error rate for (L=5,loss_rate=0.0,depo=0.007) = 0.0363
# logical error rate for (L=5,loss_rate=0.0,depo=0.007) = 0.0375
# logical error rate for (L=5,loss_rate=0.0,depo=0.007) = 0.0367
# logical error rate for (L=5,loss_rate=0.0,depo=0.007) = 0.0398
# logical error rate for (L=5,loss_rate=0.0,depo=0.007) = 0.0356
# logical error rate for (L=5,loss_rate=0.0,depo=0.007) = 0.0351
# logical error rate for (L=5,loss_rate=0.0,depo=0.007) = 0.0342
# logical error rate for (L=5,loss_rate=0.0,depo=0.007) = 0.0353
# logical error rate for (L=5,loss_rate=0.0,depo=0.007) = 0.0347
# logical error rate for (L=5,loss_rate=0.0,depo=0.007) = 0.0371
# logical error rate for (L=5,loss_rate=0.0,depo=0.008) = 0.051
# logical error rate for (L=5,loss_rate=0.0,depo=0.008) = 0.0526
# logical error rate for (L=5,loss_rate=0.0,depo=0.008) = 0.051
# logical error rate for (L=5,loss_rate=0.0,depo=0.008) = 0.0502
# logical error rate for (L=5,loss_rate=0.0,depo=0.008) = 0.0549
# logical error rate for (L=5,loss_rate=0.0,depo=0.008) = 0.0509
# logical error rate for (L=5,loss_rate=0.0,depo=0.008) = 0.0488
# logical error rate for (L=5,loss_rate=0.0,depo=0.008) = 0.0517
# logical error rate for (L=5,loss_rate=0.0,depo=0.008) = 0.0499
# logical error rate for (L=5,loss_rate=0.0,depo=0.008) = 0.0494
# logical error rate for (L=5,loss_rate=0.0,depo=0.009) = 0.0633
# logical error rate for (L=5,loss_rate=0.0,depo=0.009) = 0.0709
# logical error rate for (L=5,loss_rate=0.0,depo=0.009) = 0.0653
# logical error rate for (L=5,loss_rate=0.0,depo=0.009) = 0.0674
# logical error rate for (L=5,loss_rate=0.0,depo=0.009) = 0.0648
# logical error rate for (L=5,loss_rate=0.0,depo=0.009) = 0.073
# logical error rate for (L=5,loss_rate=0.0,depo=0.009) = 0.0621
# logical error rate for (L=5,loss_rate=0.0,depo=0.009) = 0.0692
# logical error rate for (L=5,loss_rate=0.0,depo=0.009) = 0.074
# logical error rate for (L=5,loss_rate=0.0,depo=0.009) = 0.0689
# logical error rate for (L=5,loss_rate=0.0,depo=0.01) = 0.0857
# logical error rate for (L=5,loss_rate=0.0,depo=0.01) = 0.0865
# logical error rate for (L=5,loss_rate=0.0,depo=0.01) = 0.084
# logical error rate for (L=5,loss_rate=0.0,depo=0.01) = 0.081
# logical error rate for (L=5,loss_rate=0.0,depo=0.01) = 0.079
# logical error rate for (L=5,loss_rate=0.0,depo=0.01) = 0.0891
# logical error rate for (L=5,loss_rate=0.0,depo=0.01) = 0.0848
# logical error rate for (L=5,loss_rate=0.0,depo=0.01) = 0.0857
# logical error rate for (L=5,loss_rate=0.0,depo=0.01) = 0.0853
# logical error rate for (L=5,loss_rate=0.0,depo=0.01) = 0.0875
# logical error rate for (L=5,loss_rate=0.0,depo=0.011) = 0.1027
# logical error rate for (L=5,loss_rate=0.0,depo=0.011) = 0.1034
# logical error rate for (L=5,loss_rate=0.0,depo=0.011) = 0.1062
# logical error rate for (L=5,loss_rate=0.0,depo=0.011) = 0.1051
# logical error rate for (L=5,loss_rate=0.0,depo=0.011) = 0.1092
# logical error rate for (L=5,loss_rate=0.0,depo=0.011) = 0.1021
# logical error rate for (L=5,loss_rate=0.0,depo=0.011) = 0.1063
# logical error rate for (L=5,loss_rate=0.0,depo=0.011) = 0.1048
# logical error rate for (L=5,loss_rate=0.0,depo=0.011) = 0.1044
# logical error rate for (L=5,loss_rate=0.0,depo=0.011) = 0.1076
# logical error rate for (L=5,loss_rate=0.0,depo=0.012) = 0.1268
# logical error rate for (L=5,loss_rate=0.0,depo=0.012) = 0.1267
# logical error rate for (L=5,loss_rate=0.0,depo=0.012) = 0.1246
# logical error rate for (L=5,loss_rate=0.0,depo=0.012) = 0.1272
# logical error rate for (L=5,loss_rate=0.0,depo=0.012) = 0.1259
# logical error rate for (L=5,loss_rate=0.0,depo=0.012) = 0.1314
# logical error rate for (L=5,loss_rate=0.0,depo=0.012) = 0.1236
# logical error rate for (L=5,loss_rate=0.0,depo=0.012) = 0.128
# logical error rate for (L=5,loss_rate=0.0,depo=0.012) = 0.1255
# logical error rate for (L=5,loss_rate=0.0,depo=0.012) = 0.1274
# logical error rate for (L=5,loss_rate=0.0,depo=0.013) = 0.1493
# logical error rate for (L=5,loss_rate=0.0,depo=0.013) = 0.1414
# logical error rate for (L=5,loss_rate=0.0,depo=0.013) = 0.1421
# logical error rate for (L=5,loss_rate=0.0,depo=0.013) = 0.1491
# logical error rate for (L=5,loss_rate=0.0,depo=0.013) = 0.1517
# logical error rate for (L=5,loss_rate=0.0,depo=0.013) = 0.1455
# logical error rate for (L=5,loss_rate=0.0,depo=0.013) = 0.1497
# logical error rate for (L=5,loss_rate=0.0,depo=0.013) = 0.15
# logical error rate for (L=5,loss_rate=0.0,depo=0.013) = 0.1479
# logical error rate for (L=5,loss_rate=0.0,depo=0.013) = 0.1445
# logical error rate for (L=5,loss_rate=0.0,depo=0.014) = 0.1754
# logical error rate for (L=5,loss_rate=0.0,depo=0.014) = 0.1664
# logical error rate for (L=5,loss_rate=0.0,depo=0.014) = 0.1689
# logical error rate for (L=5,loss_rate=0.0,depo=0.014) = 0.1658
# logical error rate for (L=5,loss_rate=0.0,depo=0.014) = 0.1714
# logical error rate for (L=5,loss_rate=0.0,depo=0.014) = 0.1708
# logical error rate for (L=5,loss_rate=0.0,depo=0.014) = 0.1695
# logical error rate for (L=5,loss_rate=0.0,depo=0.014) = 0.1758
# logical error rate for (L=5,loss_rate=0.0,depo=0.014) = 0.1647
# logical error rate for (L=5,loss_rate=0.0,depo=0.014) = 0.1743
# logical error rate for (L=5,loss_rate=0.0,depo=0.015) = 0.2001
# logical error rate for (L=5,loss_rate=0.0,depo=0.015) = 0.1958
# logical error rate for (L=5,loss_rate=0.0,depo=0.015) = 0.1911
# logical error rate for (L=5,loss_rate=0.0,depo=0.015) = 0.1893
# logical error rate for (L=5,loss_rate=0.0,depo=0.015) = 0.1847
# logical error rate for (L=5,loss_rate=0.0,depo=0.015) = 0.1922
# logical error rate for (L=5,loss_rate=0.0,depo=0.015) = 0.1936
# logical error rate for (L=5,loss_rate=0.0,depo=0.015) = 0.1943
# logical error rate for (L=5,loss_rate=0.0,depo=0.015) = 0.1936
# logical error rate for (L=5,loss_rate=0.0,depo=0.015) = 0.1875
# logical error rate for (L=5,loss_rate=0.0,depo=0.016) = 0.2104
# logical error rate for (L=5,loss_rate=0.0,depo=0.016) = 0.2106
# logical error rate for (L=5,loss_rate=0.0,depo=0.016) = 0.2104
# logical error rate for (L=5,loss_rate=0.0,depo=0.016) = 0.2126
# logical error rate for (L=5,loss_rate=0.0,depo=0.016) = 0.2164
# logical error rate for (L=5,loss_rate=0.0,depo=0.016) = 0.21
# logical error rate for (L=5,loss_rate=0.0,depo=0.016) = 0.2091
# logical error rate for (L=5,loss_rate=0.0,depo=0.016) = 0.2044
# logical error rate for (L=5,loss_rate=0.0,depo=0.016) = 0.2061
# logical error rate for (L=5,loss_rate=0.0,depo=0.016) = 0.2112
# logical error rate for (L=5,loss_rate=0.0,depo=0.017) = 0.2307
# logical error rate for (L=5,loss_rate=0.0,depo=0.017) = 0.2305
# logical error rate for (L=5,loss_rate=0.0,depo=0.017) = 0.2276
# logical error rate for (L=5,loss_rate=0.0,depo=0.017) = 0.2225
# logical error rate for (L=5,loss_rate=0.0,depo=0.017) = 0.2389
# logical error rate for (L=5,loss_rate=0.0,depo=0.017) = 0.2388
# logical error rate for (L=5,loss_rate=0.0,depo=0.017) = 0.2374
# logical error rate for (L=5,loss_rate=0.0,depo=0.017) = 0.2391
# logical error rate for (L=5,loss_rate=0.0,depo=0.017) = 0.2335
# logical error rate for (L=5,loss_rate=0.0,depo=0.017) = 0.2353
# logical error rate for (L=5,loss_rate=0.0,depo=0.018) = 0.2543
# logical error rate for (L=5,loss_rate=0.0,depo=0.018) = 0.2524
# logical error rate for (L=5,loss_rate=0.0,depo=0.018) = 0.2503
# logical error rate for (L=5,loss_rate=0.0,depo=0.018) = 0.2488
# logical error rate for (L=5,loss_rate=0.0,depo=0.018) = 0.2535
# logical error rate for (L=5,loss_rate=0.0,depo=0.018) = 0.2558
# logical error rate for (L=5,loss_rate=0.0,depo=0.018) = 0.2591
# logical error rate for (L=5,loss_rate=0.0,depo=0.018) = 0.2567
# logical error rate for (L=5,loss_rate=0.0,depo=0.018) = 0.2513
# logical error rate for (L=5,loss_rate=0.0,depo=0.018) = 0.2489
# logical error rate for (L=5,loss_rate=0.0,depo=0.019) = 0.2732
# logical error rate for (L=5,loss_rate=0.0,depo=0.019) = 0.2711
# logical error rate for (L=5,loss_rate=0.0,depo=0.019) = 0.2794
# logical error rate for (L=5,loss_rate=0.0,depo=0.019) = 0.2773
# logical error rate for (L=5,loss_rate=0.0,depo=0.019) = 0.278
# logical error rate for (L=5,loss_rate=0.0,depo=0.019) = 0.2745
# logical error rate for (L=5,loss_rate=0.0,depo=0.019) = 0.2721
# logical error rate for (L=5,loss_rate=0.0,depo=0.019) = 0.2751
# logical error rate for (L=5,loss_rate=0.0,depo=0.019) = 0.2717
# logical error rate for (L=5,loss_rate=0.0,depo=0.019) = 0.2756
# logical error rate for (L=5,loss_rate=0.0,depo=0.02) = 0.2949
# logical error rate for (L=5,loss_rate=0.0,depo=0.02) = 0.2865
# logical error rate for (L=5,loss_rate=0.0,depo=0.02) = 0.294
# logical error rate for (L=5,loss_rate=0.0,depo=0.02) = 0.2986
# logical error rate for (L=5,loss_rate=0.0,depo=0.02) = 0.2973
# logical error rate for (L=5,loss_rate=0.0,depo=0.02) = 0.2949
# logical error rate for (L=5,loss_rate=0.0,depo=0.02) = 0.289
# logical error rate for (L=5,loss_rate=0.0,depo=0.02) = 0.295
# logical error rate for (L=5,loss_rate=0.0,depo=0.02) = 0.2925
# logical error rate for (L=5,loss_rate=0.0,depo=0.02) = 0.2906
# logical error rate for (L=7,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=7,loss_rate=0.0,depo=0.002) = 0.0007
# logical error rate for (L=7,loss_rate=0.0,depo=0.002) = 0.0001
# logical error rate for (L=7,loss_rate=0.0,depo=0.002) = 0.0006
# logical error rate for (L=7,loss_rate=0.0,depo=0.002) = 0.0005
# logical error rate for (L=7,loss_rate=0.0,depo=0.002) = 0.0006
# logical error rate for (L=7,loss_rate=0.0,depo=0.002) = 0.0005
# logical error rate for (L=7,loss_rate=0.0,depo=0.002) = 0.0004
# logical error rate for (L=7,loss_rate=0.0,depo=0.002) = 0.0003
# logical error rate for (L=7,loss_rate=0.0,depo=0.002) = 0.0006
# logical error rate for (L=7,loss_rate=0.0,depo=0.002) = 0.0003
# logical error rate for (L=7,loss_rate=0.0,depo=0.003) = 0.0021
# logical error rate for (L=7,loss_rate=0.0,depo=0.003) = 0.0023
# logical error rate for (L=7,loss_rate=0.0,depo=0.003) = 0.0018
# logical error rate for (L=7,loss_rate=0.0,depo=0.003) = 0.0017
# logical error rate for (L=7,loss_rate=0.0,depo=0.003) = 0.0018
# logical error rate for (L=7,loss_rate=0.0,depo=0.003) = 0.002
# logical error rate for (L=7,loss_rate=0.0,depo=0.003) = 0.0021
# logical error rate for (L=7,loss_rate=0.0,depo=0.003) = 0.0022
# logical error rate for (L=7,loss_rate=0.0,depo=0.003) = 0.0021
# logical error rate for (L=7,loss_rate=0.0,depo=0.003) = 0.0021
# logical error rate for (L=7,loss_rate=0.0,depo=0.004) = 0.0054
# logical error rate for (L=7,loss_rate=0.0,depo=0.004) = 0.0051
# logical error rate for (L=7,loss_rate=0.0,depo=0.004) = 0.0052
# logical error rate for (L=7,loss_rate=0.0,depo=0.004) = 0.0053
# logical error rate for (L=7,loss_rate=0.0,depo=0.004) = 0.0056
# logical error rate for (L=7,loss_rate=0.0,depo=0.004) = 0.0062
# logical error rate for (L=7,loss_rate=0.0,depo=0.004) = 0.0047
# logical error rate for (L=7,loss_rate=0.0,depo=0.004) = 0.0061
# logical error rate for (L=7,loss_rate=0.0,depo=0.004) = 0.0069
# logical error rate for (L=7,loss_rate=0.0,depo=0.004) = 0.0049
# logical error rate for (L=7,loss_rate=0.0,depo=0.005) = 0.0136
# logical error rate for (L=7,loss_rate=0.0,depo=0.005) = 0.0133
# logical error rate for (L=7,loss_rate=0.0,depo=0.005) = 0.0135
# logical error rate for (L=7,loss_rate=0.0,depo=0.005) = 0.0147
# logical error rate for (L=7,loss_rate=0.0,depo=0.005) = 0.011
# logical error rate for (L=7,loss_rate=0.0,depo=0.005) = 0.0151
# logical error rate for (L=7,loss_rate=0.0,depo=0.005) = 0.0126
# logical error rate for (L=7,loss_rate=0.0,depo=0.005) = 0.0133
# logical error rate for (L=7,loss_rate=0.0,depo=0.005) = 0.0132
# logical error rate for (L=7,loss_rate=0.0,depo=0.005) = 0.0127
# logical error rate for (L=7,loss_rate=0.0,depo=0.006) = 0.0216
# logical error rate for (L=7,loss_rate=0.0,depo=0.006) = 0.0217
# logical error rate for (L=7,loss_rate=0.0,depo=0.006) = 0.0238
# logical error rate for (L=7,loss_rate=0.0,depo=0.006) = 0.023
# logical error rate for (L=7,loss_rate=0.0,depo=0.006) = 0.025
# logical error rate for (L=7,loss_rate=0.0,depo=0.006) = 0.0223
# logical error rate for (L=7,loss_rate=0.0,depo=0.006) = 0.023
# logical error rate for (L=7,loss_rate=0.0,depo=0.006) = 0.025
# logical error rate for (L=7,loss_rate=0.0,depo=0.006) = 0.0245
# logical error rate for (L=7,loss_rate=0.0,depo=0.006) = 0.0253
# logical error rate for (L=7,loss_rate=0.0,depo=0.007) = 0.0381
# logical error rate for (L=7,loss_rate=0.0,depo=0.007) = 0.0369
# logical error rate for (L=7,loss_rate=0.0,depo=0.007) = 0.0335
# logical error rate for (L=7,loss_rate=0.0,depo=0.007) = 0.0366
# logical error rate for (L=7,loss_rate=0.0,depo=0.007) = 0.0373
# logical error rate for (L=7,loss_rate=0.0,depo=0.007) = 0.0381
# logical error rate for (L=7,loss_rate=0.0,depo=0.007) = 0.0407
# logical error rate for (L=7,loss_rate=0.0,depo=0.007) = 0.0405
# logical error rate for (L=7,loss_rate=0.0,depo=0.007) = 0.0406
# logical error rate for (L=7,loss_rate=0.0,depo=0.007) = 0.0372
# logical error rate for (L=7,loss_rate=0.0,depo=0.008) = 0.0595
# logical error rate for (L=7,loss_rate=0.0,depo=0.008) = 0.06
# logical error rate for (L=7,loss_rate=0.0,depo=0.008) = 0.0536
# logical error rate for (L=7,loss_rate=0.0,depo=0.008) = 0.0575
# logical error rate for (L=7,loss_rate=0.0,depo=0.008) = 0.0595
# logical error rate for (L=7,loss_rate=0.0,depo=0.008) = 0.0566
# logical error rate for (L=7,loss_rate=0.0,depo=0.008) = 0.062
# logical error rate for (L=7,loss_rate=0.0,depo=0.008) = 0.0594
# logical error rate for (L=7,loss_rate=0.0,depo=0.008) = 0.0572
# logical error rate for (L=7,loss_rate=0.0,depo=0.008) = 0.0557
# logical error rate for (L=7,loss_rate=0.0,depo=0.009) = 0.0836
# logical error rate for (L=7,loss_rate=0.0,depo=0.009) = 0.0837
# logical error rate for (L=7,loss_rate=0.0,depo=0.009) = 0.0876
# logical error rate for (L=7,loss_rate=0.0,depo=0.009) = 0.0871
# logical error rate for (L=7,loss_rate=0.0,depo=0.009) = 0.0853
# logical error rate for (L=7,loss_rate=0.0,depo=0.009) = 0.0874
# logical error rate for (L=7,loss_rate=0.0,depo=0.009) = 0.0855
# logical error rate for (L=7,loss_rate=0.0,depo=0.009) = 0.0872
# logical error rate for (L=7,loss_rate=0.0,depo=0.009) = 0.0874
# logical error rate for (L=7,loss_rate=0.0,depo=0.009) = 0.0799
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.1149
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.1186
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.1124
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.1156
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.1124
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.1144
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.1114
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.1093
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.1135
# logical error rate for (L=7,loss_rate=0.0,depo=0.01) = 0.1103
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.1437
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.1383
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.1409
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.1361
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.1377
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.1457
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.1444
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.1434
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.1418
# logical error rate for (L=7,loss_rate=0.0,depo=0.011) = 0.1435
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.1746
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.1765
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.1734
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.1753
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.1754
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.1824
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.1799
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.1753
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.1746
# logical error rate for (L=7,loss_rate=0.0,depo=0.012) = 0.1728
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.2036
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.2131
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.2101
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.2062
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.2085
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.2121
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.2101
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.2035
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.2058
# logical error rate for (L=7,loss_rate=0.0,depo=0.013) = 0.2002
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.2406
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.2434
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.2401
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.2414
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.2427
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.2432
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.239
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.2465
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.24
# logical error rate for (L=7,loss_rate=0.0,depo=0.014) = 0.2423
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.2746
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.2709
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.2791
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.2692
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.2745
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.2741
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.2747
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.2682
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.2695
# logical error rate for (L=7,loss_rate=0.0,depo=0.015) = 0.2743
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.3015
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.3007
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.2987
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.302
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.3014
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.3093
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.3027
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.3006
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.2991
# logical error rate for (L=7,loss_rate=0.0,depo=0.016) = 0.3015
# logical error rate for (L=7,loss_rate=0.0,depo=0.017) = 0.3293
# logical error rate for (L=7,loss_rate=0.0,depo=0.017) = 0.3227
# logical error rate for (L=7,loss_rate=0.0,depo=0.017) = 0.338
# logical error rate for (L=7,loss_rate=0.0,depo=0.017) = 0.3387
# logical error rate for (L=7,loss_rate=0.0,depo=0.017) = 0.3345
# logical error rate for (L=7,loss_rate=0.0,depo=0.017) = 0.33
# logical error rate for (L=7,loss_rate=0.0,depo=0.017) = 0.336
# logical error rate for (L=7,loss_rate=0.0,depo=0.017) = 0.3341
# logical error rate for (L=7,loss_rate=0.0,depo=0.017) = 0.3395
# logical error rate for (L=7,loss_rate=0.0,depo=0.017) = 0.3351
# logical error rate for (L=7,loss_rate=0.0,depo=0.018) = 0.3484
# logical error rate for (L=7,loss_rate=0.0,depo=0.018) = 0.3636
# logical error rate for (L=7,loss_rate=0.0,depo=0.018) = 0.359
# logical error rate for (L=7,loss_rate=0.0,depo=0.018) = 0.3498
# logical error rate for (L=7,loss_rate=0.0,depo=0.018) = 0.3482
# logical error rate for (L=7,loss_rate=0.0,depo=0.018) = 0.3659
# logical error rate for (L=7,loss_rate=0.0,depo=0.018) = 0.3532
# logical error rate for (L=7,loss_rate=0.0,depo=0.018) = 0.3602
# logical error rate for (L=7,loss_rate=0.0,depo=0.018) = 0.3619
# logical error rate for (L=7,loss_rate=0.0,depo=0.018) = 0.3562
# logical error rate for (L=7,loss_rate=0.0,depo=0.019) = 0.3754
# logical error rate for (L=7,loss_rate=0.0,depo=0.019) = 0.3878
# logical error rate for (L=7,loss_rate=0.0,depo=0.019) = 0.38
# logical error rate for (L=7,loss_rate=0.0,depo=0.019) = 0.3766
# logical error rate for (L=7,loss_rate=0.0,depo=0.019) = 0.3769
# logical error rate for (L=7,loss_rate=0.0,depo=0.019) = 0.3889
# logical error rate for (L=7,loss_rate=0.0,depo=0.019) = 0.3781
# logical error rate for (L=7,loss_rate=0.0,depo=0.019) = 0.3813
# logical error rate for (L=7,loss_rate=0.0,depo=0.019) = 0.3844
# logical error rate for (L=7,loss_rate=0.0,depo=0.019) = 0.3801
# logical error rate for (L=7,loss_rate=0.0,depo=0.02) = 0.4002
# logical error rate for (L=7,loss_rate=0.0,depo=0.02) = 0.4016
# logical error rate for (L=7,loss_rate=0.0,depo=0.02) = 0.4035
# logical error rate for (L=7,loss_rate=0.0,depo=0.02) = 0.4077
# logical error rate for (L=7,loss_rate=0.0,depo=0.02) = 0.4013
# logical error rate for (L=7,loss_rate=0.0,depo=0.02) = 0.4011
# logical error rate for (L=7,loss_rate=0.0,depo=0.02) = 0.413
# logical error rate for (L=7,loss_rate=0.0,depo=0.02) = 0.4008
# logical error rate for (L=7,loss_rate=0.0,depo=0.02) = 0.402
# logical error rate for (L=7,loss_rate=0.0,depo=0.02) = 0.4059
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.001) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0002
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0001
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0002
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0001
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0002
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0002
# logical error rate for (L=9,loss_rate=0.0,depo=0.002) = 0.0001
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0012
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0009
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0014
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0008
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0005
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.001
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0011
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0004
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.001
# logical error rate for (L=9,loss_rate=0.0,depo=0.003) = 0.0011
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0039
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0038
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.004
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0032
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0033
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0031
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0033
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0023
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0032
# logical error rate for (L=9,loss_rate=0.0,depo=0.004) = 0.0032
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0079
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0092
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.009
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0087
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0083
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0086
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0102
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0096
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0094
# logical error rate for (L=9,loss_rate=0.0,depo=0.005) = 0.0108
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0207
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0193
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0204
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0204
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0198
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0212
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0169
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0219
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0196
# logical error rate for (L=9,loss_rate=0.0,depo=0.006) = 0.0208
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0382
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0378
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0377
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0386
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0356
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0373
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0373
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0355
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0337
# logical error rate for (L=9,loss_rate=0.0,depo=0.007) = 0.0346
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0604
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0662
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0601
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0634
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0636
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0666
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0617
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0589
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0628
# logical error rate for (L=9,loss_rate=0.0,depo=0.008) = 0.0632
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0918
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0917
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.1012
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0909
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0941
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0996
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0922
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0925
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.095
# logical error rate for (L=9,loss_rate=0.0,depo=0.009) = 0.0951
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.1363
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.1288
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.1322
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.1343
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.1341
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.1301
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.1287
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.1303
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.132
# logical error rate for (L=9,loss_rate=0.0,depo=0.01) = 0.1347
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.1663
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.1785
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.1804
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.1764
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.1802
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.1712
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.1776
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.1774
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.1747
# logical error rate for (L=9,loss_rate=0.0,depo=0.011) = 0.1772
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.217
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.2266
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.2206
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.2245
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.2249
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.2252
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.2129
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.218
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.2216
# logical error rate for (L=9,loss_rate=0.0,depo=0.012) = 0.2204
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.2714
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.2672
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.265
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.2626
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.2651
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.2684
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.2632
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.2636
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.268
# logical error rate for (L=9,loss_rate=0.0,depo=0.013) = 0.2701
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.3117
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.3054
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.3029
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.3076
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.3112
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.3081
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.3072
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.3086
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.3125
# logical error rate for (L=9,loss_rate=0.0,depo=0.014) = 0.3133
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.3469
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.3461
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.3371
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.3602
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.3423
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.3442
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.3453
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.3438
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.3423
# logical error rate for (L=9,loss_rate=0.0,depo=0.015) = 0.3521
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.3763
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.3847
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.3824
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.3807
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.3762
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.3796
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.3838
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.3737
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.3865
# logical error rate for (L=9,loss_rate=0.0,depo=0.016) = 0.3764
# logical error rate for (L=9,loss_rate=0.0,depo=0.017) = 0.408
# logical error rate for (L=9,loss_rate=0.0,depo=0.017) = 0.4173
# logical error rate for (L=9,loss_rate=0.0,depo=0.017) = 0.404
# logical error rate for (L=9,loss_rate=0.0,depo=0.017) = 0.4008
# logical error rate for (L=9,loss_rate=0.0,depo=0.017) = 0.4071
# ...
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.4974
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.5017
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.5065
# logical error rate for (L=9,loss_rate=0.025,depo=0.016) = 0.4965
# logical error rate for (L=9,loss_rate=0.025,depo=0.017) = 0.4989
# logical error rate for (L=9,loss_rate=0.025,depo=0.017) = 0.5027
# logical error rate for (L=9,loss_rate=0.025,depo=0.017) = 0.5004
# logical error rate for (L=9,loss_rate=0.025,depo=0.017) = 0.5044
# logical error rate for (L=9,loss_rate=0.025,depo=0.017) = 0.5088
# logical error rate for (L=9,loss_rate=0.025,depo=0.017) = 0.4995
# logical error rate for (L=9,loss_rate=0.025,depo=0.017) = 0.5047
# logical error rate for (L=9,loss_rate=0.025,depo=0.017) = 0.5047
# logical error rate for (L=9,loss_rate=0.025,depo=0.017) = 0.5005
# logical error rate for (L=9,loss_rate=0.025,depo=0.017) = 0.5018
# logical error rate for (L=9,loss_rate=0.025,depo=0.018) = 0.4992
# logical error rate for (L=9,loss_rate=0.025,depo=0.018) = 0.5028
# logical error rate for (L=9,loss_rate=0.025,depo=0.018) = 0.5042
# logical error rate for (L=9,loss_rate=0.025,depo=0.018) = 0.4965
# logical error rate for (L=9,loss_rate=0.025,depo=0.018) = 0.4949
# logical error rate for (L=9,loss_rate=0.025,depo=0.018) = 0.4935
# logical error rate for (L=9,loss_rate=0.025,depo=0.018) = 0.499
# logical error rate for (L=9,loss_rate=0.025,depo=0.018) = 0.5026
# logical error rate for (L=9,loss_rate=0.025,depo=0.018) = 0.5019
# logical error rate for (L=9,loss_rate=0.025,depo=0.018) = 0.5063
# logical error rate for (L=9,loss_rate=0.025,depo=0.019) = 0.5
# logical error rate for (L=9,loss_rate=0.025,depo=0.019) = 0.5041
# logical error rate for (L=9,loss_rate=0.025,depo=0.019) = 0.5019
# logical error rate for (L=9,loss_rate=0.025,depo=0.019) = 0.4985
# logical error rate for (L=9,loss_rate=0.025,depo=0.019) = 0.5061
# logical error rate for (L=9,loss_rate=0.025,depo=0.019) = 0.4995
# logical error rate for (L=9,loss_rate=0.025,depo=0.019) = 0.5052
# logical error rate for (L=9,loss_rate=0.025,depo=0.019) = 0.4961
# logical error rate for (L=9,loss_rate=0.025,depo=0.019) = 0.499
# logical error rate for (L=9,loss_rate=0.025,depo=0.019) = 0.4949
# logical error rate for (L=9,loss_rate=0.025,depo=0.02) = 0.5055
# logical error rate for (L=9,loss_rate=0.025,depo=0.02) = 0.4995
# logical error rate for (L=9,loss_rate=0.025,depo=0.02) = 0.5009
# logical error rate for (L=9,loss_rate=0.025,depo=0.02) = 0.5017
# logical error rate for (L=9,loss_rate=0.025,depo=0.02) = 0.4937
# logical error rate for (L=9,loss_rate=0.025,depo=0.02) = 0.5006
# logical error rate for (L=9,loss_rate=0.025,depo=0.02) = 0.5032
# logical error rate for (L=9,loss_rate=0.025,depo=0.02) = 0.5019
# logical error rate for (L=9,loss_rate=0.025,depo=0.02) = 0.5116
# logical error rate for (L=9,loss_rate=0.025,depo=0.02) = 0.4954
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.4997
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.4984
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.4938
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.4944
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.503
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.5025
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.4993
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.5037
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.4939
# logical error rate for (L=11,loss_rate=0.025,depo=0.001) = 0.5006
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.4945
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.4962
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.5041
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.5063
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.4935
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.5071
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.5014
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.5025
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.5005
# logical error rate for (L=11,loss_rate=0.025,depo=0.002) = 0.4967
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.5078
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.498
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.502
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.4997
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.4992
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.4978
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.5075
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.498
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.5044
# logical error rate for (L=11,loss_rate=0.025,depo=0.003) = 0.5081
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.502
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5091
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.4947
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5123
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5057
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5001
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.4999
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.5001
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.4998
# logical error rate for (L=11,loss_rate=0.025,depo=0.004) = 0.506
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.4981
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.4977
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.5015
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.4994
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.4994
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.4992
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.5023
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.4972
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.5012
# logical error rate for (L=11,loss_rate=0.025,depo=0.005) = 0.5
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.4951
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.4987
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.4933
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.5029
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.5036
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.5045
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.4986
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.4974
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.501
# logical error rate for (L=11,loss_rate=0.025,depo=0.006) = 0.4923
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.5019
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.5132
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.4876
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.4959
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.5139
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.498
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.4927
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.5
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.4958
# logical error rate for (L=11,loss_rate=0.025,depo=0.007) = 0.5016
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.5023
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.4975
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.4956
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.4988
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.5068
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.4986
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.5108
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.507
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.507
# logical error rate for (L=11,loss_rate=0.025,depo=0.008) = 0.4975
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.5096
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.5037
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.5031
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.4979
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.5027
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.5024
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.4954
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.5008
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.4907
# logical error rate for (L=11,loss_rate=0.025,depo=0.009) = 0.5036
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.508
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.4979
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.5033
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.5041
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.501
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.4976
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.5031
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.5138
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.4988
# logical error rate for (L=11,loss_rate=0.025,depo=0.01) = 0.5079
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.4942
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.4935
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.5061
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.4998
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.5031
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.495
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.4999
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.5003
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.5028
# logical error rate for (L=11,loss_rate=0.025,depo=0.011) = 0.4954
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.5056
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.4991
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.4991
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.5019
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.4882
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.4979
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.4975
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.4973
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.5004
# logical error rate for (L=11,loss_rate=0.025,depo=0.012) = 0.4923
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.5033
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.5004
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.5104
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.4926
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.4934
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.4982
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.493
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.499
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.5022
# logical error rate for (L=11,loss_rate=0.025,depo=0.013) = 0.4932
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.496
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.5023
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.4973
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.4941
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.5102
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.5001
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.4994
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.498
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.5019
# logical error rate for (L=11,loss_rate=0.025,depo=0.014) = 0.5024
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.4968
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.4954
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.5033
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.5026
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.5007
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.5061
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.4955
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.4954
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.5082
# logical error rate for (L=11,loss_rate=0.025,depo=0.015) = 0.497
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.4911
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.5093
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.5016
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.5133
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.5046
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.5047
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.5012
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.4888
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.5008
# logical error rate for (L=11,loss_rate=0.025,depo=0.016) = 0.499
# logical error rate for (L=11,loss_rate=0.025,depo=0.017) = 0.5011
# logical error rate for (L=11,loss_rate=0.025,depo=0.017) = 0.501
# logical error rate for (L=11,loss_rate=0.025,depo=0.017) = 0.5023
# logical error rate for (L=11,loss_rate=0.025,depo=0.017) = 0.4901
# logical error rate for (L=11,loss_rate=0.025,depo=0.017) = 0.5053
# logical error rate for (L=11,loss_rate=0.025,depo=0.017) = 0.507
# logical error rate for (L=11,loss_rate=0.025,depo=0.017) = 0.5047
# logical error rate for (L=11,loss_rate=0.025,depo=0.017) = 0.4984
# logical error rate for (L=11,loss_rate=0.025,depo=0.017) = 0.5036
# logical error rate for (L=11,loss_rate=0.025,depo=0.017) = 0.4996
# logical error rate for (L=11,loss_rate=0.025,depo=0.018) = 0.4956
# logical error rate for (L=11,loss_rate=0.025,depo=0.018) = 0.4868
# logical error rate for (L=11,loss_rate=0.025,depo=0.018) = 0.4946
# logical error rate for (L=11,loss_rate=0.025,depo=0.018) = 0.5024
# logical error rate for (L=11,loss_rate=0.025,depo=0.018) = 0.5023
# logical error rate for (L=11,loss_rate=0.025,depo=0.018) = 0.4954
# logical error rate for (L=11,loss_rate=0.025,depo=0.018) = 0.5003
# logical error rate for (L=11,loss_rate=0.025,depo=0.018) = 0.5059
# logical error rate for (L=11,loss_rate=0.025,depo=0.018) = 0.4966
# logical error rate for (L=11,loss_rate=0.025,depo=0.018) = 0.5026
# logical error rate for (L=11,loss_rate=0.025,depo=0.019) = 0.5005
# logical error rate for (L=11,loss_rate=0.025,depo=0.019) = 0.5089
# logical error rate for (L=11,loss_rate=0.025,depo=0.019) = 0.4924
# logical error rate for (L=11,loss_rate=0.025,depo=0.019) = 0.4977
# logical error rate for (L=11,loss_rate=0.025,depo=0.019) = 0.4985
# logical error rate for (L=11,loss_rate=0.025,depo=0.019) = 0.4926
# logical error rate for (L=11,loss_rate=0.025,depo=0.019) = 0.5001
# logical error rate for (L=11,loss_rate=0.025,depo=0.019) = 0.5032
# logical error rate for (L=11,loss_rate=0.025,depo=0.019) = 0.4924
# logical error rate for (L=11,loss_rate=0.025,depo=0.019) = 0.506
# logical error rate for (L=11,loss_rate=0.025,depo=0.02) = 0.4988
# logical error rate for (L=11,loss_rate=0.025,depo=0.02) = 0.4988
# logical error rate for (L=11,loss_rate=0.025,depo=0.02) = 0.4915
# logical error rate for (L=11,loss_rate=0.025,depo=0.02) = 0.5028
# logical error rate for (L=11,loss_rate=0.025,depo=0.02) = 0.4933
# logical error rate for (L=11,loss_rate=0.025,depo=0.02) = 0.503
# logical error rate for (L=11,loss_rate=0.025,depo=0.02) = 0.5035
# logical error rate for (L=11,loss_rate=0.025,depo=0.02) = 0.5015
# logical error rate for (L=11,loss_rate=0.025,depo=0.02) = 0.5059
# logical error rate for (L=11,loss_rate=0.025,depo=0.02) = 0.505

# %%
#function for simulation

#Compute the logical error rate of the surface code supplemented with the standard LDU for a given noise and loss probability using a naive decoder
#stored as a dictionnary in a file for a fixed depolarizing noise probability and various loss probabilities

def simulation_code_fixed_depo(L,loss,depo,num_shots):
    loss=round(loss,5)
    depo=round(depo,5)
    lattice = Rotated_Surface_Code_standard_LDU(L,L,L,'|0>','Z',measurement_order='z_first',loss_rate=loss,after_CZ=('DEPOLARIZE2',depo))
    dem_build=DEM_builder(lattice)
    path_dem='data/dem/naive_dem_standard_LDU/DEM_surface_code_({},{},{})_loss_rate={}.dem'.format(lattice.width,lattice.height,lattice.rounds,lattice.loss_rate)
    
    error_rate=dem_build.naive_logical_errors(num_shots,path_dem)
    
    if os.path.exists('data/logical_error/naive_logical_error_standard_LDU_d=({},{})_rounds={}_depo_noise={}.pkl'.format(L,L,L,depo)):
        with open('data/logical_error/naive_logical_error_standard_LDU_d=({},{})_rounds={}_depo_noise={}.pkl'.format(L,L,L,depo), 'rb') as fp:
            data_saved=pickle.load(fp)
        
    else:
        data_saved={}
    if loss not in data_saved.keys():#CREATE DICTIONNARY if the loss probability has never been computed
        data_saved[loss]={}
        data_saved[loss]['num_shots']=num_shots
        data_saved[loss]['error_rate']=error_rate
    else:#UPDATE DICTIONNARY if there has been already simulation for that given loss and noise probability
        data_saved[loss]['error_rate']*=data_saved[loss]['num_shots']/(data_saved[loss]['num_shots']+num_shots)
        data_saved[loss]['error_rate']+=error_rate*num_shots/(data_saved[loss]['num_shots']+num_shots)
        data_saved[loss]['num_shots']+=num_shots
    
    #stored in a file for a given loss and various noise probabilities
    with open('data/logical_error/naive_logical_error_standard_LDU_d=({},{})_rounds={}_depo_noise={}.pkl'.format(L,L,L,depo), 'wb') as fp:
        pickle.dump(data_saved, fp)

    print('logical error rate for (L={},loss_rate={},depo={}) = {}'.format(L,loss,depo,error_rate))
    

#wrapper to one argument (needed for parallelization)    
def multi_args_wrapper_fixed_depo(args):
   simulation_code_fixed_depo(*args)

# %%
#Compute the logical error rate and store as a dictionnary in files with a fixed depolarizing noise probabilities

Ls = range(3,13,2)
loss_list = np.linspace(0.001, 0.03, 30)
depo=0.0
num_shots = 10000 #number of shots per core
nb_core=10  #number of cores used

for L in Ls:
    for loss_rate in loss_list:
        with Pool(processes=nb_core) as pool:
            pool.imap(multi_args_wrapper_fixed_depo,[(L,loss_rate,depo,num_shots) for _ in range(10)])
            pool.close()
            pool.join()
# Out:
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.002
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0017
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0018
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0014
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0014
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.002
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0021
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0016
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0022
# logical error rate for (L=3,loss_rate=0.001,depo=0.0) = 0.0021
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0053
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0051
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0057
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0063
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0046
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0052
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0062
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0045
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0049
# logical error rate for (L=3,loss_rate=0.002,depo=0.0) = 0.0055
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0082
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0103
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0091
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0088
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0085
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0105
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0108
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0089
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0093
# logical error rate for (L=3,loss_rate=0.003,depo=0.0) = 0.0078
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0131
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.015
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.017
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0148
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0153
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.012
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0152
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.016
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0156
# logical error rate for (L=3,loss_rate=0.004,depo=0.0) = 0.0144
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0214
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0192
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0195
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0192
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0198
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0214
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0183
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.02
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0207
# logical error rate for (L=3,loss_rate=0.005,depo=0.0) = 0.0198
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0271
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0262
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0271
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0285
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0289
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0304
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0244
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0297
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0255
# logical error rate for (L=3,loss_rate=0.006,depo=0.0) = 0.0274
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0346
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0361
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0356
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0355
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0357
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0341
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0353
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0329
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0347
# logical error rate for (L=3,loss_rate=0.007,depo=0.0) = 0.0363
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0418
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0438
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0424
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0407
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0451
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0402
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.039
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0417
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0436
# logical error rate for (L=3,loss_rate=0.008,depo=0.0) = 0.0431
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0506
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0483
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0465
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0487
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.053
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0491
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0576
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0511
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0495
# logical error rate for (L=3,loss_rate=0.009,depo=0.0) = 0.0511
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0603
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0614
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0575
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0572
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0548
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.059
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0544
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0591
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.0581
# logical error rate for (L=3,loss_rate=0.01,depo=0.0) = 0.058
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0649
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0717
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0682
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0715
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0699
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0662
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0636
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0665
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0647
# logical error rate for (L=3,loss_rate=0.011,depo=0.0) = 0.0657
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0744
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0773
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0752
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0764
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0785
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0779
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0769
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0778
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0753
# logical error rate for (L=3,loss_rate=0.012,depo=0.0) = 0.0804
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0854
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.087
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0859
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0827
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0905
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0858
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0851
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0857
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0873
# logical error rate for (L=3,loss_rate=0.013,depo=0.0) = 0.0844
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0904
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.1035
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0961
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.097
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.091
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0957
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0934
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0983
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0932
# logical error rate for (L=3,loss_rate=0.014,depo=0.0) = 0.0926
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.1069
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.1086
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.1073
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.1107
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.1058
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.1041
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.1077
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.1117
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.1051
# logical error rate for (L=3,loss_rate=0.015,depo=0.0) = 0.1047
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.1169
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.1116
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.1163
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.1153
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.1161
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.1117
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.1159
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.1174
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.1166
# logical error rate for (L=3,loss_rate=0.016,depo=0.0) = 0.1174
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.1253
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.1307
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.1244
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.1308
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.125
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.1243
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.1288
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.1286
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.1251
# logical error rate for (L=3,loss_rate=0.017,depo=0.0) = 0.1309
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.1365
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.1389
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.1341
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.1339
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.131
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.1391
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.1387
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.1294
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.1421
# logical error rate for (L=3,loss_rate=0.018,depo=0.0) = 0.1292
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.1465
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.1468
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.1426
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.1462
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.145
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.1423
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.1436
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.1449
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.1442
# logical error rate for (L=3,loss_rate=0.019,depo=0.0) = 0.147
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.1554
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.1568
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.161
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.1518
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.1576
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.1527
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.1535
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.1589
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.1638
# logical error rate for (L=3,loss_rate=0.02,depo=0.0) = 0.1598
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.1676
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.1694
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.1651
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.1549
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.1641
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.1597
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.1691
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.1618
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.1612
# logical error rate for (L=3,loss_rate=0.021,depo=0.0) = 0.1667
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.1716
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.1754
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.1774
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.1744
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.1755
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.1766
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.1773
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.1767
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.1756
# logical error rate for (L=3,loss_rate=0.022,depo=0.0) = 0.1809
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.1827
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.1796
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.1928
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.1837
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.1929
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.182
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.1849
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.1786
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.1799
# logical error rate for (L=3,loss_rate=0.023,depo=0.0) = 0.1886
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.1935
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.1981
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.1952
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.1951
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.1931
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.198
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.197
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.1925
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.198
# logical error rate for (L=3,loss_rate=0.024,depo=0.0) = 0.1968
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.2066
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.1975
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.1968
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.2036
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.2059
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.204
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.2074
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.2073
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.2059
# logical error rate for (L=3,loss_rate=0.025,depo=0.0) = 0.2044
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0006
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0004
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0007
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0005
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0004
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0007
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0004
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0002
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0005
# logical error rate for (L=5,loss_rate=0.001,depo=0.0) = 0.0002
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0025
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0028
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0019
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0018
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0031
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0022
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0027
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0022
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0022
# logical error rate for (L=5,loss_rate=0.002,depo=0.0) = 0.0024
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0079
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0071
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0046
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0056
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0065
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0053
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0082
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0085
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0083
# logical error rate for (L=5,loss_rate=0.003,depo=0.0) = 0.0067
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0144
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0125
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0132
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0143
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0129
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0143
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0127
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.012
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.0154
# logical error rate for (L=5,loss_rate=0.004,depo=0.0) = 0.016
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0238
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0252
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0256
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.022
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0232
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0229
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0262
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.02
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0257
# logical error rate for (L=5,loss_rate=0.005,depo=0.0) = 0.0208
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0372
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0327
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0324
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0352
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0375
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0345
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0345
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.038
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0363
# logical error rate for (L=5,loss_rate=0.006,depo=0.0) = 0.0349
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0502
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0505
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.056
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0504
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0521
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0527
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0533
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0499
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0505
# logical error rate for (L=5,loss_rate=0.007,depo=0.0) = 0.0486
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0678
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0646
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0674
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0668
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0689
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0695
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0704
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0703
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0691
# logical error rate for (L=5,loss_rate=0.008,depo=0.0) = 0.0694
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0894
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0909
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0887
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0873
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0839
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0859
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0859
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0839
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0888
# logical error rate for (L=5,loss_rate=0.009,depo=0.0) = 0.0872
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.114
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.1125
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.1123
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.1059
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.1017
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.1049
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.1108
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.1173
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.1115
# logical error rate for (L=5,loss_rate=0.01,depo=0.0) = 0.1088
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.1384
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.1327
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.1325
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.1327
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.1288
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.1328
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.1293
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.1283
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.1318
# logical error rate for (L=5,loss_rate=0.011,depo=0.0) = 0.129
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.1575
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.15
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.1525
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.1543
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.1514
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.152
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.1588
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.1502
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.1485
# logical error rate for (L=5,loss_rate=0.012,depo=0.0) = 0.1569
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.1812
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.1771
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.1787
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.1795
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.1757
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.1744
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.177
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.1677
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.171
# logical error rate for (L=5,loss_rate=0.013,depo=0.0) = 0.1725
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.1971
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.1998
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.1965
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.2075
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.1991
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.1986
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.2039
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.1939
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.1982
# logical error rate for (L=5,loss_rate=0.014,depo=0.0) = 0.2013
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.2272
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.2266
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.2232
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.2232
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.2191
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.221
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.2204
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.2192
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.2243
# logical error rate for (L=5,loss_rate=0.015,depo=0.0) = 0.2158
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.2459
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.2419
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.2503
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.2469
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.2435
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.2473
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.2411
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.2413
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.2501
# logical error rate for (L=5,loss_rate=0.016,depo=0.0) = 0.2399
# logical error rate for (L=5,loss_rate=0.017,depo=0.0) = 0.2692
# logical error rate for (L=5,loss_rate=0.017,depo=0.0) = 0.2702
# logical error rate for (L=5,loss_rate=0.017,depo=0.0) = 0.2706
# logical error rate for (L=5,loss_rate=0.017,depo=0.0) = 0.266
# logical error rate for (L=5,loss_rate=0.017,depo=0.0) = 0.2646
# logical error rate for (L=5,loss_rate=0.017,depo=0.0) = 0.2609
# logical error rate for (L=5,loss_rate=0.017,depo=0.0) = 0.2654
# logical error rate for (L=5,loss_rate=0.017,depo=0.0) = 0.2656
# logical error rate for (L=5,loss_rate=0.017,depo=0.0) = 0.2682
# logical error rate for (L=5,loss_rate=0.017,depo=0.0) = 0.2698
# logical error rate for (L=5,loss_rate=0.018,depo=0.0) = 0.2905
# logical error rate for (L=5,loss_rate=0.018,depo=0.0) = 0.293
# logical error rate for (L=5,loss_rate=0.018,depo=0.0) = 0.2883
# logical error rate for (L=5,loss_rate=0.018,depo=0.0) = 0.2981
# logical error rate for (L=5,loss_rate=0.018,depo=0.0) = 0.2951
# logical error rate for (L=5,loss_rate=0.018,depo=0.0) = 0.2861
# logical error rate for (L=5,loss_rate=0.018,depo=0.0) = 0.2899
# logical error rate for (L=5,loss_rate=0.018,depo=0.0) = 0.2937
# logical error rate for (L=5,loss_rate=0.018,depo=0.0) = 0.2869
# logical error rate for (L=5,loss_rate=0.018,depo=0.0) = 0.2979
# logical error rate for (L=5,loss_rate=0.019,depo=0.0) = 0.3158
# logical error rate for (L=5,loss_rate=0.019,depo=0.0) = 0.3066
# logical error rate for (L=5,loss_rate=0.019,depo=0.0) = 0.3135
# logical error rate for (L=5,loss_rate=0.019,depo=0.0) = 0.3094
# logical error rate for (L=5,loss_rate=0.019,depo=0.0) = 0.3168
# logical error rate for (L=5,loss_rate=0.019,depo=0.0) = 0.3073
# logical error rate for (L=5,loss_rate=0.019,depo=0.0) = 0.3116
# logical error rate for (L=5,loss_rate=0.019,depo=0.0) = 0.3033
# logical error rate for (L=5,loss_rate=0.019,depo=0.0) = 0.3092
# logical error rate for (L=5,loss_rate=0.019,depo=0.0) = 0.3071
# logical error rate for (L=5,loss_rate=0.02,depo=0.0) = 0.3257
# logical error rate for (L=5,loss_rate=0.02,depo=0.0) = 0.3236
# logical error rate for (L=5,loss_rate=0.02,depo=0.0) = 0.3287
# logical error rate for (L=5,loss_rate=0.02,depo=0.0) = 0.323
# logical error rate for (L=5,loss_rate=0.02,depo=0.0) = 0.324
# logical error rate for (L=5,loss_rate=0.02,depo=0.0) = 0.329
# logical error rate for (L=5,loss_rate=0.02,depo=0.0) = 0.3309
# logical error rate for (L=5,loss_rate=0.02,depo=0.0) = 0.3206
# logical error rate for (L=5,loss_rate=0.02,depo=0.0) = 0.3307
# logical error rate for (L=5,loss_rate=0.02,depo=0.0) = 0.3184
# logical error rate for (L=5,loss_rate=0.021,depo=0.0) = 0.3518
# logical error rate for (L=5,loss_rate=0.021,depo=0.0) = 0.3412
# logical error rate for (L=5,loss_rate=0.021,depo=0.0) = 0.341
# logical error rate for (L=5,loss_rate=0.021,depo=0.0) = 0.339
# logical error rate for (L=5,loss_rate=0.021,depo=0.0) = 0.342
# logical error rate for (L=5,loss_rate=0.021,depo=0.0) = 0.3375
# logical error rate for (L=5,loss_rate=0.021,depo=0.0) = 0.3447
# logical error rate for (L=5,loss_rate=0.021,depo=0.0) = 0.3412
# logical error rate for (L=5,loss_rate=0.021,depo=0.0) = 0.3471
# logical error rate for (L=5,loss_rate=0.021,depo=0.0) = 0.3476
# logical error rate for (L=5,loss_rate=0.022,depo=0.0) = 0.3673
# logical error rate for (L=5,loss_rate=0.022,depo=0.0) = 0.3653
# logical error rate for (L=5,loss_rate=0.022,depo=0.0) = 0.3584
# logical error rate for (L=5,loss_rate=0.022,depo=0.0) = 0.3584
# logical error rate for (L=5,loss_rate=0.022,depo=0.0) = 0.3527
# logical error rate for (L=5,loss_rate=0.022,depo=0.0) = 0.3573
# logical error rate for (L=5,loss_rate=0.022,depo=0.0) = 0.3626
# logical error rate for (L=5,loss_rate=0.022,depo=0.0) = 0.3575
# logical error rate for (L=5,loss_rate=0.022,depo=0.0) = 0.3553
# logical error rate for (L=5,loss_rate=0.022,depo=0.0) = 0.361
# logical error rate for (L=5,loss_rate=0.023,depo=0.0) = 0.3738
# logical error rate for (L=5,loss_rate=0.023,depo=0.0) = 0.3797
# logical error rate for (L=5,loss_rate=0.023,depo=0.0) = 0.3794
# logical error rate for (L=5,loss_rate=0.023,depo=0.0) = 0.376
# logical error rate for (L=5,loss_rate=0.023,depo=0.0) = 0.3777
# logical error rate for (L=5,loss_rate=0.023,depo=0.0) = 0.359
# logical error rate for (L=5,loss_rate=0.023,depo=0.0) = 0.3697
# logical error rate for (L=5,loss_rate=0.023,depo=0.0) = 0.374
# logical error rate for (L=5,loss_rate=0.023,depo=0.0) = 0.3788
# logical error rate for (L=5,loss_rate=0.023,depo=0.0) = 0.379
# logical error rate for (L=5,loss_rate=0.024,depo=0.0) = 0.3841
# logical error rate for (L=5,loss_rate=0.024,depo=0.0) = 0.3932
# logical error rate for (L=5,loss_rate=0.024,depo=0.0) = 0.3949
# logical error rate for (L=5,loss_rate=0.024,depo=0.0) = 0.3856
# logical error rate for (L=5,loss_rate=0.024,depo=0.0) = 0.3941
# logical error rate for (L=5,loss_rate=0.024,depo=0.0) = 0.3847
# logical error rate for (L=5,loss_rate=0.024,depo=0.0) = 0.3852
# logical error rate for (L=5,loss_rate=0.024,depo=0.0) = 0.3831
# logical error rate for (L=5,loss_rate=0.024,depo=0.0) = 0.3939
# logical error rate for (L=5,loss_rate=0.024,depo=0.0) = 0.3907
# logical error rate for (L=5,loss_rate=0.025,depo=0.0) = 0.4027
# logical error rate for (L=5,loss_rate=0.025,depo=0.0) = 0.4
# logical error rate for (L=5,loss_rate=0.025,depo=0.0) = 0.3998
# logical error rate for (L=5,loss_rate=0.025,depo=0.0) = 0.4033
# logical error rate for (L=5,loss_rate=0.025,depo=0.0) = 0.3912
# logical error rate for (L=5,loss_rate=0.025,depo=0.0) = 0.404
# logical error rate for (L=5,loss_rate=0.025,depo=0.0) = 0.4047
# logical error rate for (L=5,loss_rate=0.025,depo=0.0) = 0.3957
# logical error rate for (L=5,loss_rate=0.025,depo=0.0) = 0.4028
# logical error rate for (L=5,loss_rate=0.025,depo=0.0) = 0.4059
# logical error rate for (L=7,loss_rate=0.001,depo=0.0) = 0.0002
# logical error rate for (L=7,loss_rate=0.001,depo=0.0) = 0.0001
# logical error rate for (L=7,loss_rate=0.001,depo=0.0) = 0.0001
# logical error rate for (L=7,loss_rate=0.001,depo=0.0) = 0.0003
# logical error rate for (L=7,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=7,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=7,loss_rate=0.001,depo=0.0) = 0.0002
# logical error rate for (L=7,loss_rate=0.001,depo=0.0) = 0.0002
# logical error rate for (L=7,loss_rate=0.001,depo=0.0) = 0.0001
# logical error rate for (L=7,loss_rate=0.001,depo=0.0) = 0.0001
# logical error rate for (L=7,loss_rate=0.002,depo=0.0) = 0.0013
# logical error rate for (L=7,loss_rate=0.002,depo=0.0) = 0.001
# logical error rate for (L=7,loss_rate=0.002,depo=0.0) = 0.0013
# logical error rate for (L=7,loss_rate=0.002,depo=0.0) = 0.0009
# logical error rate for (L=7,loss_rate=0.002,depo=0.0) = 0.001
# logical error rate for (L=7,loss_rate=0.002,depo=0.0) = 0.0012
# logical error rate for (L=7,loss_rate=0.002,depo=0.0) = 0.0005
# logical error rate for (L=7,loss_rate=0.002,depo=0.0) = 0.0005
# logical error rate for (L=7,loss_rate=0.002,depo=0.0) = 0.001
# logical error rate for (L=7,loss_rate=0.002,depo=0.0) = 0.0012
# logical error rate for (L=7,loss_rate=0.003,depo=0.0) = 0.0034
# logical error rate for (L=7,loss_rate=0.003,depo=0.0) = 0.0035
# logical error rate for (L=7,loss_rate=0.003,depo=0.0) = 0.0045
# logical error rate for (L=7,loss_rate=0.003,depo=0.0) = 0.0033
# logical error rate for (L=7,loss_rate=0.003,depo=0.0) = 0.0038
# logical error rate for (L=7,loss_rate=0.003,depo=0.0) = 0.0039
# logical error rate for (L=7,loss_rate=0.003,depo=0.0) = 0.0049
# logical error rate for (L=7,loss_rate=0.003,depo=0.0) = 0.0034
# logical error rate for (L=7,loss_rate=0.003,depo=0.0) = 0.0042
# logical error rate for (L=7,loss_rate=0.003,depo=0.0) = 0.0037
# logical error rate for (L=7,loss_rate=0.004,depo=0.0) = 0.0072
# logical error rate for (L=7,loss_rate=0.004,depo=0.0) = 0.0096
# logical error rate for (L=7,loss_rate=0.004,depo=0.0) = 0.0099
# logical error rate for (L=7,loss_rate=0.004,depo=0.0) = 0.0094
# logical error rate for (L=7,loss_rate=0.004,depo=0.0) = 0.0119
# logical error rate for (L=7,loss_rate=0.004,depo=0.0) = 0.0116
# logical error rate for (L=7,loss_rate=0.004,depo=0.0) = 0.0095
# logical error rate for (L=7,loss_rate=0.004,depo=0.0) = 0.0075
# logical error rate for (L=7,loss_rate=0.004,depo=0.0) = 0.0087
# logical error rate for (L=7,loss_rate=0.004,depo=0.0) = 0.0092
# logical error rate for (L=7,loss_rate=0.005,depo=0.0) = 0.0209
# logical error rate for (L=7,loss_rate=0.005,depo=0.0) = 0.0213
# logical error rate for (L=7,loss_rate=0.005,depo=0.0) = 0.0199
# logical error rate for (L=7,loss_rate=0.005,depo=0.0) = 0.0201
# logical error rate for (L=7,loss_rate=0.005,depo=0.0) = 0.0214
# logical error rate for (L=7,loss_rate=0.005,depo=0.0) = 0.0203
# logical error rate for (L=7,loss_rate=0.005,depo=0.0) = 0.0228
# logical error rate for (L=7,loss_rate=0.005,depo=0.0) = 0.0207
# logical error rate for (L=7,loss_rate=0.005,depo=0.0) = 0.0193
# logical error rate for (L=7,loss_rate=0.005,depo=0.0) = 0.0211
# logical error rate for (L=7,loss_rate=0.006,depo=0.0) = 0.034
# logical error rate for (L=7,loss_rate=0.006,depo=0.0) = 0.0378
# logical error rate for (L=7,loss_rate=0.006,depo=0.0) = 0.0347
# logical error rate for (L=7,loss_rate=0.006,depo=0.0) = 0.0349
# logical error rate for (L=7,loss_rate=0.006,depo=0.0) = 0.0373
# logical error rate for (L=7,loss_rate=0.006,depo=0.0) = 0.0392
# logical error rate for (L=7,loss_rate=0.006,depo=0.0) = 0.0363
# logical error rate for (L=7,loss_rate=0.006,depo=0.0) = 0.0376
# logical error rate for (L=7,loss_rate=0.006,depo=0.0) = 0.033
# logical error rate for (L=7,loss_rate=0.006,depo=0.0) = 0.0396
# logical error rate for (L=7,loss_rate=0.007,depo=0.0) = 0.0574
# logical error rate for (L=7,loss_rate=0.007,depo=0.0) = 0.0568
# logical error rate for (L=7,loss_rate=0.007,depo=0.0) = 0.0564
# logical error rate for (L=7,loss_rate=0.007,depo=0.0) = 0.059
# logical error rate for (L=7,loss_rate=0.007,depo=0.0) = 0.0549
# logical error rate for (L=7,loss_rate=0.007,depo=0.0) = 0.054
# logical error rate for (L=7,loss_rate=0.007,depo=0.0) = 0.0574
# logical error rate for (L=7,loss_rate=0.007,depo=0.0) = 0.0592
# logical error rate for (L=7,loss_rate=0.007,depo=0.0) = 0.0582
# logical error rate for (L=7,loss_rate=0.007,depo=0.0) = 0.059
# logical error rate for (L=7,loss_rate=0.008,depo=0.0) = 0.0791
# logical error rate for (L=7,loss_rate=0.008,depo=0.0) = 0.0871
# logical error rate for (L=7,loss_rate=0.008,depo=0.0) = 0.0794
# logical error rate for (L=7,loss_rate=0.008,depo=0.0) = 0.0897
# logical error rate for (L=7,loss_rate=0.008,depo=0.0) = 0.0856
# logical error rate for (L=7,loss_rate=0.008,depo=0.0) = 0.086
# logical error rate for (L=7,loss_rate=0.008,depo=0.0) = 0.0851
# logical error rate for (L=7,loss_rate=0.008,depo=0.0) = 0.0827
# logical error rate for (L=7,loss_rate=0.008,depo=0.0) = 0.0838
# logical error rate for (L=7,loss_rate=0.008,depo=0.0) = 0.0808
# logical error rate for (L=7,loss_rate=0.009,depo=0.0) = 0.1152
# logical error rate for (L=7,loss_rate=0.009,depo=0.0) = 0.1157
# logical error rate for (L=7,loss_rate=0.009,depo=0.0) = 0.1164
# logical error rate for (L=7,loss_rate=0.009,depo=0.0) = 0.1195
# logical error rate for (L=7,loss_rate=0.009,depo=0.0) = 0.1146
# logical error rate for (L=7,loss_rate=0.009,depo=0.0) = 0.1174
# logical error rate for (L=7,loss_rate=0.009,depo=0.0) = 0.1159
# logical error rate for (L=7,loss_rate=0.009,depo=0.0) = 0.118
# logical error rate for (L=7,loss_rate=0.009,depo=0.0) = 0.1127
# logical error rate for (L=7,loss_rate=0.009,depo=0.0) = 0.1261
# logical error rate for (L=7,loss_rate=0.01,depo=0.0) = 0.1523
# logical error rate for (L=7,loss_rate=0.01,depo=0.0) = 0.1502
# logical error rate for (L=7,loss_rate=0.01,depo=0.0) = 0.1523
# logical error rate for (L=7,loss_rate=0.01,depo=0.0) = 0.1515
# logical error rate for (L=7,loss_rate=0.01,depo=0.0) = 0.1549
# logical error rate for (L=7,loss_rate=0.01,depo=0.0) = 0.1528
# logical error rate for (L=7,loss_rate=0.01,depo=0.0) = 0.1563
# logical error rate for (L=7,loss_rate=0.01,depo=0.0) = 0.1491
# logical error rate for (L=7,loss_rate=0.01,depo=0.0) = 0.1512
# logical error rate for (L=7,loss_rate=0.01,depo=0.0) = 0.1496
# logical error rate for (L=7,loss_rate=0.011,depo=0.0) = 0.1813
# logical error rate for (L=7,loss_rate=0.011,depo=0.0) = 0.1846
# logical error rate for (L=7,loss_rate=0.011,depo=0.0) = 0.1882
# logical error rate for (L=7,loss_rate=0.011,depo=0.0) = 0.1928
# logical error rate for (L=7,loss_rate=0.011,depo=0.0) = 0.1836
# logical error rate for (L=7,loss_rate=0.011,depo=0.0) = 0.1894
# logical error rate for (L=7,loss_rate=0.011,depo=0.0) = 0.1899
# logical error rate for (L=7,loss_rate=0.011,depo=0.0) = 0.19
# logical error rate for (L=7,loss_rate=0.011,depo=0.0) = 0.1823
# logical error rate for (L=7,loss_rate=0.011,depo=0.0) = 0.1877
# logical error rate for (L=7,loss_rate=0.012,depo=0.0) = 0.2175
# logical error rate for (L=7,loss_rate=0.012,depo=0.0) = 0.2229
# logical error rate for (L=7,loss_rate=0.012,depo=0.0) = 0.2277
# logical error rate for (L=7,loss_rate=0.012,depo=0.0) = 0.2152
# logical error rate for (L=7,loss_rate=0.012,depo=0.0) = 0.2334
# logical error rate for (L=7,loss_rate=0.012,depo=0.0) = 0.2182
# logical error rate for (L=7,loss_rate=0.012,depo=0.0) = 0.2272
# logical error rate for (L=7,loss_rate=0.012,depo=0.0) = 0.2266
# logical error rate for (L=7,loss_rate=0.012,depo=0.0) = 0.2236
# logical error rate for (L=7,loss_rate=0.012,depo=0.0) = 0.2167
# logical error rate for (L=7,loss_rate=0.013,depo=0.0) = 0.2598
# logical error rate for (L=7,loss_rate=0.013,depo=0.0) = 0.259
# logical error rate for (L=7,loss_rate=0.013,depo=0.0) = 0.2499
# logical error rate for (L=7,loss_rate=0.013,depo=0.0) = 0.2571
# logical error rate for (L=7,loss_rate=0.013,depo=0.0) = 0.2643
# logical error rate for (L=7,loss_rate=0.013,depo=0.0) = 0.2554
# logical error rate for (L=7,loss_rate=0.013,depo=0.0) = 0.2585
# logical error rate for (L=7,loss_rate=0.013,depo=0.0) = 0.2548
# logical error rate for (L=7,loss_rate=0.013,depo=0.0) = 0.2613
# logical error rate for (L=7,loss_rate=0.013,depo=0.0) = 0.2585
# logical error rate for (L=7,loss_rate=0.014,depo=0.0) = 0.2898
# logical error rate for (L=7,loss_rate=0.014,depo=0.0) = 0.2976
# logical error rate for (L=7,loss_rate=0.014,depo=0.0) = 0.3029
# logical error rate for (L=7,loss_rate=0.014,depo=0.0) = 0.2931
# logical error rate for (L=7,loss_rate=0.014,depo=0.0) = 0.2895
# logical error rate for (L=7,loss_rate=0.014,depo=0.0) = 0.2918
# logical error rate for (L=7,loss_rate=0.014,depo=0.0) = 0.2909
# logical error rate for (L=7,loss_rate=0.014,depo=0.0) = 0.2964
# logical error rate for (L=7,loss_rate=0.014,depo=0.0) = 0.2979
# logical error rate for (L=7,loss_rate=0.014,depo=0.0) = 0.3031
# logical error rate for (L=7,loss_rate=0.015,depo=0.0) = 0.3297
# logical error rate for (L=7,loss_rate=0.015,depo=0.0) = 0.3293
# logical error rate for (L=7,loss_rate=0.015,depo=0.0) = 0.3237
# logical error rate for (L=7,loss_rate=0.015,depo=0.0) = 0.3301
# logical error rate for (L=7,loss_rate=0.015,depo=0.0) = 0.3303
# logical error rate for (L=7,loss_rate=0.015,depo=0.0) = 0.3224
# logical error rate for (L=7,loss_rate=0.015,depo=0.0) = 0.3281
# logical error rate for (L=7,loss_rate=0.015,depo=0.0) = 0.3315
# logical error rate for (L=7,loss_rate=0.015,depo=0.0) = 0.316
# logical error rate for (L=7,loss_rate=0.015,depo=0.0) = 0.3293
# logical error rate for (L=7,loss_rate=0.016,depo=0.0) = 0.3504
# logical error rate for (L=7,loss_rate=0.016,depo=0.0) = 0.3537
# logical error rate for (L=7,loss_rate=0.016,depo=0.0) = 0.349
# logical error rate for (L=7,loss_rate=0.016,depo=0.0) = 0.3562
# logical error rate for (L=7,loss_rate=0.016,depo=0.0) = 0.3538
# logical error rate for (L=7,loss_rate=0.016,depo=0.0) = 0.3474
# logical error rate for (L=7,loss_rate=0.016,depo=0.0) = 0.3628
# logical error rate for (L=7,loss_rate=0.016,depo=0.0) = 0.3518
# logical error rate for (L=7,loss_rate=0.016,depo=0.0) = 0.3575
# logical error rate for (L=7,loss_rate=0.016,depo=0.0) = 0.3697
# logical error rate for (L=7,loss_rate=0.017,depo=0.0) = 0.3854
# logical error rate for (L=7,loss_rate=0.017,depo=0.0) = 0.383
# logical error rate for (L=7,loss_rate=0.017,depo=0.0) = 0.3813
# logical error rate for (L=7,loss_rate=0.017,depo=0.0) = 0.3855
# logical error rate for (L=7,loss_rate=0.017,depo=0.0) = 0.3811
# logical error rate for (L=7,loss_rate=0.017,depo=0.0) = 0.3742
# logical error rate for (L=7,loss_rate=0.017,depo=0.0) = 0.3802
# logical error rate for (L=7,loss_rate=0.017,depo=0.0) = 0.3793
# logical error rate for (L=7,loss_rate=0.017,depo=0.0) = 0.3844
# logical error rate for (L=7,loss_rate=0.017,depo=0.0) = 0.3831
# logical error rate for (L=7,loss_rate=0.018,depo=0.0) = 0.4078
# logical error rate for (L=7,loss_rate=0.018,depo=0.0) = 0.411
# logical error rate for (L=7,loss_rate=0.018,depo=0.0) = 0.3933
# logical error rate for (L=7,loss_rate=0.018,depo=0.0) = 0.4063
# logical error rate for (L=7,loss_rate=0.018,depo=0.0) = 0.413
# logical error rate for (L=7,loss_rate=0.018,depo=0.0) = 0.4
# logical error rate for (L=7,loss_rate=0.018,depo=0.0) = 0.4038
# logical error rate for (L=7,loss_rate=0.018,depo=0.0) = 0.4057
# logical error rate for (L=7,loss_rate=0.018,depo=0.0) = 0.4098
# logical error rate for (L=7,loss_rate=0.018,depo=0.0) = 0.4065
# logical error rate for (L=7,loss_rate=0.019,depo=0.0) = 0.4244
# logical error rate for (L=7,loss_rate=0.019,depo=0.0) = 0.422
# logical error rate for (L=7,loss_rate=0.019,depo=0.0) = 0.4235
# logical error rate for (L=7,loss_rate=0.019,depo=0.0) = 0.418
# logical error rate for (L=7,loss_rate=0.019,depo=0.0) = 0.4215
# logical error rate for (L=7,loss_rate=0.019,depo=0.0) = 0.4172
# logical error rate for (L=7,loss_rate=0.019,depo=0.0) = 0.4219
# logical error rate for (L=7,loss_rate=0.019,depo=0.0) = 0.4169
# logical error rate for (L=7,loss_rate=0.019,depo=0.0) = 0.4283
# logical error rate for (L=7,loss_rate=0.019,depo=0.0) = 0.4266
# logical error rate for (L=7,loss_rate=0.02,depo=0.0) = 0.4328
# logical error rate for (L=7,loss_rate=0.02,depo=0.0) = 0.4463
# logical error rate for (L=7,loss_rate=0.02,depo=0.0) = 0.4332
# logical error rate for (L=7,loss_rate=0.02,depo=0.0) = 0.4444
# logical error rate for (L=7,loss_rate=0.02,depo=0.0) = 0.4438
# logical error rate for (L=7,loss_rate=0.02,depo=0.0) = 0.4379
# logical error rate for (L=7,loss_rate=0.02,depo=0.0) = 0.4393
# logical error rate for (L=7,loss_rate=0.02,depo=0.0) = 0.4305
# logical error rate for (L=7,loss_rate=0.02,depo=0.0) = 0.4318
# logical error rate for (L=7,loss_rate=0.02,depo=0.0) = 0.4322
# logical error rate for (L=7,loss_rate=0.021,depo=0.0) = 0.4618
# logical error rate for (L=7,loss_rate=0.021,depo=0.0) = 0.4504
# logical error rate for (L=7,loss_rate=0.021,depo=0.0) = 0.4552
# logical error rate for (L=7,loss_rate=0.021,depo=0.0) = 0.4487
# logical error rate for (L=7,loss_rate=0.021,depo=0.0) = 0.4525
# logical error rate for (L=7,loss_rate=0.021,depo=0.0) = 0.447
# logical error rate for (L=7,loss_rate=0.021,depo=0.0) = 0.4511
# logical error rate for (L=7,loss_rate=0.021,depo=0.0) = 0.4493
# logical error rate for (L=7,loss_rate=0.021,depo=0.0) = 0.4505
# logical error rate for (L=7,loss_rate=0.021,depo=0.0) = 0.4517
# logical error rate for (L=7,loss_rate=0.022,depo=0.0) = 0.4599
# logical error rate for (L=7,loss_rate=0.022,depo=0.0) = 0.4592
# logical error rate for (L=7,loss_rate=0.022,depo=0.0) = 0.4609
# logical error rate for (L=7,loss_rate=0.022,depo=0.0) = 0.4618
# logical error rate for (L=7,loss_rate=0.022,depo=0.0) = 0.4651
# logical error rate for (L=7,loss_rate=0.022,depo=0.0) = 0.4729
# logical error rate for (L=7,loss_rate=0.022,depo=0.0) = 0.4619
# logical error rate for (L=7,loss_rate=0.022,depo=0.0) = 0.4614
# logical error rate for (L=7,loss_rate=0.022,depo=0.0) = 0.4585
# logical error rate for (L=7,loss_rate=0.022,depo=0.0) = 0.4596
# logical error rate for (L=7,loss_rate=0.023,depo=0.0) = 0.4695
# logical error rate for (L=7,loss_rate=0.023,depo=0.0) = 0.4705
# logical error rate for (L=7,loss_rate=0.023,depo=0.0) = 0.4727
# logical error rate for (L=7,loss_rate=0.023,depo=0.0) = 0.4662
# logical error rate for (L=7,loss_rate=0.023,depo=0.0) = 0.4642
# logical error rate for (L=7,loss_rate=0.023,depo=0.0) = 0.4741
# logical error rate for (L=7,loss_rate=0.023,depo=0.0) = 0.4669
# logical error rate for (L=7,loss_rate=0.023,depo=0.0) = 0.4717
# logical error rate for (L=7,loss_rate=0.023,depo=0.0) = 0.4752
# logical error rate for (L=7,loss_rate=0.023,depo=0.0) = 0.477
# logical error rate for (L=7,loss_rate=0.024,depo=0.0) = 0.4662
# logical error rate for (L=7,loss_rate=0.024,depo=0.0) = 0.4759
# logical error rate for (L=7,loss_rate=0.024,depo=0.0) = 0.4801
# logical error rate for (L=7,loss_rate=0.024,depo=0.0) = 0.4726
# logical error rate for (L=7,loss_rate=0.024,depo=0.0) = 0.4825
# logical error rate for (L=7,loss_rate=0.024,depo=0.0) = 0.4811
# logical error rate for (L=7,loss_rate=0.024,depo=0.0) = 0.479
# logical error rate for (L=7,loss_rate=0.024,depo=0.0) = 0.4794
# logical error rate for (L=7,loss_rate=0.024,depo=0.0) = 0.4863
# logical error rate for (L=7,loss_rate=0.024,depo=0.0) = 0.4817
# logical error rate for (L=7,loss_rate=0.025,depo=0.0) = 0.478
# logical error rate for (L=7,loss_rate=0.025,depo=0.0) = 0.4806
# logical error rate for (L=7,loss_rate=0.025,depo=0.0) = 0.49
# logical error rate for (L=7,loss_rate=0.025,depo=0.0) = 0.4922
# logical error rate for (L=7,loss_rate=0.025,depo=0.0) = 0.4896
# logical error rate for (L=7,loss_rate=0.025,depo=0.0) = 0.4766
# logical error rate for (L=7,loss_rate=0.025,depo=0.0) = 0.4808
# logical error rate for (L=7,loss_rate=0.025,depo=0.0) = 0.4903
# logical error rate for (L=7,loss_rate=0.025,depo=0.0) = 0.4894
# logical error rate for (L=7,loss_rate=0.025,depo=0.0) = 0.4796
# logical error rate for (L=9,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=9,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=9,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=9,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=9,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=9,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=9,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=9,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=9,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=9,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=9,loss_rate=0.002,depo=0.0) = 0.0002
# logical error rate for (L=9,loss_rate=0.002,depo=0.0) = 0.0001
# logical error rate for (L=9,loss_rate=0.002,depo=0.0) = 0.0004
# logical error rate for (L=9,loss_rate=0.002,depo=0.0) = 0.0003
# ...
# logical error rate for (L=9,loss_rate=0.025,depo=0.0) = 0.4947
# logical error rate for (L=11,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=11,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=11,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=11,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=11,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=11,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=11,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=11,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=11,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=11,loss_rate=0.001,depo=0.0) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.0) = 0.0001
# logical error rate for (L=11,loss_rate=0.002,depo=0.0) = 0.0002
# logical error rate for (L=11,loss_rate=0.002,depo=0.0) = 0.0003
# logical error rate for (L=11,loss_rate=0.002,depo=0.0) = 0.0001
# logical error rate for (L=11,loss_rate=0.002,depo=0.0) = 0.0001
# logical error rate for (L=11,loss_rate=0.002,depo=0.0) = 0.0001
# logical error rate for (L=11,loss_rate=0.002,depo=0.0) = 0.0001
# logical error rate for (L=11,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.0) = 0.0
# logical error rate for (L=11,loss_rate=0.002,depo=0.0) = 0.0002
# logical error rate for (L=11,loss_rate=0.003,depo=0.0) = 0.0009
# logical error rate for (L=11,loss_rate=0.003,depo=0.0) = 0.0009
# logical error rate for (L=11,loss_rate=0.003,depo=0.0) = 0.001
# logical error rate for (L=11,loss_rate=0.003,depo=0.0) = 0.0007
# logical error rate for (L=11,loss_rate=0.003,depo=0.0) = 0.0008
# logical error rate for (L=11,loss_rate=0.003,depo=0.0) = 0.0013
# logical error rate for (L=11,loss_rate=0.003,depo=0.0) = 0.0007
# logical error rate for (L=11,loss_rate=0.003,depo=0.0) = 0.0011
# logical error rate for (L=11,loss_rate=0.003,depo=0.0) = 0.0004
# logical error rate for (L=11,loss_rate=0.003,depo=0.0) = 0.0009
# logical error rate for (L=11,loss_rate=0.004,depo=0.0) = 0.0037
# logical error rate for (L=11,loss_rate=0.004,depo=0.0) = 0.0036
# logical error rate for (L=11,loss_rate=0.004,depo=0.0) = 0.004
# logical error rate for (L=11,loss_rate=0.004,depo=0.0) = 0.0035
# logical error rate for (L=11,loss_rate=0.004,depo=0.0) = 0.0042
# logical error rate for (L=11,loss_rate=0.004,depo=0.0) = 0.0044
# logical error rate for (L=11,loss_rate=0.004,depo=0.0) = 0.0045
# logical error rate for (L=11,loss_rate=0.004,depo=0.0) = 0.0028
# logical error rate for (L=11,loss_rate=0.004,depo=0.0) = 0.004
# logical error rate for (L=11,loss_rate=0.004,depo=0.0) = 0.0037
# logical error rate for (L=11,loss_rate=0.005,depo=0.0) = 0.0113
# logical error rate for (L=11,loss_rate=0.005,depo=0.0) = 0.0145
# logical error rate for (L=11,loss_rate=0.005,depo=0.0) = 0.0131
# logical error rate for (L=11,loss_rate=0.005,depo=0.0) = 0.0104
# logical error rate for (L=11,loss_rate=0.005,depo=0.0) = 0.0115
# logical error rate for (L=11,loss_rate=0.005,depo=0.0) = 0.0125
# logical error rate for (L=11,loss_rate=0.005,depo=0.0) = 0.0119
# logical error rate for (L=11,loss_rate=0.005,depo=0.0) = 0.012
# logical error rate for (L=11,loss_rate=0.005,depo=0.0) = 0.0113
# logical error rate for (L=11,loss_rate=0.005,depo=0.0) = 0.0121
# logical error rate for (L=11,loss_rate=0.006,depo=0.0) = 0.0306
# logical error rate for (L=11,loss_rate=0.006,depo=0.0) = 0.0261
# logical error rate for (L=11,loss_rate=0.006,depo=0.0) = 0.0309
# logical error rate for (L=11,loss_rate=0.006,depo=0.0) = 0.0289
# logical error rate for (L=11,loss_rate=0.006,depo=0.0) = 0.0271
# logical error rate for (L=11,loss_rate=0.006,depo=0.0) = 0.0333
# logical error rate for (L=11,loss_rate=0.006,depo=0.0) = 0.029
# logical error rate for (L=11,loss_rate=0.006,depo=0.0) = 0.0296
# logical error rate for (L=11,loss_rate=0.006,depo=0.0) = 0.0288
# logical error rate for (L=11,loss_rate=0.006,depo=0.0) = 0.027
# logical error rate for (L=11,loss_rate=0.007,depo=0.0) = 0.0598
# logical error rate for (L=11,loss_rate=0.007,depo=0.0) = 0.0565
# logical error rate for (L=11,loss_rate=0.007,depo=0.0) = 0.0589
# logical error rate for (L=11,loss_rate=0.007,depo=0.0) = 0.0592
# logical error rate for (L=11,loss_rate=0.007,depo=0.0) = 0.054
# logical error rate for (L=11,loss_rate=0.007,depo=0.0) = 0.0549
# logical error rate for (L=11,loss_rate=0.007,depo=0.0) = 0.0576
# logical error rate for (L=11,loss_rate=0.007,depo=0.0) = 0.0565
# logical error rate for (L=11,loss_rate=0.007,depo=0.0) = 0.0637
# logical error rate for (L=11,loss_rate=0.007,depo=0.0) = 0.0623
# logical error rate for (L=11,loss_rate=0.008,depo=0.0) = 0.1034
# logical error rate for (L=11,loss_rate=0.008,depo=0.0) = 0.1065
# logical error rate for (L=11,loss_rate=0.008,depo=0.0) = 0.1053
# logical error rate for (L=11,loss_rate=0.008,depo=0.0) = 0.0967
# logical error rate for (L=11,loss_rate=0.008,depo=0.0) = 0.102
# logical error rate for (L=11,loss_rate=0.008,depo=0.0) = 0.1017
# logical error rate for (L=11,loss_rate=0.008,depo=0.0) = 0.0989
# logical error rate for (L=11,loss_rate=0.008,depo=0.0) = 0.1096
# logical error rate for (L=11,loss_rate=0.008,depo=0.0) = 0.0939
# logical error rate for (L=11,loss_rate=0.008,depo=0.0) = 0.102
# logical error rate for (L=11,loss_rate=0.009,depo=0.0) = 0.1572
# logical error rate for (L=11,loss_rate=0.009,depo=0.0) = 0.1552
# logical error rate for (L=11,loss_rate=0.009,depo=0.0) = 0.1574
# logical error rate for (L=11,loss_rate=0.009,depo=0.0) = 0.1555
# logical error rate for (L=11,loss_rate=0.009,depo=0.0) = 0.155
# logical error rate for (L=11,loss_rate=0.009,depo=0.0) = 0.1527
# logical error rate for (L=11,loss_rate=0.009,depo=0.0) = 0.1595
# logical error rate for (L=11,loss_rate=0.009,depo=0.0) = 0.158
# logical error rate for (L=11,loss_rate=0.009,depo=0.0) = 0.1501
# logical error rate for (L=11,loss_rate=0.009,depo=0.0) = 0.1593
# logical error rate for (L=11,loss_rate=0.01,depo=0.0) = 0.2116
# logical error rate for (L=11,loss_rate=0.01,depo=0.0) = 0.2171
# logical error rate for (L=11,loss_rate=0.01,depo=0.0) = 0.2149
# logical error rate for (L=11,loss_rate=0.01,depo=0.0) = 0.2117
# logical error rate for (L=11,loss_rate=0.01,depo=0.0) = 0.2202
# logical error rate for (L=11,loss_rate=0.01,depo=0.0) = 0.2187
# logical error rate for (L=11,loss_rate=0.01,depo=0.0) = 0.2171
# logical error rate for (L=11,loss_rate=0.01,depo=0.0) = 0.2129
# logical error rate for (L=11,loss_rate=0.01,depo=0.0) = 0.2188
# logical error rate for (L=11,loss_rate=0.01,depo=0.0) = 0.2217
# logical error rate for (L=11,loss_rate=0.011,depo=0.0) = 0.2793
# logical error rate for (L=11,loss_rate=0.011,depo=0.0) = 0.2765
# logical error rate for (L=11,loss_rate=0.011,depo=0.0) = 0.2861
# logical error rate for (L=11,loss_rate=0.011,depo=0.0) = 0.2815
# logical error rate for (L=11,loss_rate=0.011,depo=0.0) = 0.2759
# logical error rate for (L=11,loss_rate=0.011,depo=0.0) = 0.2807
# logical error rate for (L=11,loss_rate=0.011,depo=0.0) = 0.2766
# logical error rate for (L=11,loss_rate=0.011,depo=0.0) = 0.2839
# logical error rate for (L=11,loss_rate=0.011,depo=0.0) = 0.2855
# logical error rate for (L=11,loss_rate=0.011,depo=0.0) = 0.2855
# logical error rate for (L=11,loss_rate=0.012,depo=0.0) = 0.3386
# logical error rate for (L=11,loss_rate=0.012,depo=0.0) = 0.3389
# logical error rate for (L=11,loss_rate=0.012,depo=0.0) = 0.3397
# logical error rate for (L=11,loss_rate=0.012,depo=0.0) = 0.33
# logical error rate for (L=11,loss_rate=0.012,depo=0.0) = 0.333
# logical error rate for (L=11,loss_rate=0.012,depo=0.0) = 0.3352
# logical error rate for (L=11,loss_rate=0.012,depo=0.0) = 0.3397
# logical error rate for (L=11,loss_rate=0.012,depo=0.0) = 0.3374
# logical error rate for (L=11,loss_rate=0.012,depo=0.0) = 0.3378
# logical error rate for (L=11,loss_rate=0.012,depo=0.0) = 0.3336
# logical error rate for (L=11,loss_rate=0.013,depo=0.0) = 0.3884
# logical error rate for (L=11,loss_rate=0.013,depo=0.0) = 0.3869
# logical error rate for (L=11,loss_rate=0.013,depo=0.0) = 0.3976
# logical error rate for (L=11,loss_rate=0.013,depo=0.0) = 0.3823
# logical error rate for (L=11,loss_rate=0.013,depo=0.0) = 0.3823
# logical error rate for (L=11,loss_rate=0.013,depo=0.0) = 0.3846
# logical error rate for (L=11,loss_rate=0.013,depo=0.0) = 0.3883
# logical error rate for (L=11,loss_rate=0.013,depo=0.0) = 0.3903
# logical error rate for (L=11,loss_rate=0.013,depo=0.0) = 0.3883
# logical error rate for (L=11,loss_rate=0.013,depo=0.0) = 0.3736
# logical error rate for (L=11,loss_rate=0.014,depo=0.0) = 0.4179
# logical error rate for (L=11,loss_rate=0.014,depo=0.0) = 0.4196
# logical error rate for (L=11,loss_rate=0.014,depo=0.0) = 0.4287
# logical error rate for (L=11,loss_rate=0.014,depo=0.0) = 0.4288
# logical error rate for (L=11,loss_rate=0.014,depo=0.0) = 0.4267
# logical error rate for (L=11,loss_rate=0.014,depo=0.0) = 0.4305
# logical error rate for (L=11,loss_rate=0.014,depo=0.0) = 0.4259
# logical error rate for (L=11,loss_rate=0.014,depo=0.0) = 0.4283
# logical error rate for (L=11,loss_rate=0.014,depo=0.0) = 0.4306
# logical error rate for (L=11,loss_rate=0.014,depo=0.0) = 0.4121
# logical error rate for (L=11,loss_rate=0.015,depo=0.0) = 0.4509
# logical error rate for (L=11,loss_rate=0.015,depo=0.0) = 0.4499
# logical error rate for (L=11,loss_rate=0.015,depo=0.0) = 0.4544
# logical error rate for (L=11,loss_rate=0.015,depo=0.0) = 0.4507
# logical error rate for (L=11,loss_rate=0.015,depo=0.0) = 0.446
# logical error rate for (L=11,loss_rate=0.015,depo=0.0) = 0.4383
# logical error rate for (L=11,loss_rate=0.015,depo=0.0) = 0.4521
# logical error rate for (L=11,loss_rate=0.015,depo=0.0) = 0.4489
# logical error rate for (L=11,loss_rate=0.015,depo=0.0) = 0.4532
# logical error rate for (L=11,loss_rate=0.015,depo=0.0) = 0.4593
# logical error rate for (L=11,loss_rate=0.016,depo=0.0) = 0.4743
# logical error rate for (L=11,loss_rate=0.016,depo=0.0) = 0.4633
# logical error rate for (L=11,loss_rate=0.016,depo=0.0) = 0.4631
# logical error rate for (L=11,loss_rate=0.016,depo=0.0) = 0.4758
# logical error rate for (L=11,loss_rate=0.016,depo=0.0) = 0.4679
# logical error rate for (L=11,loss_rate=0.016,depo=0.0) = 0.4702
# logical error rate for (L=11,loss_rate=0.016,depo=0.0) = 0.4718
# logical error rate for (L=11,loss_rate=0.016,depo=0.0) = 0.4774
# logical error rate for (L=11,loss_rate=0.016,depo=0.0) = 0.4776
# logical error rate for (L=11,loss_rate=0.016,depo=0.0) = 0.4662
# logical error rate for (L=11,loss_rate=0.017,depo=0.0) = 0.4788
# logical error rate for (L=11,loss_rate=0.017,depo=0.0) = 0.4819
# logical error rate for (L=11,loss_rate=0.017,depo=0.0) = 0.4869
# logical error rate for (L=11,loss_rate=0.017,depo=0.0) = 0.4869
# logical error rate for (L=11,loss_rate=0.017,depo=0.0) = 0.4803
# logical error rate for (L=11,loss_rate=0.017,depo=0.0) = 0.4858
# logical error rate for (L=11,loss_rate=0.017,depo=0.0) = 0.4806
# logical error rate for (L=11,loss_rate=0.017,depo=0.0) = 0.4721
# logical error rate for (L=11,loss_rate=0.017,depo=0.0) = 0.4975
# logical error rate for (L=11,loss_rate=0.017,depo=0.0) = 0.4893
# logical error rate for (L=11,loss_rate=0.018,depo=0.0) = 0.4952
# logical error rate for (L=11,loss_rate=0.018,depo=0.0) = 0.4963
# logical error rate for (L=11,loss_rate=0.018,depo=0.0) = 0.4852
# logical error rate for (L=11,loss_rate=0.018,depo=0.0) = 0.4951
# logical error rate for (L=11,loss_rate=0.018,depo=0.0) = 0.4944
# logical error rate for (L=11,loss_rate=0.018,depo=0.0) = 0.4892
# logical error rate for (L=11,loss_rate=0.018,depo=0.0) = 0.4907
# logical error rate for (L=11,loss_rate=0.018,depo=0.0) = 0.4915
# logical error rate for (L=11,loss_rate=0.018,depo=0.0) = 0.4948
# logical error rate for (L=11,loss_rate=0.018,depo=0.0) = 0.4989
# logical error rate for (L=11,loss_rate=0.019,depo=0.0) = 0.4993
# logical error rate for (L=11,loss_rate=0.019,depo=0.0) = 0.4917
# logical error rate for (L=11,loss_rate=0.019,depo=0.0) = 0.4976
# logical error rate for (L=11,loss_rate=0.019,depo=0.0) = 0.491
# logical error rate for (L=11,loss_rate=0.019,depo=0.0) = 0.4911
# logical error rate for (L=11,loss_rate=0.019,depo=0.0) = 0.4887
# logical error rate for (L=11,loss_rate=0.019,depo=0.0) = 0.4939
# logical error rate for (L=11,loss_rate=0.019,depo=0.0) = 0.4991
# logical error rate for (L=11,loss_rate=0.019,depo=0.0) = 0.4968
# logical error rate for (L=11,loss_rate=0.019,depo=0.0) = 0.5004
# logical error rate for (L=11,loss_rate=0.02,depo=0.0) = 0.5056
# logical error rate for (L=11,loss_rate=0.02,depo=0.0) = 0.5063
# logical error rate for (L=11,loss_rate=0.02,depo=0.0) = 0.4886
# logical error rate for (L=11,loss_rate=0.02,depo=0.0) = 0.4929
# logical error rate for (L=11,loss_rate=0.02,depo=0.0) = 0.5015
# logical error rate for (L=11,loss_rate=0.02,depo=0.0) = 0.4998
# logical error rate for (L=11,loss_rate=0.02,depo=0.0) = 0.4966
# logical error rate for (L=11,loss_rate=0.02,depo=0.0) = 0.5065
# logical error rate for (L=11,loss_rate=0.02,depo=0.0) = 0.5002
# logical error rate for (L=11,loss_rate=0.02,depo=0.0) = 0.4999
# logical error rate for (L=11,loss_rate=0.021,depo=0.0) = 0.4955
# logical error rate for (L=11,loss_rate=0.021,depo=0.0) = 0.4956
# logical error rate for (L=11,loss_rate=0.021,depo=0.0) = 0.5051
# logical error rate for (L=11,loss_rate=0.021,depo=0.0) = 0.4953
# logical error rate for (L=11,loss_rate=0.021,depo=0.0) = 0.4994
# logical error rate for (L=11,loss_rate=0.021,depo=0.0) = 0.4952
# logical error rate for (L=11,loss_rate=0.021,depo=0.0) = 0.4973
# logical error rate for (L=11,loss_rate=0.021,depo=0.0) = 0.4972
# logical error rate for (L=11,loss_rate=0.021,depo=0.0) = 0.4977
# logical error rate for (L=11,loss_rate=0.021,depo=0.0) = 0.4958
# logical error rate for (L=11,loss_rate=0.022,depo=0.0) = 0.4981
# logical error rate for (L=11,loss_rate=0.022,depo=0.0) = 0.4989
# logical error rate for (L=11,loss_rate=0.022,depo=0.0) = 0.4973
# logical error rate for (L=11,loss_rate=0.022,depo=0.0) = 0.5057
# logical error rate for (L=11,loss_rate=0.022,depo=0.0) = 0.5055
# logical error rate for (L=11,loss_rate=0.022,depo=0.0) = 0.5031
# logical error rate for (L=11,loss_rate=0.022,depo=0.0) = 0.4989
# logical error rate for (L=11,loss_rate=0.022,depo=0.0) = 0.5012
# logical error rate for (L=11,loss_rate=0.022,depo=0.0) = 0.4998
# logical error rate for (L=11,loss_rate=0.022,depo=0.0) = 0.5065
# logical error rate for (L=11,loss_rate=0.023,depo=0.0) = 0.4902
# logical error rate for (L=11,loss_rate=0.023,depo=0.0) = 0.4936
# logical error rate for (L=11,loss_rate=0.023,depo=0.0) = 0.5016
# logical error rate for (L=11,loss_rate=0.023,depo=0.0) = 0.4997
# logical error rate for (L=11,loss_rate=0.023,depo=0.0) = 0.4977
# logical error rate for (L=11,loss_rate=0.023,depo=0.0) = 0.5096
# logical error rate for (L=11,loss_rate=0.023,depo=0.0) = 0.4981
# logical error rate for (L=11,loss_rate=0.023,depo=0.0) = 0.4882
# logical error rate for (L=11,loss_rate=0.023,depo=0.0) = 0.4927
# logical error rate for (L=11,loss_rate=0.023,depo=0.0) = 0.4986
# logical error rate for (L=11,loss_rate=0.024,depo=0.0) = 0.4961
# logical error rate for (L=11,loss_rate=0.024,depo=0.0) = 0.5058
# logical error rate for (L=11,loss_rate=0.024,depo=0.0) = 0.4979
# logical error rate for (L=11,loss_rate=0.024,depo=0.0) = 0.4995
# logical error rate for (L=11,loss_rate=0.024,depo=0.0) = 0.4968
# logical error rate for (L=11,loss_rate=0.024,depo=0.0) = 0.4885
# logical error rate for (L=11,loss_rate=0.024,depo=0.0) = 0.4974
# logical error rate for (L=11,loss_rate=0.024,depo=0.0) = 0.5026
# logical error rate for (L=11,loss_rate=0.024,depo=0.0) = 0.5012
# logical error rate for (L=11,loss_rate=0.024,depo=0.0) = 0.502
# logical error rate for (L=11,loss_rate=0.025,depo=0.0) = 0.4994
# logical error rate for (L=11,loss_rate=0.025,depo=0.0) = 0.5089
# logical error rate for (L=11,loss_rate=0.025,depo=0.0) = 0.5051
# logical error rate for (L=11,loss_rate=0.025,depo=0.0) = 0.4947
# logical error rate for (L=11,loss_rate=0.025,depo=0.0) = 0.5095
# logical error rate for (L=11,loss_rate=0.025,depo=0.0) = 0.4854
# logical error rate for (L=11,loss_rate=0.025,depo=0.0) = 0.5097
# logical error rate for (L=11,loss_rate=0.025,depo=0.0) = 0.4966
# logical error rate for (L=11,loss_rate=0.025,depo=0.0) = 0.5018
# logical error rate for (L=11,loss_rate=0.025,depo=0.0) = 0.4954
