# %%
import stim
from dem_builder_standard_LDU import DEM_builder
import os
import numpy as np
import scipy
from surface_code_standard_LDU import Rotated_Surface_Code_standard_LDU
import pymatching
import pickle
import multiprocessing
from multiprocessing import Pool

# %%
#function for simulation

#Compute the logical error rate of the surface code supplemented with the standard LDU for a given noise and loss probability
#stored as a dictionnary in a file for a fixed loss probability and various depolarizing noise probabilities
def simulation_code_fixed_loss(L,loss,depo,num_shots):
    loss=round(loss,5)
    depo=round(depo,5)
    lattice = Rotated_Surface_Code_standard_LDU(L,L,L,'|0>','Z',measurement_order='z_first',loss_rate=loss,after_CZ=('DEPOLARIZE2',depo))
    dem_build=DEM_builder(lattice)
    PATH='data/dem/dem_standard_LDU/DEM_surface_code_({},{},{})'.format(L,L,L)
    
    error_rate=dem_build.logical_errors(num_shots,PATH)
    
    if os.path.exists('data/logical_error/logical_error_standard_LDU_d=({},{})_rounds={}_loss_rate={}.pkl'.format(L,L,L,loss)):
        with open('data/logical_error/logical_error_standard_LDU_d=({},{})_rounds={}_loss_rate={}.pkl'.format(L,L,L,loss), 'rb') as fp:
            data_saved=pickle.load(fp)
        
    else:
        data_saved={}
    if depo not in data_saved.keys():#CREATE DICTIONNARY if the noise probability has never been computed
        data_saved[depo]={}
        data_saved[depo]['num_shots']=num_shots
        data_saved[depo]['error_rate']=error_rate
    else:#UPDATE DICTIONNARY if there has been already simulation for that given loss and noise probability
        data_saved[depo]['error_rate']*=data_saved[depo]['num_shots']/(data_saved[depo]['num_shots']+num_shots)
        data_saved[depo]['error_rate']+=error_rate*num_shots/(data_saved[depo]['num_shots']+num_shots)
        data_saved[depo]['num_shots']+=num_shots
    
    #stored in a file for a given loss and various noise probabilities
    with open('data/logical_error/logical_error_standard_LDU_d=({},{})_rounds={}_loss_rate={}.pkl'.format(L,L,L,loss), 'wb') as fp:
        pickle.dump(data_saved, fp)

    print('logical error rate for (L={},loss_rate={},depo={}) = {}'.format(L,loss,depo,error_rate))
    

#wrapper to one argument (needed for parallelization)
def multi_args_wrapper_fixed_loss(args):
   simulation_code_fixed_loss(*args)

# %%
simulation_code_fixed_loss(3,0.0001,0.0001,100)
# Out:
# logical error rate for (L=3,loss_rate=0.0001,depo=0.0001) = 0.0

# %%
#Compute the logical error rate and store as a dictionnary in files with a fixed loss probabilities

Ls = range(3,13,2)
depo_list = np.linspace(0.001, 0.016, 16) #list of depolarizing noise probabilities
loss_list=[0.,0.001,0.002,0.003,0.005,0.007,0.01,0.015,0.02,0.025] #list of loss probabilities
num_shots = 10000 #number of shots per core
nb_core=10 #number of cores used

for loss_rate in loss_list:
    for L in Ls:
        for depo in depo_list:
            with Pool(processes=nb_core) as pool:
                pool.imap(multi_args_wrapper_fixed_loss,[(L,loss_rate,depo,num_shots) for _ in range(10)])
                pool.close()
                pool.join()
# Out:
# logical error rate for (L=11,loss_rate=0.001,depo=0.016) = 0.4168
# logical error rate for (L=11,loss_rate=0.001,depo=0.016) = 0.4257
# logical error rate for (L=11,loss_rate=0.001,depo=0.016) = 0.4216
# logical error rate for (L=11,loss_rate=0.001,depo=0.016) = 0.4228
# logical error rate for (L=11,loss_rate=0.001,depo=0.016) = 0.4116
# logical error rate for (L=11,loss_rate=0.001,depo=0.016) = 0.413
# logical error rate for (L=11,loss_rate=0.001,depo=0.016) = 0.4238
# logical error rate for (L=11,loss_rate=0.001,depo=0.016) = 0.4226
# logical error rate for (L=11,loss_rate=0.001,depo=0.016) = 0.4303
# logical error rate for (L=11,loss_rate=0.001,depo=0.016) = 0.4153
# logical error rate for (L=11,loss_rate=0.001,depo=0.017) = 0.4405
# logical error rate for (L=11,loss_rate=0.001,depo=0.017) = 0.4469
# logical error rate for (L=11,loss_rate=0.001,depo=0.017) = 0.4404
# logical error rate for (L=11,loss_rate=0.001,depo=0.017) = 0.4475
# logical error rate for (L=11,loss_rate=0.001,depo=0.017) = 0.4343
# logical error rate for (L=11,loss_rate=0.001,depo=0.017) = 0.4468
# logical error rate for (L=11,loss_rate=0.001,depo=0.017) = 0.4477
# logical error rate for (L=11,loss_rate=0.001,depo=0.017) = 0.4443
# logical error rate for (L=11,loss_rate=0.001,depo=0.017) = 0.4372
# logical error rate for (L=11,loss_rate=0.001,depo=0.017) = 0.4407
# logical error rate for (L=11,loss_rate=0.001,depo=0.018) = 0.4638
# logical error rate for (L=11,loss_rate=0.001,depo=0.018) = 0.4676
# logical error rate for (L=11,loss_rate=0.001,depo=0.018) = 0.4743
# logical error rate for (L=11,loss_rate=0.001,depo=0.018) = 0.4626
# logical error rate for (L=11,loss_rate=0.001,depo=0.018) = 0.4712
# logical error rate for (L=11,loss_rate=0.001,depo=0.018) = 0.4609
# logical error rate for (L=11,loss_rate=0.001,depo=0.018) = 0.4681
# logical error rate for (L=11,loss_rate=0.001,depo=0.018) = 0.4652
# logical error rate for (L=11,loss_rate=0.001,depo=0.018) = 0.4655
# logical error rate for (L=11,loss_rate=0.001,depo=0.018) = 0.4654
# logical error rate for (L=11,loss_rate=0.001,depo=0.019) = 0.4723
# logical error rate for (L=11,loss_rate=0.001,depo=0.019) = 0.4806
# logical error rate for (L=11,loss_rate=0.001,depo=0.019) = 0.4721
# logical error rate for (L=11,loss_rate=0.001,depo=0.019) = 0.4816
# logical error rate for (L=11,loss_rate=0.001,depo=0.019) = 0.4774
# logical error rate for (L=11,loss_rate=0.001,depo=0.019) = 0.4795
# logical error rate for (L=11,loss_rate=0.001,depo=0.019) = 0.4799
# logical error rate for (L=11,loss_rate=0.001,depo=0.019) = 0.4779
# logical error rate for (L=11,loss_rate=0.001,depo=0.019) = 0.4743
# logical error rate for (L=11,loss_rate=0.001,depo=0.019) = 0.4813
# logical error rate for (L=11,loss_rate=0.001,depo=0.02) = 0.4863
# logical error rate for (L=11,loss_rate=0.001,depo=0.02) = 0.4886
# logical error rate for (L=11,loss_rate=0.001,depo=0.02) = 0.4882
# logical error rate for (L=11,loss_rate=0.001,depo=0.02) = 0.493
# logical error rate for (L=11,loss_rate=0.001,depo=0.02) = 0.489
# logical error rate for (L=11,loss_rate=0.001,depo=0.02) = 0.4818
# logical error rate for (L=11,loss_rate=0.001,depo=0.02) = 0.483
# logical error rate for (L=11,loss_rate=0.001,depo=0.02) = 0.4943
# logical error rate for (L=11,loss_rate=0.001,depo=0.02) = 0.4797
# logical error rate for (L=11,loss_rate=0.001,depo=0.02) = 0.4897

# %%
#function for simulation

#Compute the logical error rate of the surface code supplemented with the standard LDU for a given noise and loss probability
#stored as a dictionnary in a file for a fixed depolarizing noise probability and various loss probabilities
def simulation_code_fixed_depo(L,loss,depo,num_shots):
    loss=round(loss,5)
    depo=round(depo,5)
    lattice = Rotated_Surface_Code_standard_LDU(L,L,L,'|0>','Z',measurement_order='z_first',loss_rate=loss,after_CZ=('DEPOLARIZE2',depo))
    dem_build=DEM_builder(lattice)
    PATH='data/dem/dem_standard_LDU/DEM_surface_code_({},{},{})'.format(L,L,L)
    
    error_rate=dem_build.logical_errors(num_shots,PATH)
    
    if os.path.exists('data/logical_error/logical_error_standard_LDU_d=({},{})_rounds={}_depo_noise={}.pkl'.format(L,L,L,depo)):
        with open('data/logical_error/logical_error_standard_LDU_d=({},{})_rounds={}_depo_noise={}.pkl'.format(L,L,L,depo), 'rb') as fp:
            data_saved=pickle.load(fp)
        
    else:
        data_saved={}
    if loss not in data_saved.keys():#CREATE DICTIONNARY if the loss probability has never been computed
        data_saved[loss]={}
        data_saved[loss]['num_shots']=num_shots
        data_saved[loss]['error_rate']=error_rate
    else:#UPDATE DICTIONNARY if there has been already simulation for that given loss and noise probability
        data_saved[loss]['error_rate']*=data_saved[loss]['num_shots']/(data_saved[loss]['num_shots']+num_shots)
        data_saved[loss]['error_rate']+=error_rate*num_shots/(data_saved[loss]['num_shots']+num_shots)
        data_saved[loss]['num_shots']+=num_shots
    
    #stored in a file for a given loss and various noise probabilities
    with open('data/logical_error/logical_error_standard_LDU_d=({},{})_rounds={}_depo_noise={}.pkl'.format(L,L,L,depo), 'wb') as fp:
        pickle.dump(data_saved, fp)

    print('logical error rate for (L={},loss_rate={},depo={}) = {}'.format(L,loss,depo,error_rate))
    

#wrapper to one argument (needed for parallelization)    
def multi_args_wrapper_fixed_depo(args):
   simulation_code_fixed_depo(*args)

# %%
#Compute the logical error rate and store as a dictionnary in files with a fixed depolarizing noise probabilities

Ls = range(3,13,2)
loss_list = np.linspace(0.001, 0.03, 30)
depo=0.0
num_shots = 10000 #number of shots per core
nb_core=10  #number of cores used

for L in Ls:
    for loss_rate in loss_list:
        with Pool(processes=nb_core) as pool:
            pool.imap(multi_args_wrapper_fixed_depo,[(L,loss_rate,depo,num_shots) for _ in range(10)])
            pool.close()
            pool.join()
# Out:
# logical error rate for (L=5,loss_rate=0.016,depo=0.003) = 0.0676
# logical error rate for (L=5,loss_rate=0.016,depo=0.003) = 0.0654
# logical error rate for (L=5,loss_rate=0.016,depo=0.003) = 0.0685
# logical error rate for (L=5,loss_rate=0.016,depo=0.003) = 0.0688
# logical error rate for (L=5,loss_rate=0.016,depo=0.003) = 0.0681
# logical error rate for (L=5,loss_rate=0.016,depo=0.003) = 0.064
# logical error rate for (L=5,loss_rate=0.016,depo=0.003) = 0.0699
# logical error rate for (L=5,loss_rate=0.016,depo=0.003) = 0.0634
# logical error rate for (L=5,loss_rate=0.016,depo=0.003) = 0.0643
# logical error rate for (L=5,loss_rate=0.016,depo=0.003) = 0.0666
# logical error rate for (L=5,loss_rate=0.017,depo=0.003) = 0.0769
# logical error rate for (L=5,loss_rate=0.017,depo=0.003) = 0.0782
# logical error rate for (L=5,loss_rate=0.017,depo=0.003) = 0.0803
# logical error rate for (L=5,loss_rate=0.017,depo=0.003) = 0.0749
# logical error rate for (L=5,loss_rate=0.017,depo=0.003) = 0.0727
# logical error rate for (L=5,loss_rate=0.017,depo=0.003) = 0.0724
# logical error rate for (L=5,loss_rate=0.017,depo=0.003) = 0.0735
# logical error rate for (L=5,loss_rate=0.017,depo=0.003) = 0.073
# logical error rate for (L=5,loss_rate=0.017,depo=0.003) = 0.0725
# logical error rate for (L=5,loss_rate=0.017,depo=0.003) = 0.0748
# logical error rate for (L=5,loss_rate=0.018,depo=0.003) = 0.0813
# logical error rate for (L=5,loss_rate=0.018,depo=0.003) = 0.0809
# logical error rate for (L=5,loss_rate=0.018,depo=0.003) = 0.0812
# logical error rate for (L=5,loss_rate=0.018,depo=0.003) = 0.0793
# logical error rate for (L=5,loss_rate=0.018,depo=0.003) = 0.0879
# logical error rate for (L=5,loss_rate=0.018,depo=0.003) = 0.0805
# logical error rate for (L=5,loss_rate=0.018,depo=0.003) = 0.0849
# logical error rate for (L=5,loss_rate=0.018,depo=0.003) = 0.0827
# logical error rate for (L=5,loss_rate=0.018,depo=0.003) = 0.0853
# logical error rate for (L=5,loss_rate=0.018,depo=0.003) = 0.0789
# logical error rate for (L=5,loss_rate=0.019,depo=0.003) = 0.0921
# logical error rate for (L=5,loss_rate=0.019,depo=0.003) = 0.0913
# logical error rate for (L=5,loss_rate=0.019,depo=0.003) = 0.0904
# logical error rate for (L=5,loss_rate=0.019,depo=0.003) = 0.0928
# logical error rate for (L=5,loss_rate=0.019,depo=0.003) = 0.0962
# logical error rate for (L=5,loss_rate=0.019,depo=0.003) = 0.0916
# logical error rate for (L=5,loss_rate=0.019,depo=0.003) = 0.0958
# logical error rate for (L=5,loss_rate=0.019,depo=0.003) = 0.0912
# logical error rate for (L=5,loss_rate=0.019,depo=0.003) = 0.0967
# logical error rate for (L=5,loss_rate=0.019,depo=0.003) = 0.0933
# logical error rate for (L=7,loss_rate=0.016,depo=0.003) = 0.0829
# logical error rate for (L=7,loss_rate=0.016,depo=0.003) = 0.0819
# logical error rate for (L=7,loss_rate=0.016,depo=0.003) = 0.085
# logical error rate for (L=7,loss_rate=0.016,depo=0.003) = 0.0853
# logical error rate for (L=7,loss_rate=0.016,depo=0.003) = 0.0844
# logical error rate for (L=7,loss_rate=0.016,depo=0.003) = 0.0881
# logical error rate for (L=7,loss_rate=0.016,depo=0.003) = 0.0876
# logical error rate for (L=7,loss_rate=0.016,depo=0.003) = 0.0899
# logical error rate for (L=7,loss_rate=0.016,depo=0.003) = 0.0899
# logical error rate for (L=7,loss_rate=0.016,depo=0.003) = 0.0819
# logical error rate for (L=7,loss_rate=0.017,depo=0.003) = 0.0953
# logical error rate for (L=7,loss_rate=0.017,depo=0.003) = 0.1016
# logical error rate for (L=7,loss_rate=0.017,depo=0.003) = 0.102
# logical error rate for (L=7,loss_rate=0.017,depo=0.003) = 0.1045
# logical error rate for (L=7,loss_rate=0.017,depo=0.003) = 0.0941
# logical error rate for (L=7,loss_rate=0.017,depo=0.003) = 0.1025
# logical error rate for (L=7,loss_rate=0.017,depo=0.003) = 0.0962
# logical error rate for (L=7,loss_rate=0.017,depo=0.003) = 0.0948
# logical error rate for (L=7,loss_rate=0.017,depo=0.003) = 0.1004
# logical error rate for (L=7,loss_rate=0.017,depo=0.003) = 0.0984
# logical error rate for (L=7,loss_rate=0.018,depo=0.003) = 0.1119
# logical error rate for (L=7,loss_rate=0.018,depo=0.003) = 0.1107
# logical error rate for (L=7,loss_rate=0.018,depo=0.003) = 0.1117
# logical error rate for (L=7,loss_rate=0.018,depo=0.003) = 0.1085
# logical error rate for (L=7,loss_rate=0.018,depo=0.003) = 0.1114
# logical error rate for (L=7,loss_rate=0.018,depo=0.003) = 0.1106
# logical error rate for (L=7,loss_rate=0.018,depo=0.003) = 0.1116
# logical error rate for (L=7,loss_rate=0.018,depo=0.003) = 0.1126
# logical error rate for (L=7,loss_rate=0.018,depo=0.003) = 0.1132
# logical error rate for (L=7,loss_rate=0.018,depo=0.003) = 0.1136
# logical error rate for (L=7,loss_rate=0.019,depo=0.003) = 0.1311
# logical error rate for (L=7,loss_rate=0.019,depo=0.003) = 0.1262
# logical error rate for (L=7,loss_rate=0.019,depo=0.003) = 0.1331
# logical error rate for (L=7,loss_rate=0.019,depo=0.003) = 0.1253
# logical error rate for (L=7,loss_rate=0.019,depo=0.003) = 0.1267
# logical error rate for (L=7,loss_rate=0.019,depo=0.003) = 0.1244
# logical error rate for (L=7,loss_rate=0.019,depo=0.003) = 0.1296
# logical error rate for (L=7,loss_rate=0.019,depo=0.003) = 0.1271
# logical error rate for (L=7,loss_rate=0.019,depo=0.003) = 0.1271
# logical error rate for (L=7,loss_rate=0.019,depo=0.003) = 0.1281
# logical error rate for (L=9,loss_rate=0.016,depo=0.003) = 0.101
# logical error rate for (L=9,loss_rate=0.016,depo=0.003) = 0.1039
# logical error rate for (L=9,loss_rate=0.016,depo=0.003) = 0.1032
# logical error rate for (L=9,loss_rate=0.016,depo=0.003) = 0.1015
# logical error rate for (L=9,loss_rate=0.016,depo=0.003) = 0.1075
# logical error rate for (L=9,loss_rate=0.016,depo=0.003) = 0.0996
# logical error rate for (L=9,loss_rate=0.016,depo=0.003) = 0.1
# logical error rate for (L=9,loss_rate=0.016,depo=0.003) = 0.1023
# logical error rate for (L=9,loss_rate=0.016,depo=0.003) = 0.1022
# logical error rate for (L=9,loss_rate=0.016,depo=0.003) = 0.1038
# logical error rate for (L=9,loss_rate=0.017,depo=0.003) = 0.1213
# logical error rate for (L=9,loss_rate=0.017,depo=0.003) = 0.1199
# logical error rate for (L=9,loss_rate=0.017,depo=0.003) = 0.1253
# logical error rate for (L=9,loss_rate=0.017,depo=0.003) = 0.1198
# logical error rate for (L=9,loss_rate=0.017,depo=0.003) = 0.1245
# logical error rate for (L=9,loss_rate=0.017,depo=0.003) = 0.1234
# logical error rate for (L=9,loss_rate=0.017,depo=0.003) = 0.1207
# logical error rate for (L=9,loss_rate=0.017,depo=0.003) = 0.1223
# logical error rate for (L=9,loss_rate=0.017,depo=0.003) = 0.1232
# logical error rate for (L=9,loss_rate=0.017,depo=0.003) = 0.1244
# logical error rate for (L=9,loss_rate=0.018,depo=0.003) = 0.1461
# logical error rate for (L=9,loss_rate=0.018,depo=0.003) = 0.1459
# logical error rate for (L=9,loss_rate=0.018,depo=0.003) = 0.1419
# logical error rate for (L=9,loss_rate=0.018,depo=0.003) = 0.1379
# logical error rate for (L=9,loss_rate=0.018,depo=0.003) = 0.1413
# logical error rate for (L=9,loss_rate=0.018,depo=0.003) = 0.1427
# logical error rate for (L=9,loss_rate=0.018,depo=0.003) = 0.1432
# logical error rate for (L=9,loss_rate=0.018,depo=0.003) = 0.145
# logical error rate for (L=9,loss_rate=0.018,depo=0.003) = 0.1446
# logical error rate for (L=9,loss_rate=0.018,depo=0.003) = 0.1481
# logical error rate for (L=9,loss_rate=0.019,depo=0.003) = 0.1655
# logical error rate for (L=9,loss_rate=0.019,depo=0.003) = 0.1675
# logical error rate for (L=9,loss_rate=0.019,depo=0.003) = 0.1658
# logical error rate for (L=9,loss_rate=0.019,depo=0.003) = 0.1679
# logical error rate for (L=9,loss_rate=0.019,depo=0.003) = 0.1646
# logical error rate for (L=9,loss_rate=0.019,depo=0.003) = 0.1672
# logical error rate for (L=9,loss_rate=0.019,depo=0.003) = 0.1665
# logical error rate for (L=9,loss_rate=0.019,depo=0.003) = 0.1647
# logical error rate for (L=9,loss_rate=0.019,depo=0.003) = 0.1652
# logical error rate for (L=9,loss_rate=0.019,depo=0.003) = 0.1665
# logical error rate for (L=11,loss_rate=0.016,depo=0.003) = 0.1183
# logical error rate for (L=11,loss_rate=0.016,depo=0.003) = 0.1163
# logical error rate for (L=11,loss_rate=0.016,depo=0.003) = 0.1206
# logical error rate for (L=11,loss_rate=0.016,depo=0.003) = 0.1247
# logical error rate for (L=11,loss_rate=0.016,depo=0.003) = 0.1159
# logical error rate for (L=11,loss_rate=0.016,depo=0.003) = 0.1199
# logical error rate for (L=11,loss_rate=0.016,depo=0.003) = 0.1181
# logical error rate for (L=11,loss_rate=0.016,depo=0.003) = 0.1237
# logical error rate for (L=11,loss_rate=0.016,depo=0.003) = 0.1213
# logical error rate for (L=11,loss_rate=0.016,depo=0.003) = 0.1169
# logical error rate for (L=11,loss_rate=0.017,depo=0.003) = 0.1432
# logical error rate for (L=11,loss_rate=0.017,depo=0.003) = 0.143
# logical error rate for (L=11,loss_rate=0.017,depo=0.003) = 0.1405
# logical error rate for (L=11,loss_rate=0.017,depo=0.003) = 0.1435
# logical error rate for (L=11,loss_rate=0.017,depo=0.003) = 0.1433
# logical error rate for (L=11,loss_rate=0.017,depo=0.003) = 0.1443
# logical error rate for (L=11,loss_rate=0.017,depo=0.003) = 0.1477
# logical error rate for (L=11,loss_rate=0.017,depo=0.003) = 0.1439
# logical error rate for (L=11,loss_rate=0.017,depo=0.003) = 0.1451
# logical error rate for (L=11,loss_rate=0.017,depo=0.003) = 0.1425
# logical error rate for (L=11,loss_rate=0.018,depo=0.003) = 0.1698
# logical error rate for (L=11,loss_rate=0.018,depo=0.003) = 0.1807
# logical error rate for (L=11,loss_rate=0.018,depo=0.003) = 0.1742
# logical error rate for (L=11,loss_rate=0.018,depo=0.003) = 0.1783
# logical error rate for (L=11,loss_rate=0.018,depo=0.003) = 0.1729
# logical error rate for (L=11,loss_rate=0.018,depo=0.003) = 0.1705
# logical error rate for (L=11,loss_rate=0.018,depo=0.003) = 0.1734
# logical error rate for (L=11,loss_rate=0.018,depo=0.003) = 0.1733
# logical error rate for (L=11,loss_rate=0.018,depo=0.003) = 0.1718
# logical error rate for (L=11,loss_rate=0.018,depo=0.003) = 0.1789
# logical error rate for (L=11,loss_rate=0.019,depo=0.003) = 0.1987
# logical error rate for (L=11,loss_rate=0.019,depo=0.003) = 0.2081
# logical error rate for (L=11,loss_rate=0.019,depo=0.003) = 0.2068
# logical error rate for (L=11,loss_rate=0.019,depo=0.003) = 0.2067
# logical error rate for (L=11,loss_rate=0.019,depo=0.003) = 0.2006
# logical error rate for (L=11,loss_rate=0.019,depo=0.003) = 0.2059
# logical error rate for (L=11,loss_rate=0.019,depo=0.003) = 0.1946
# logical error rate for (L=11,loss_rate=0.019,depo=0.003) = 0.2001
# logical error rate for (L=11,loss_rate=0.019,depo=0.003) = 0.2062
# logical error rate for (L=11,loss_rate=0.019,depo=0.003) = 0.2037
